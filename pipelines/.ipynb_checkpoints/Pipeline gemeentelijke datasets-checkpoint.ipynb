# %% [markdown]
# # Create and/or update (Dutch) municipal datasets

# %% [markdown]
# **TO DO** | Add "getting started" documentation

# %%
# internal modules
import os
import sys

# external modules
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import seaborn as sns
import xlwings as xw
import yaml
from pathlib import Path

# project modules
import config.config as config
from src.checks import Checker
from src.extract import PblService
from src.transform import Transformer

# %% [markdown]
# ## Scope

# %% [markdown]
# Before we start we need to specify which datasets we want to create or update. This can be done with the `data.csv` file in the `config` directory. Here you can specify the geo ID, parent dataset and name for each region.
#
# Also, make sure to specify the parent dataset and the year in the cell below.
#
# **TO DO** | Add variable all_municipalities (based on the default etlocal config)

# %%
# Select the parent data set. Make sure to use the geo ID. It should be existing in the Dataset Manager.
parent = "nl"

# Specify the year
year = 2019

# Specify the CSV-separator (presumably either "," or ";")
sep=","

# Either specify the municipalities by using the data.csv file in the config directory.
# Make sure to specify the right separator in the pd.read_csv() function.
path = Path("config", "data.csv")
municipalities = pd.read_csv(path, sep=sep)['geo_id'].to_list()

# Preview municipality geo IDs
municipalities
# Out:
# ['GM1896']

# %% [markdown]
# ## General

# %% [markdown]
# ### 1. Data collection

# %%
# TODO

# %% [markdown]
# In the data collection phase, we make an overview of the required data and design a data model to efficiently build our database. If possible, we call the API to collect our data. Otherwise, we first manually collect a data export and store it in the `data / raw` directory.
#
# ![image.png](attachment:75b96a93-92f4-444a-9a96-18eb4a6d5295.png)
#
# For the municipal datasets we use the following data sources:
# * **??** | ...
# * **Dataset manager** | to collect the parent dataset
#
# For each data source, the following steps are followed:
# * **Extract** | Extracting the raw data from its source
# * **Transform** | Transforming the raw data to a 'workable' format
# * **Load** | Writing the processed data to the intermediate data directory

# %%
# TODO

# %% [markdown]
# #### ETM dataset manager (parent dataset)

# %% [markdown]
# In case certain data points are not available for the given region, we want to inherit the values of the parent dataset. For the municipality datasets, the parent is the NL2019 dataset.

# %% [markdown]
# ##### Extract
# In this step we call the ETM Dataset Manager API to get the parent dataset.

# %%
# Connect to the ETM dataset manager API and collect the parent dataset 
response = requests.get(f"https://data.energytransitionmodel.com/api/v1/exports/{parent}")

# %%
# Check if the response has been successful. If the code is anything else than 200, something went wrong.
response.status_code
# Out:
# 200

# %% [markdown]
# Here is an overview of the different status codes and what these imply:
#
# - **200**: Everything went okay, and the result has been returned (if any).
# - **301**: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# - **400**: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
# - **401**: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t send the right credentials to access an API.
# - **403**: The resource you’re trying to access is forbidden: you don’t have the right perlessons to see it.
# - **404**: The resource you tried to access wasn’t found on the server.
# - **503**: The server is not ready to handle the request.

# %%
# In that case, print the error message to see what caused the error
response.reason
# Out:
# 'OK'

# %% [markdown]
# ##### Transform
# Create a dataframe from the API response in which the parent dataset is included.

# %%
# If the reponse has been successful, collect its data.

# The data is stored as a dict in a single-itemed array. To get the dict, get the first item of the array.
raw_parent_data = response.json()[0]

# Then, create a dataframe from the dict.
df_parent = pd.DataFrame(raw_parent_data, index=[0])

# Rename the index to nl
df_parent = df_parent.rename(index={0: 'nl'})

# %%
# Preview the data in its transposed form (by using .T)
df_parent.T
# Out:
#                                                                 nl
# agriculture_final_demand_electricity_demand              41584.615
# agriculture_final_demand_network_gas_demand              91072.918
# input_agriculture_final_demand_steam_hot_water_...        2783.107
# agriculture_final_demand_wood_pellets_demand              5437.224
# input_agriculture_final_demand_crude_oil_demand          17965.442
# ...                                                            ...
# input_transport_ship_electricity_demand                        0.0
# bunkers_total_useful_demand_ships_demand                478316.636
# area                                                NL_netherlands
# base_dataset                                                    eu
# group                                                      country
#
# [645 rows x 1 columns]

# %% [markdown]
# ##### Load
# Save the parent data set to the intermediate data folder.

# %%
# Write dataframe to intermediate data folder
df_parent.to_csv(f"data/intermediate/parent_data.csv")

# %% [markdown]
# ### 2. Data quality

# %%
# TODO

# %% [markdown]
# #### Setup
#
# Setup the checker and load all files from the `data / intermediate` directory.

# %% [markdown]
# First, setup the checker class

# %%
# Initialise checker class to access transformation functions
checker = Checker()

# %% [markdown]
# Then, setup all data files:
# - ...
# - parent data

# %% [markdown]
# ### 3. Data transformation

# %%
# TODO

# %% [markdown]
# #### Setup
#
# Setup the transformer and load all intermediate data files for the next step in the pipeline.

# %% [markdown]
# First, setup the transformer class:

# %%
# Initialise transformer class to access transformation functions
transformer = Transformer(municipalities, year)

# %% [markdown]
# Then, setup all data files:
# - dataframe representing data.csv
# - commits.yml
# - dataframe with all etlocal interface elements
# - ...
# - parent data

# %% [markdown]
# ##### Create empty ETLocal templates

# %% [markdown]
# Only run these cells if you want to create empty ETLocal templates. If the templates have been filled in previous steps, these changes will be overwritten. If you don't want to overwrite your changes, **DON'T** run the cells below. :-)

# %%
# First, initialize data.csv file based on the config file
path = Path("config", "data.csv")
df_data_csv = pd.read_csv(path, index_col=[0], sep=sep)

# Drop unnamed columns
df_data_csv = df_data_csv.drop(columns=df_data_csv.columns[df_data_csv.columns.str.startswith('Unnamed')])

# Preview dataframe representing data.csv
df_data_csv
# Out:
#        country             name
# geo_id
# GM1896  nl2019  Zwartewaterland

# %%
# Then, initialize commits.yml file by specifying the file path where you want to create the YAML file
path = Path("data", "reporting", "commits.yml")

# Write the document separator to the YAML file
with open(path, 'w') as file:
    file.write('---\n')

# %%
# TODO: Describe that by running this cell an empty template is created. This overwrites the filled template.

# Load ETLocal template with target keys from config
path = Path("config", "etlocal_interface_elements.csv")
empty_template = pd.read_csv(path, header=[0], sep=sep)#, index_col=[2])

# Add columns geo_id, value and commit to the template    
for column in ['geo_id', 'value', 'commit']:
    empty_template[column] = float('nan')
    
# Fill the geo_id column with all relevant municipal geo IDs
templates = []
for municipality in municipalities:
    template_to_add = empty_template.copy()
    template_to_add['geo_id'] = municipality
    templates.append(template_to_add)
    
# Concatenate list of templates to one big template with all municipalities
template = pd.concat(templates)

# Transform the templates into a multi-index dataframe
index = pd.MultiIndex.from_frame(template[['geo_id', 'group', 'subgroup', 'key']])
template = template.drop(columns=['geo_id', 'group', 'subgroup', 'key'])
template.index = index

# Preview merged template
template
# Out:
#                                                                                                unit  \
# geo_id group      subgroup                key
# GM1896 area       area_emission_factors   file_carriers_imported_heat_lt_co2_conversion_p...  kg/MJ
#                                           file_carriers_imported_heat_mt_co2_conversion_p...  kg/MJ
#                                           file_carriers_imported_heat_ht_co2_conversion_p...  kg/MJ
#        households households_applications households_final_demand_electricity_households_...      %
#                                           households_final_demand_electricity_households_...      %
# ...                                                                                             ...
#        energy     energy_heat_production  energy_import_mt_heat_demand                           TJ
#                                           energy_import_lt_heat_demand                           TJ
#                   energy_energy_demand    energy_heat_distribution_ht_loss_share                  %
#                                           energy_heat_distribution_mt_loss_share                  %
#                                           energy_heat_distribution_lt_loss_share                  %
#
#                                                                                               value  \
# geo_id group      subgroup                key
# GM1896 area       area_emission_factors   file_carriers_imported_heat_lt_co2_conversion_p...    NaN
#                                           file_carriers_imported_heat_mt_co2_conversion_p...    NaN
#                                           file_carriers_imported_heat_ht_co2_conversion_p...    NaN
#        households households_applications households_final_demand_electricity_households_...    NaN
#                                           households_final_demand_electricity_households_...    NaN
# ...                                                                                             ...
#        energy     energy_heat_production  energy_import_mt_heat_demand                          NaN
#                                           energy_import_lt_heat_demand                          NaN
#                   energy_energy_demand    energy_heat_distribution_ht_loss_share                NaN
#                                           energy_heat_distribution_mt_loss_share                NaN
#                                           energy_heat_distribution_lt_loss_share                NaN
#
#                                                                                               commit
# geo_id group      subgroup                key
# GM1896 area       area_emission_factors   file_carriers_imported_heat_lt_co2_conversion_p...     NaN
#                                           file_carriers_imported_heat_mt_co2_conversion_p...     NaN
#                                           file_carriers_imported_heat_ht_co2_conversion_p...     NaN
#        households households_applications households_final_demand_electricity_households_...     NaN
#                                           households_final_demand_electricity_households_...     NaN
# ...                                                                                              ...
#        energy     energy_heat_production  energy_import_mt_heat_demand                           NaN
#                                           energy_import_lt_heat_demand                           NaN
#                   energy_energy_demand    energy_heat_distribution_ht_loss_share                 NaN
#                                           energy_heat_distribution_mt_loss_share                 NaN
#                                           energy_heat_distribution_lt_loss_share                 NaN
#
# [212 rows x 3 columns]

# %% [markdown]
# ##### Load parent data

# %%
# Import parent data
path = Path("data", "intermediate", "parent_data.csv")
df_parent = pd.read_csv(path, index_col=0)

# Preview parent data
df_parent.T.head()
# Out:
#                                                            nl
# agriculture_final_demand_electricity_demand         41584.615
# agriculture_final_demand_network_gas_demand         91072.918
# input_agriculture_final_demand_steam_hot_water_...   2783.107
# agriculture_final_demand_wood_pellets_demand         5437.224
# input_agriculture_final_demand_crude_oil_demand     17965.442

# %% [markdown]
# #### Emission factors
# Transform the data to the right format.

# %% [markdown]
# ##### List ETLocal keys

# %% [markdown]
# Preview the ETLocal keys that are relevant for the agriculture energy demand category

# %%
# Filter the ETLocal keys that are relevant for the emission factors category
filter_emission_factors = (slice(None), 'area', 'area_emission_factors')

# Preview the filtered template
template.loc[filter_emission_factors, :]
# Out:
#                                                                                         unit  \
# geo_id group subgroup              key
# GM1896 area  area_emission_factors file_carriers_imported_heat_lt_co2_conversion_p...  kg/MJ
#                                    file_carriers_imported_heat_mt_co2_conversion_p...  kg/MJ
#                                    file_carriers_imported_heat_ht_co2_conversion_p...  kg/MJ
#
#                                                                                        value  \
# geo_id group subgroup              key
# GM1896 area  area_emission_factors file_carriers_imported_heat_lt_co2_conversion_p...    NaN
#                                    file_carriers_imported_heat_mt_co2_conversion_p...    NaN
#                                    file_carriers_imported_heat_ht_co2_conversion_p...    NaN
#
#                                                                                        commit
# geo_id group subgroup              key
# GM1896 area  area_emission_factors file_carriers_imported_heat_lt_co2_conversion_p...     NaN
#                                    file_carriers_imported_heat_mt_co2_conversion_p...     NaN
#                                    file_carriers_imported_heat_ht_co2_conversion_p...     NaN

# %% [markdown]
# ##### Fill missing values

# %% [markdown]
# Then, fill the missing values for:
# - Imported heat
# - ...

# %% [markdown]
# **Imported heat** | Emission factors are cross-regionals. Hence, we use the same values for all datasets.

# %%
# TODO: we could also use the parent data shares instead?
key = f'file_carriers_imported_heat_co2_conversion_per_mj'

val = 0.036 # TODO: this should be moved to a config or raw data file?

# Update value and corresponding commit message for the temperature level share
template.loc[(slice(None), slice(None), slice(None), key), 'value'] = val
template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"Based on https://www.co2emissiefactoren.nl/lijst-emissiefactoren/" # TODO: Describe which exact data is used

# %%
# Preview template after changes
template.loc[filter_emission_factors, :].head()
# Out:
#                                                                                         unit  \
# geo_id group subgroup              key
# GM1896 area  area_emission_factors file_carriers_imported_heat_lt_co2_conversion_p...  kg/MJ
#                                    file_carriers_imported_heat_mt_co2_conversion_p...  kg/MJ
#                                    file_carriers_imported_heat_ht_co2_conversion_p...  kg/MJ
#
#                                                                                        value  \
# geo_id group subgroup              key
# GM1896 area  area_emission_factors file_carriers_imported_heat_lt_co2_conversion_p...  0.036
#                                    file_carriers_imported_heat_mt_co2_conversion_p...  0.036
#                                    file_carriers_imported_heat_ht_co2_conversion_p...  0.036
#
#                                                                                                                                   commit
# geo_id group subgroup              key
# GM1896 area  area_emission_factors file_carriers_imported_heat_lt_co2_conversion_p...  Based on https://www.co2emissiefactoren.nl/lij...
#                                    file_carriers_imported_heat_mt_co2_conversion_p...  Based on https://www.co2emissiefactoren.nl/lij...
#                                    file_carriers_imported_heat_ht_co2_conversion_p...  Based on https://www.co2emissiefactoren.nl/lij...

# %% [markdown]
# #### Exceptions
#
# If there are any exceptions for municipal datasets, you can overwrite the values below.

# %% [markdown]
# **TO DO** | Explain to the user that this section should always be checked. Should the exception be overwritten by the update? Or should it remain untouched?

# %% [markdown]
# ##### Gemeente X

# %%
#

# %% [markdown]
# #### Export processed data
# Write the transformed data to our  `data / processed` directory. This is the data we will be using for the next (analysis and visualisation) steps in the pipeline.

# %%
# Write dataframe to intermediate data folder
path = Path("data", "processed", "etlocal_template.csv")
template.to_csv(path)

# %% [markdown]
# ### 4. Data analysis and visualisation

# %%
# TODO

# %% [markdown]
# ## Households

# %% [markdown]
# In this section we focus on the data of the households sector: energy demand, energy supply, housing stock and application shares.

# %% [markdown]
# ### 1. Data collection (extract, transform, load)

# %% [markdown]
# In the data collection phase, we make an overview of the required data and design a data model to efficiently build our database. If possible, we call the API to collect our data. Otherwise, we first manually collect a data export and store it in the `data / raw` directory.
#
# ![image.png](attachment:75b96a93-92f4-444a-9a96-18eb4a6d5295.png)
#
# For the municipal datasets we use the following data sources:
# * **Klimaatmonitor** | to collect municipal data about energy demand, supply and housing stock
# * **Referentieverbruiken PBL** | to collect municipal data about application shares
# * **Dataset manager** | to collect the parent dataset
#
# For each data source, the following steps are followed:
# * **Extract** | Extracting the raw data from its source
# * **Transform** | Transforming the raw data to a 'workable' format
# * **Load** | Writing the processed data to the intermediate data directory

# %% [markdown]
# #### Klimaatmonitor

# %% [markdown]
# Klimaatmonitor is used to determine the final demand per carrier for each municipality, using the following the keys:
#
# - inwoners
# - woningen
# - el_woningen_tj_incl_zonachtermeter
# - gaswoningen
# - warmwontier2
# - houtskool
# - houtwontj
# - zonpvtj_won
#
# **TO DO** | Describe the steps for retrieving the raw data from Klimaatmonitor

# %% [markdown]
# ##### Extract
#
# We start with collecting the relevant data from the data export. This results in a dataframe with key/value combinations for all Dutch municipalities.

# %%
# Source data retrieves all KM data for each municipality
path_km = Path("data", "raw", f"Thema's - {year} - Gemeenten.xlsx")
wb_km = xw.Book(str(path_km))
ws_km_source_data = wb_km.sheets["Data"]

df_km_source_data = pd.DataFrame(ws_km_source_data.used_range.value)
df_km_source_data.columns = df_km_source_data.iloc[0]
df_km_source_data = df_km_source_data[1:]
df_km_source_data = df_km_source_data.set_index(df_km_source_data.columns[1])

# Close the Excel workbook
wb_km.close()

# %%
# Preview
df_km_source_data.head()
# Out:
# 0          Gebieden inwoners_2019 woningen_2019 zonpvtj_won_2019  \
# Code
# 1680    Aa en Hunze       25386.0       11257.0             30.0
# 358        Aalsmeer       31728.0       13091.0             16.0
# 197          Aalten       27011.0       11971.0             23.0
# 59    Achtkarspelen       27852.0       12118.0             21.0
# 482    Alblasserdam       20069.0        8324.0              6.0
#
# 0    houtwontj_2019 houtskool_2019 warmwontier2_2019 gaswoningen_2019  \
# Code
# 1680           61.0            0.0               0.0             18.5
# 358            11.0            0.0               0.0             16.2
# 197            55.0            0.0            1000.0             15.6
# 59             21.0            0.0               0.0             17.1
# 482            15.0            0.0            4000.0              8.4
#
# 0    el_woningen_tj_incl_zonachtermeter_2019
# Code
# 1680                                   129.0
# 358                                    145.0
# 197                                    129.0
# 59                                     121.0
# 482                                     81.0

# %% [markdown]
# Next, we collect the relevant meta data for each key (or "topic"). This provides us with information about, among others, the topic and unit for each key.

# %%
# Meta data is used to generate commit messages and extract the unit
path_km = Path("data", "raw", f"Thema's - {year} - Gemeenten.xlsx")
wb_km = xw.Book(str(path_km))
ws_km_meta_data = wb_km.sheets["Onderwerp Informatie"]

df_km_meta_data = pd.DataFrame(ws_km_meta_data.used_range.value)
df_km_meta_data.columns = df_km_meta_data.iloc[0]
df_km_meta_data = df_km_meta_data[1:]
df_km_meta_data = df_km_meta_data.set_index(df_km_meta_data.columns[0])

# Close the Excel workbook
wb_km.close()

# %%
# Preview
df_km_meta_data.head()
# Out:
# 0                                                    Onderwerp Eenheid  \
# Code
# inwoners                                       Aantal inwoners  Aantal
# woningen                         Aantal woningen per 1 januari  Aantal
# zonpvtj_won  Zonnestroom opgewekt door zonnepanelen op woni...      TJ
# houtwontj                    Houtkachels woningen hern. warmte      TJ
# houtskool                               Houtskool hern. warmte      TJ
#
# 0                                                         Bron Voetnoot  \
# Code
# inwoners              CBS - Centraal Bureau voor de Statistiek     None
# woningen                                                  None     None
# zonpvtj_won      CBS - Statistiek zonnestroom en schatting RVO     None
# houtwontj    Verdeling regionale gegevens hernieuwbare ener...     None
# houtskool    Verdeling regionale gegevens hernieuwbare ener...     None
#
# 0           Beschrijving Gegevenstype Laatste database wijziging
# Code
# inwoners            None     Numeriek         20-1-2023 12:56:43
# woningen            None     Numeriek         20-1-2023 12:54:55
# zonpvtj_won         None     Numeriek         16-5-2023 05:57:48
# houtwontj           None     Numeriek        24-12-2022 17:56:42
# houtskool           None     Numeriek        12-11-2022 20:24:59

# %% [markdown]
# ##### Transform
#
# We need to transform the municipal codes to the geo ID format that the ETM is familiar with. Thus, we need to paste "GM" and possibly some zeros in front of the code.

# %%
# Fill GM code to match desired area code structure
df_km_source_data.index = df_km_source_data.index.str.zfill(4).map(lambda x: 'GM' + x)

# %%
# Preview
df_km_source_data.head()
# Out:
# 0            Gebieden inwoners_2019 woningen_2019 zonpvtj_won_2019  \
# Code
# GM1680    Aa en Hunze       25386.0       11257.0             30.0
# GM0358       Aalsmeer       31728.0       13091.0             16.0
# GM0197         Aalten       27011.0       11971.0             23.0
# GM0059  Achtkarspelen       27852.0       12118.0             21.0
# GM0482   Alblasserdam       20069.0        8324.0              6.0
#
# 0      houtwontj_2019 houtskool_2019 warmwontier2_2019 gaswoningen_2019  \
# Code
# GM1680           61.0            0.0               0.0             18.5
# GM0358           11.0            0.0               0.0             16.2
# GM0197           55.0            0.0            1000.0             15.6
# GM0059           21.0            0.0               0.0             17.1
# GM0482           15.0            0.0            4000.0              8.4
#
# 0      el_woningen_tj_incl_zonachtermeter_2019
# Code
# GM1680                                   129.0
# GM0358                                   145.0
# GM0197                                   129.0
# GM0059                                   121.0
# GM0482                                    81.0

# %% [markdown]
# ##### Load
#
# We're now done with the data collection from Klimaatmonitor. Let's store our data in the `data / intermediate` directory.

# %%
# Write dataframe to intermediate data folder
df_km_source_data.to_csv(f"data/intermediate/klimaatmonitor_source_data_{year}.csv")

# %%
# Write dataframe to intermediate data folder
df_km_meta_data.to_csv(f"data/intermediate/klimaatmonitor_meta_data_{year}.csv")

# %% [markdown]
# #### Referentieverbruiken PBL

# %% [markdown]
# The "referentieverbruiken" study by PBL is used to calculate the application shares for each municipality.

# %% [markdown]
# ##### Extract
# First, we extract the raw data in Excel format from the PBL website. Then, we create a dataframe from the relevant Excel data sheet.

# %%
# Call the PBL referentieverbruiken service and store the raw Excel data in the "data / raw" directory
# It's not necessary to run this step if the raw Excel data is yet present in the directory
for municipality in municipalities:
    PblService(municipality).call()

# %%
# Transform and load the raw Excel data to a workable dataframe format
df_pbl_raw = {}
for municipality in municipalities:
    # Initialise the path to the application shares data by PBL
    path = Path("data", "raw", f"pbl_referentieverbruiken_{municipality}.xlsx")
        
    # Load the relevant sheet ("Resultaten gemeente") into a dataframe
    wb = xw.Book(path)
    ws = wb.sheets["Resultaten gemeente"]
    
    # Add the dataframe to the dict
    df_pbl_raw[municipality] = pd.DataFrame(ws.used_range.value)

    # Close the workbook
    wb.close()
    
# NB: Excel will open the relevant files after running this cell.
# Make sure not to actively close them. The files should close themselves 
# after all steps from the data collection have been run.

# %%
# Preview dataframe for the first municipality in the dict
df_pbl_raw[municipalities[0]]
# Out:
#                       0                    1                2         3   \
# 0                 Woning                Adres  Aantal bewoners     Regio
# 1                 vbo_id  Postcode_huisnummer  Aantal bewoners  gemeente
# 2
# 3                   code                 code           aantal      code
# 4     '1896010000000004'        '8281BV_25_a'              1.0      1896
# ...                  ...                  ...              ...       ...
# 8960  '1896010000011198'         '8294PA_124'              3.0      1896
# 8961  '1896010000011257'        '8064EA_19_a'              3.0      1896
# 8962  '1896010000011259'          '8064AE_44'              3.0      1896
# 8963  '1896010000011263'         '8061HA_1_a'              2.0      1896
# 8964  '1896010000011264'         '8061HA_1_b'              2.0      1896
#
#           4             5                                                6   \
# 0       None                                                Woningkenmerken
# 1       wijk     buurtcode                                        Kenmerken
# 2       None                                                           None
# 3       code          code                                             code
# 4     189600  'BU18960001'  'meergezins: laag en midden_voor 1930_wooncorp'
# ...      ...           ...                                              ...
# 8960  189605  'BU18960500'                    'Vrijstaand_1946 - 1964_koop'
# 8961  189604  'BU18960406'                 '2 onder 1 kap_1996 - 1999_koop'
# 8962  189604  'BU18960402'                  'Vrijstaand_voor 1930_parthuur'
# 8963  189602  'BU18960200'  'meergezins: laag en midden_voor 1930_parthuur'
# 8964  189602  'BU18960200'  'meergezins: laag en midden_voor 1930_parthuur'
#
#               7            8         9   ...    65    66    67    68    69  \
# 0           None         None      None  ...  None  None  None  None  None
# 1     woningtype  bouwperiode  bouwjaar  ...  None  None  None  None  None
# 2                                  None  ...  None  None  None  None  None
# 3           code         code      jaar  ...  None  None  None  None  None
# 4            5.0          0.0    1910.0  ...  None  None  None  None  None
# ...          ...          ...       ...  ...   ...   ...   ...   ...   ...
# 8960         1.0          2.0    1960.0  ...  None  None  None  None  None
# 8961         2.0          6.0    1996.0  ...  None  None  None  None  None
# 8962         1.0          0.0    1900.0  ...  None  None  None  None  None
# 8963         5.0          0.0    1560.0  ...  None  None  None  None  None
# 8964         5.0          0.0    1560.0  ...  None  None  None  None  None
#
#         70    71    72    73    74
# 0     None  None  None  None  None
# 1     None  None  None  None  None
# 2     None  None  None  None  None
# 3     None  None  None  None  None
# 4     None  None  None  None  None
# ...    ...   ...   ...   ...   ...
# 8960  None  None  None  None  None
# 8961  None  None  None  None  None
# 8962  None  None  None  None  None
# 8963  None  None  None  None  None
# 8964  None  None  None  None  None
#
# [8965 rows x 75 columns]

# %% [markdown]
# ##### Transform
# The raw data should be cleaned before we can use it. We should remove columns without headers or values, use the bag vbo id as index, and set the right headers. Also, we want to merge the data for all municipalities into one big dataframe.

# %%
df_pbl = {}
for municipality in municipalities:
    # Columns 62 through 74 seem to be empty--thus, these can be removed
    df_pbl[municipality] = df_pbl_raw[municipality].drop(df_pbl_raw[municipality].iloc[:, 62:75], axis=1)

    # Use first column as (woning vbo_id) as index and rename it
    df_pbl[municipality] = df_pbl[municipality].set_index(df_pbl[municipality][0])
    df_pbl[municipality].index.names = ['bag_vbo_id']
    df_pbl[municipality] = df_pbl[municipality].drop(df_pbl[municipality].columns[0], axis=1)

    # Use first four rows to create a multi-row header
    df_pbl[municipality].columns = [df_pbl[municipality].iloc[0], df_pbl[municipality].iloc[1], df_pbl[municipality].iloc[2], df_pbl[municipality].iloc[3]]
    df_pbl[municipality] = df_pbl[municipality][4:]

    # Remove redundant top-level index names 
    df_pbl[municipality].columns.names = [None] * len(df_pbl[municipality].columns.names)

# %%
# Run this cell if you want the transformed dataframe to be previewed for the first municipality in the dict
df_pbl[municipalities[0]]
# Out:
#                                  Adres Aantal bewoners    Regio     NaN  \
#                    Postcode_huisnummer Aantal bewoners gemeente    wijk
#                                                                     NaN
#                                   code          aantal     code    code
# bag_vbo_id
# '1896010000000004'       '8281BV_25_a'             1.0     1896  189600
# '1896010000000005'         '8061AH_35'             3.0     1896  189602
# '1896010000000006'         '8061AH_37'             3.0     1896  189602
# '1896010000000007'         '8061AH_39'             3.0     1896  189602
# '1896010000000008'         '8061AH_41'             3.0     1896  189602
# ...                                ...             ...      ...     ...
# '1896010000011198'        '8294PA_124'             3.0     1896  189605
# '1896010000011257'       '8064EA_19_a'             3.0     1896  189604
# '1896010000011259'         '8064AE_44'             3.0     1896  189604
# '1896010000011263'        '8061HA_1_a'             2.0     1896  189602
# '1896010000011264'        '8061HA_1_b'             2.0     1896  189602
#
#                                   \
#                        buurtcode
#
#                             code
# bag_vbo_id
# '1896010000000004'  'BU18960001'
# '1896010000000005'  'BU18960204'
# '1896010000000006'  'BU18960204'
# '1896010000000007'  'BU18960204'
# '1896010000000008'  'BU18960204'
# ...                          ...
# '1896010000011198'  'BU18960500'
# '1896010000011257'  'BU18960406'
# '1896010000011259'  'BU18960402'
# '1896010000011263'  'BU18960200'
# '1896010000011264'  'BU18960200'
#
#                                                     Woningkenmerken  \
#                                                           Kenmerken
#                                                                 NaN
#                                                                code
# bag_vbo_id
# '1896010000000004'  'meergezins: laag en midden_voor 1930_wooncorp'
# '1896010000000005'                'rijwoning hoek_1975 - 1991_koop'
# '1896010000000006'              'rijwoning tussen_1975 - 1991_koop'
# '1896010000000007'              'rijwoning tussen_1975 - 1991_koop'
# '1896010000000008'              'rijwoning tussen_1975 - 1991_koop'
# ...                                                             ...
# '1896010000011198'                    'Vrijstaand_1946 - 1964_koop'
# '1896010000011257'                 '2 onder 1 kap_1996 - 1999_koop'
# '1896010000011259'                  'Vrijstaand_voor 1930_parthuur'
# '1896010000011263'  'meergezins: laag en midden_voor 1930_parthuur'
# '1896010000011264'  'meergezins: laag en midden_voor 1930_parthuur'
#
#                           NaN                                  ...  \
#                    woningtype bouwperiode bouwjaar schillabel  ...
#                                                NaN             ...
#                          code        code     jaar       code  ...
# bag_vbo_id                                                     ...
# '1896010000000004'        5.0         0.0   1910.0          x  ...
# '1896010000000005'        3.0         4.0   1975.0          C  ...
# '1896010000000006'        4.0         4.0   1975.0          x  ...
# '1896010000000007'        4.0         4.0   1975.0          x  ...
# '1896010000000008'        4.0         4.0   1975.0          C  ...
# ...                       ...         ...      ...        ...  ...
# '1896010000011198'        1.0         2.0   1960.0          A  ...
# '1896010000011257'        2.0         6.0   1996.0          x  ...
# '1896010000011259'        1.0         0.0   1900.0          x  ...
# '1896010000011263'        5.0         0.0   1560.0          x  ...
# '1896010000011264'        5.0         0.0   1560.0          x  ...
#
#                     Metervraag olie  NaN Metervraag totaal           NaN  \
#                    ruimteverwarming  NaN           aardgas elektriciteit
#                               basis piek
#                                  GJ   GJ                GJ            GJ
# bag_vbo_id
# '1896010000000004'              0.0  0.0           24.7769       0.10093
# '1896010000000005'              0.0  0.0         41.723369      0.173674
# '1896010000000006'              0.0  0.0         38.224543      0.160749
# '1896010000000007'              0.0  0.0         41.698018      0.174953
# '1896010000000008'              0.0  0.0          39.05084      0.165318
# ...                             ...  ...               ...           ...
# '1896010000011198'              0.0  0.0         49.498442      0.200934
# '1896010000011257'              0.0  0.0         40.854764      0.170706
# '1896010000011259'              0.0  0.0         72.243063      0.286257
# '1896010000011263'              0.0  0.0         42.177068      0.155844
# '1896010000011264'              0.0  0.0         42.177068      0.155844
#
#                                                                  \
#                    warmtenet waterstof biomassa olie     totaal
#
#                           GJ        GJ       GJ   GJ         GJ
# bag_vbo_id
# '1896010000000004'       0.0       0.0      0.0  0.0   24.87783
# '1896010000000005'       0.0       0.0      0.0  0.0  41.897043
# '1896010000000006'       0.0       0.0      0.0  0.0  38.385292
# '1896010000000007'       0.0       0.0      0.0  0.0  41.872972
# '1896010000000008'       0.0       0.0      0.0  0.0  39.216158
# ...                      ...       ...      ...  ...        ...
# '1896010000011198'       0.0       0.0      0.0  0.0  49.699376
# '1896010000011257'       0.0       0.0      0.0  0.0   41.02547
# '1896010000011259'       0.0       0.0      0.0  0.0   72.52932
# '1896010000011263'       0.0       0.0      0.0  0.0  42.332912
# '1896010000011264'       0.0       0.0      0.0  0.0  42.332912
#
#                    Regionale klimaatcorrectie
#
#
#
# bag_vbo_id
# '1896010000000004'                   1.052596
# '1896010000000005'                   1.052302
# '1896010000000006'                   1.052302
# '1896010000000007'                   1.052302
# '1896010000000008'                   1.052302
# ...                                       ...
# '1896010000011198'                     1.0466
# '1896010000011257'                   1.056163
# '1896010000011259'                   1.055357
# '1896010000011263'                   1.051428
# '1896010000011264'                   1.051428
#
# [8961 rows x 61 columns]

# %% [markdown]
# Since the raw data is not formatted properly, we need to create a new dataframe and fill it with the relevant data.

# %%
# Setup dataframe to collect the relevant data from the PBL referentieverbruiken overview
header=[['Metervraag aardgas','Metervraag aardgas','Metervraag aardgas',
         'Metervraag elektriciteit','Metervraag elektriciteit','Metervraag elektriciteit','Metervraag elektriciteit',
         'Metervraag warmtenet','Metervraag warmtenet',
         'Metervraag waterstof','Metervraag waterstof',
         'Metervraag biomassa','Metervraag biomassa',
         'Metervraag olie',
         'Metervraag totaal','Metervraag totaal','Metervraag totaal','Metervraag totaal','Metervraag totaal','Metervraag totaal','Metervraag totaal'],
        ['koken','warm tapwater','ruimteverwarming', # aardgas
         'koken','warm tapwater','ruimteverwarming','hulpvraag', # elektriciteit
         'warm tapwater','ruimteverwarming', # warmtenet
         'warm tapwater','ruimteverwarming', # waterstof
         'warm tapwater','ruimteverwarming', # biomassa
         'ruimteverwarming', # olie
         'aardgas', 'elektriciteit', 'warmtenet', 'waterstof', 'biomassa', 'olie', 'totaal']]

df_pbl_new = {}
for municipality in municipalities:
    df_pbl_new[municipality] = pd.DataFrame(columns=header)
    df_pbl_new[municipality].reindex(index=list(df_pbl[municipality].index))
    df_pbl_new[municipality].index.names = ['bag_vbo_id']

# %%
for municipality in municipalities:
    # Fill df_new with relevant data from df
    # TODO: restructure df so that we don't have to collect the data in this VERY VERY ugly way (which is also VERY VERY error prone)
    df_pbl_new[municipality].loc[:, ('Metervraag aardgas', 'koken')] = df_pbl[municipality].iloc[:,29]
    df_pbl_new[municipality].loc[:, ('Metervraag aardgas', 'warm tapwater')] = df_pbl[municipality].iloc[:,30]
    df_pbl_new[municipality].loc[:, ('Metervraag aardgas', 'ruimteverwarming')] = df_pbl[municipality].iloc[:,32]
    df_pbl_new[municipality].loc[:, ('Metervraag elektriciteit', 'koken')] = df_pbl[municipality].iloc[:,34]
    df_pbl_new[municipality].loc[:, ('Metervraag elektriciteit', 'warm tapwater')] = df_pbl[municipality].iloc[:,35]
    df_pbl_new[municipality].loc[:, ('Metervraag elektriciteit', 'ruimteverwarming')] = df_pbl[municipality].iloc[:,37]
    df_pbl_new[municipality].loc[:, ('Metervraag elektriciteit', 'hulpvraag')] = df_pbl[municipality].iloc[:,39]
    df_pbl_new[municipality].loc[:, ('Metervraag warmtenet', 'warm tapwater')] = df_pbl[municipality].iloc[:,40]
    df_pbl_new[municipality].loc[:, ('Metervraag warmtenet', 'ruimteverwarming')] = df_pbl[municipality].iloc[:,42]
    df_pbl_new[municipality].loc[:, ('Metervraag waterstof', 'warm tapwater')] = df_pbl[municipality].iloc[:,44]
    df_pbl_new[municipality].loc[:, ('Metervraag waterstof', 'ruimteverwarming')] = df_pbl[municipality].iloc[:,46]
    df_pbl_new[municipality].loc[:, ('Metervraag biomassa', 'warm tapwater')] = df_pbl[municipality].iloc[:,48]
    df_pbl_new[municipality].loc[:, ('Metervraag biomassa', 'ruimteverwarming')] = df_pbl[municipality].iloc[:,50]
    df_pbl_new[municipality].loc[:, ('Metervraag olie', 'ruimteverwarming')] = df_pbl[municipality].iloc[:,52]
    df_pbl_new[municipality].loc[:, ('Metervraag totaal', 'aardgas')] = df_pbl[municipality].iloc[:,54]
    df_pbl_new[municipality].loc[:, ('Metervraag totaal', 'elektriciteit')] = df_pbl[municipality].iloc[:,55]
    df_pbl_new[municipality].loc[:, ('Metervraag totaal', 'warmtenet')] = df_pbl[municipality].iloc[:,56]
    df_pbl_new[municipality].loc[:, ('Metervraag totaal', 'waterstof')] = df_pbl[municipality].iloc[:,57]
    df_pbl_new[municipality].loc[:, ('Metervraag totaal', 'biomassa')] = df_pbl[municipality].iloc[:,58]
    df_pbl_new[municipality].loc[:, ('Metervraag totaal', 'olie')] = df_pbl[municipality].iloc[:,59]
    df_pbl_new[municipality].loc[:, ('Metervraag totaal', 'totaal')] = df_pbl[municipality].iloc[:,60]

# %%
# Preview new dataframe (df_pbl_new) filled with data from the old dataframe (df_pbl) for the first municipality in the dict
df_pbl_new[municipalities[0]]
# Out:
#                    Metervraag aardgas                                 \
#                                 koken warm tapwater ruimteverwarming
# bag_vbo_id
# '1896010000000004'           2.987719      1.280451         6.010728
# '1896010000000005'           5.880235      2.520101         9.698433
# '1896010000000006'           5.905672      2.531002         8.633164
# '1896010000000007'           5.634049      2.414592         9.803854
# '1896010000000008'           5.634049      2.414592         9.009701
# ...                               ...           ...              ...
# '1896010000011198'           6.020058      2.580025        11.945091
# '1896010000011257'           5.935692      2.543868         9.453788
# '1896010000011259'           5.571699      2.387871        18.977192
# '1896010000011263'           4.384987       1.87928        10.536592
# '1896010000011264'           4.384987       1.87928        10.536592
#
#                    Metervraag elektriciteit                                 \
#                                       koken warm tapwater ruimteverwarming
# bag_vbo_id
# '1896010000000004'                      0.0           0.0              0.0
# '1896010000000005'                      0.0           0.0              0.0
# '1896010000000006'                      0.0           0.0              0.0
# '1896010000000007'                      0.0           0.0              0.0
# '1896010000000008'                      0.0           0.0              0.0
# ...                                     ...           ...              ...
# '1896010000011198'                      0.0           0.0              0.0
# '1896010000011257'                      0.0           0.0              0.0
# '1896010000011259'                      0.0           0.0              0.0
# '1896010000011263'                      0.0           0.0              0.0
# '1896010000011264'                      0.0           0.0              0.0
#
#                              Metervraag warmtenet                   \
#                    hulpvraag        warm tapwater ruimteverwarming
# bag_vbo_id
# '1896010000000004'       0.0                  0.0              0.0
# '1896010000000005'       0.0                  0.0              0.0
# '1896010000000006'       0.0                  0.0              0.0
# '1896010000000007'       0.0                  0.0              0.0
# '1896010000000008'       0.0                  0.0              0.0
# ...                      ...                  ...              ...
# '1896010000011198'       0.0                  0.0              0.0
# '1896010000011257'       0.0                  0.0              0.0
# '1896010000011259'       0.0                  0.0              0.0
# '1896010000011263'       0.0                  0.0              0.0
# '1896010000011264'       0.0                  0.0              0.0
#
#                    Metervraag waterstof  ... Metervraag biomassa  \
#                           warm tapwater  ...       warm tapwater
# bag_vbo_id                               ...
# '1896010000000004'                  0.0  ...                 0.0
# '1896010000000005'                  0.0  ...                 0.0
# '1896010000000006'                  0.0  ...                 0.0
# '1896010000000007'                  0.0  ...                 0.0
# '1896010000000008'                  0.0  ...                 0.0
# ...                                 ...  ...                 ...
# '1896010000011198'                  0.0  ...                 0.0
# '1896010000011257'                  0.0  ...                 0.0
# '1896010000011259'                  0.0  ...                 0.0
# '1896010000011263'                  0.0  ...                 0.0
# '1896010000011264'                  0.0  ...                 0.0
#
#                                      Metervraag olie Metervraag totaal  \
#                    ruimteverwarming ruimteverwarming           aardgas
# bag_vbo_id
# '1896010000000004'              0.0              0.0           0.10093
# '1896010000000005'              0.0              0.0          0.173674
# '1896010000000006'              0.0              0.0          0.160749
# '1896010000000007'              0.0              0.0          0.174953
# '1896010000000008'              0.0              0.0          0.165318
# ...                             ...              ...               ...
# '1896010000011198'              0.0              0.0          0.200934
# '1896010000011257'              0.0              0.0          0.170706
# '1896010000011259'              0.0              0.0          0.286257
# '1896010000011263'              0.0              0.0          0.155844
# '1896010000011264'              0.0              0.0          0.155844
#
#                                                                           \
#                    elektriciteit warmtenet waterstof biomassa       olie
# bag_vbo_id
# '1896010000000004'           0.0       0.0       0.0      0.0   24.87783
# '1896010000000005'           0.0       0.0       0.0      0.0  41.897043
# '1896010000000006'           0.0       0.0       0.0      0.0  38.385292
# '1896010000000007'           0.0       0.0       0.0      0.0  41.872972
# '1896010000000008'           0.0       0.0       0.0      0.0  39.216158
# ...                          ...       ...       ...      ...        ...
# '1896010000011198'           0.0       0.0       0.0      0.0  49.699376
# '1896010000011257'           0.0       0.0       0.0      0.0   41.02547
# '1896010000011259'           0.0       0.0       0.0      0.0   72.52932
# '1896010000011263'           0.0       0.0       0.0      0.0  42.332912
# '1896010000011264'           0.0       0.0       0.0      0.0  42.332912
#
#
#                       totaal
# bag_vbo_id
# '1896010000000004'  1.052596
# '1896010000000005'  1.052302
# '1896010000000006'  1.052302
# '1896010000000007'  1.052302
# '1896010000000008'  1.052302
# ...                      ...
# '1896010000011198'    1.0466
# '1896010000011257'  1.056163
# '1896010000011259'  1.055357
# '1896010000011263'  1.051428
# '1896010000011264'  1.051428
#
# [8961 rows x 21 columns]

# %% [markdown]
# Now concatenate all separate dataframes into one big one containing data for all municipalities

# %%
# Load application shares and store it in a dict of dataframes per municipality
dfs = []
for municipality in municipalities:
    # Add municipal geo ID to the dataframe and create a multi-index
    df_pbl_new[municipality]['geo_id'] = municipality
    df_pbl_new[municipality].set_index('geo_id', append=True, inplace=True)
    df_pbl_new[municipality] = df_pbl_new[municipality].swaplevel()

    # Remove the top-level index name
    df_pbl_new[municipality].columns.names = [None] * len(df_pbl_new[municipality].columns.names)
    
    # Append dataframe to the list
    dfs.append(df_pbl_new[municipality])

# Concatenate list of dataframes to one big dataframe
df_application_shares = pd.concat(dfs)

# Preview dataframe
df_application_shares
# Out:
#                           Metervraag aardgas                                 \
#                                        koken warm tapwater ruimteverwarming
# geo_id bag_vbo_id
# GM1896 '1896010000000004'           2.987719      1.280451         6.010728
#        '1896010000000005'           5.880235      2.520101         9.698433
#        '1896010000000006'           5.905672      2.531002         8.633164
#        '1896010000000007'           5.634049      2.414592         9.803854
#        '1896010000000008'           5.634049      2.414592         9.009701
# ...                                      ...           ...              ...
#        '1896010000011198'           6.020058      2.580025        11.945091
#        '1896010000011257'           5.935692      2.543868         9.453788
#        '1896010000011259'           5.571699      2.387871        18.977192
#        '1896010000011263'           4.384987       1.87928        10.536592
#        '1896010000011264'           4.384987       1.87928        10.536592
#
#                           Metervraag elektriciteit                \
#                                              koken warm tapwater
# geo_id bag_vbo_id
# GM1896 '1896010000000004'                      0.0           0.0
#        '1896010000000005'                      0.0           0.0
#        '1896010000000006'                      0.0           0.0
#        '1896010000000007'                      0.0           0.0
#        '1896010000000008'                      0.0           0.0
# ...                                            ...           ...
#        '1896010000011198'                      0.0           0.0
#        '1896010000011257'                      0.0           0.0
#        '1896010000011259'                      0.0           0.0
#        '1896010000011263'                      0.0           0.0
#        '1896010000011264'                      0.0           0.0
#
#                                                      Metervraag warmtenet  \
#                           ruimteverwarming hulpvraag        warm tapwater
# geo_id bag_vbo_id
# GM1896 '1896010000000004'              0.0       0.0                  0.0
#        '1896010000000005'              0.0       0.0                  0.0
#        '1896010000000006'              0.0       0.0                  0.0
#        '1896010000000007'              0.0       0.0                  0.0
#        '1896010000000008'              0.0       0.0                  0.0
# ...                                    ...       ...                  ...
#        '1896010000011198'              0.0       0.0                  0.0
#        '1896010000011257'              0.0       0.0                  0.0
#        '1896010000011259'              0.0       0.0                  0.0
#        '1896010000011263'              0.0       0.0                  0.0
#        '1896010000011264'              0.0       0.0                  0.0
#
#                                            Metervraag waterstof  ...  \
#                           ruimteverwarming        warm tapwater  ...
# geo_id bag_vbo_id                                                ...
# GM1896 '1896010000000004'              0.0                  0.0  ...
#        '1896010000000005'              0.0                  0.0  ...
#        '1896010000000006'              0.0                  0.0  ...
#        '1896010000000007'              0.0                  0.0  ...
#        '1896010000000008'              0.0                  0.0  ...
# ...                                    ...                  ...  ...
#        '1896010000011198'              0.0                  0.0  ...
#        '1896010000011257'              0.0                  0.0  ...
#        '1896010000011259'              0.0                  0.0  ...
#        '1896010000011263'              0.0                  0.0  ...
#        '1896010000011264'              0.0                  0.0  ...
#
#                           Metervraag biomassa                   \
#                                 warm tapwater ruimteverwarming
# geo_id bag_vbo_id
# GM1896 '1896010000000004'                 0.0              0.0
#        '1896010000000005'                 0.0              0.0
#        '1896010000000006'                 0.0              0.0
#        '1896010000000007'                 0.0              0.0
#        '1896010000000008'                 0.0              0.0
# ...                                       ...              ...
#        '1896010000011198'                 0.0              0.0
#        '1896010000011257'                 0.0              0.0
#        '1896010000011259'                 0.0              0.0
#        '1896010000011263'                 0.0              0.0
#        '1896010000011264'                 0.0              0.0
#
#                            Metervraag olie Metervraag totaal                \
#                           ruimteverwarming           aardgas elektriciteit
# geo_id bag_vbo_id
# GM1896 '1896010000000004'              0.0           0.10093           0.0
#        '1896010000000005'              0.0          0.173674           0.0
#        '1896010000000006'              0.0          0.160749           0.0
#        '1896010000000007'              0.0          0.174953           0.0
#        '1896010000000008'              0.0          0.165318           0.0
# ...                                    ...               ...           ...
#        '1896010000011198'              0.0          0.200934           0.0
#        '1896010000011257'              0.0          0.170706           0.0
#        '1896010000011259'              0.0          0.286257           0.0
#        '1896010000011263'              0.0          0.155844           0.0
#        '1896010000011264'              0.0          0.155844           0.0
#
#
#                           warmtenet waterstof biomassa       olie    totaal
# geo_id bag_vbo_id
# GM1896 '1896010000000004'       0.0       0.0      0.0   24.87783  1.052596
#        '1896010000000005'       0.0       0.0      0.0  41.897043  1.052302
#        '1896010000000006'       0.0       0.0      0.0  38.385292  1.052302
#        '1896010000000007'       0.0       0.0      0.0  41.872972  1.052302
#        '1896010000000008'       0.0       0.0      0.0  39.216158  1.052302
# ...                             ...       ...      ...        ...       ...
#        '1896010000011198'       0.0       0.0      0.0  49.699376    1.0466
#        '1896010000011257'       0.0       0.0      0.0   41.02547  1.056163
#        '1896010000011259'       0.0       0.0      0.0   72.52932  1.055357
#        '1896010000011263'       0.0       0.0      0.0  42.332912  1.051428
#        '1896010000011264'       0.0       0.0      0.0  42.332912  1.051428
#
# [8961 rows x 21 columns]

# %% [markdown]
# ##### Load
# Load the data into the intermediate data folder. This is the data we will be using for the next steps in the pipeline.

# %%
# Specify path for the to be created CSV file
path = Path("data", "intermediate", "application_shares.csv")

# Write the dataframe to this path
df_application_shares.to_csv(path)

# %% [markdown]
# #### ETM dataset manager (parent dataset)

# %% [markdown]
# In case certain data points are not available for the given region, we want to inherit the values of the parent dataset. For the municipality datasets, the parent is the NL2019 dataset.

# %% [markdown]
# ##### Extract
# In this step we call the ETM Dataset Manager API to get the parent dataset.

# %%
# Connect to the ETM dataset manager API and collect the parent dataset 
response = requests.get(f"https://data.energytransitionmodel.com/api/v1/exports/{parent}")

# %%
# Check if the response has been successful. If the code is anything else than 200, something went wrong.
response.status_code
# Out:
# 200

# %% [markdown]
# Here is an overview of the different status codes and what these imply:
#
# - **200**: Everything went okay, and the result has been returned (if any).
# - **301**: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# - **400**: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
# - **401**: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t send the right credentials to access an API.
# - **403**: The resource you’re trying to access is forbidden: you don’t have the right perlessons to see it.
# - **404**: The resource you tried to access wasn’t found on the server.
# - **503**: The server is not ready to handle the request.

# %%
# In that case, print the error message to see what caused the error
response.reason
# Out:
# 'OK'

# %% [markdown]
# ##### Transform
# Create a dataframe from the API response in which the parent dataset is included.

# %%
# If the reponse has been successful, collect its data.

# The data is stored as a dict in a single-itemed array. To get the dict, get the first item of the array.
raw_parent_data = response.json()[0]

# Then, create a dataframe from the dict.
df_parent = pd.DataFrame(raw_parent_data, index=[0])

# Rename the index to nl
df_parent = df_parent.rename(index={0: 'nl'})

# %%
# Preview the data in its transposed form (by using .T)
df_parent.T
# Out:
#                                                              nl
# agriculture_final_demand_electricity_demand           41584.615
# agriculture_final_demand_network_gas_demand           91072.918
# agriculture_final_demand_steam_hot_water_demand        2783.107
# agriculture_final_demand_wood_pellets_demand           5437.224
# input_agriculture_final_demand_crude_oil_demand       17965.442
# ...                                                         ...
# input_transport_ship_electricity_demand                     0.0
# bunkers_total_useful_demand_ships_demand             478316.636
# area                                             NL_netherlands
# base_dataset                                                 eu
# group                                                   country
#
# [619 rows x 1 columns]

# %% [markdown]
# ##### Load
# Save the parent data set to the intermediate data folder.

# %%
# Write dataframe to intermediate data folder
df_parent.to_csv(f"data/intermediate/parent_data.csv")

# %% [markdown]
# ### 2. Data quality

# %% [markdown]
# Addressing and managing the data quality of our data is crucial; it will ensure we have the correct data to answer the business question and therefore are able to have a good, reliable analytical solution. Not only for our current intention but also for future purposes. Hence, perform checks on accuracy, relevancy, completeness, timeliness, consistency:
#
# * **Accuracy** | for whatever data described, it needs to be accurate
# * **Relevancy** | the data should meet the requirements for the intended use
# * **Completeness** | the data should not have missing values or miss records
# * **Timeliness** | the data should be up to date
# * **Consistency** |the data should have the data format as expected and can be cross reference-able with the same results
#
#
# Typical checks that could be performed:
#
# * Are there any negative values or shares?
# * Are there any NaN values?
# * Are the data types per column as expected?
# * Do all keys occur in the dataset?
# * Are there keys without data? Could we inherit parent data here?
# * Are there any duplicate values for a key?
# * Do all share groups sum up to 100%?
# * Do the hourly curves sum up to 1?
# * Do the hourly curves correspond to the dataset year?

# %% [markdown]
# #### Setup
#
# Setup the checker and load all files from the `data / intermediate` directory.

# %% [markdown]
# First, setup the checker class

# %%
# Initialise checker class to access transformation functions
checker = Checker()

# %% [markdown]
# Then, setup all data files:
# - Klimaatmonitor source data
# - Klimaatmonitor meta data
# - application shares
# - parent data

# %%
# Load Klimaatmonitor source data
df_km_source_data = pd.read_csv(f'data/intermediate/klimaatmonitor_source_data_{year}.csv', index_col=[0])

# Preview data
df_km_source_data
# Out:
#                Gebieden  inwoners_2019  woningen_2019  zonpvtj_won_2019  \
# Code
# GM1680      Aa en Hunze        25386.0        11257.0              30.0
# GM0358         Aalsmeer        31728.0        13091.0              16.0
# GM0197           Aalten        27011.0        11971.0              23.0
# GM0059    Achtkarspelen        27852.0        12118.0              21.0
# GM0482     Alblasserdam        20069.0         8324.0               6.0
# ...                 ...            ...            ...               ...
# GM0879          Zundert        21612.0         9455.0              15.0
# GM0301          Zutphen        47609.0        22095.0              22.0
# GM1896  Zwartewaterland        22503.0         8903.0              12.0
# GM0642      Zwijndrecht        44639.0        20454.0              13.0
# GM0193           Zwolle       127497.0        57730.0              88.0
#
#         houtwontj_2019  houtskool_2019  warmwontier2_2019  gaswoningen_2019  \
# Code
# GM1680            61.0             0.0                0.0              18.5
# GM0358            11.0             0.0                0.0              16.2
# GM0197            55.0             0.0             1000.0              15.6
# GM0059            21.0             0.0                0.0              17.1
# GM0482            15.0             0.0             4000.0               8.4
# ...                ...             ...                ...               ...
# GM0879            49.0             0.0                0.0              14.0
# GM0301            45.0             1.0                0.0              24.5
# GM1896            36.0             0.0                0.0              11.6
# GM0642            29.0             1.0             2000.0              21.5
# GM0193            33.0             2.0            55000.0              58.2
#
#         el_woningen_tj_incl_zonachtermeter_2019
# Code
# GM1680                                    129.0
# GM0358                                    145.0
# GM0197                                    129.0
# GM0059                                    121.0
# GM0482                                     81.0
# ...                                         ...
# GM0879                                    117.0
# GM0301                                    197.0
# GM1896                                     95.0
# GM0642                                    194.0
# GM0193                                    531.0
#
# [345 rows x 9 columns]

# %%
# Load Klimaatmonitor meta data
df_km_meta_data = pd.read_csv(f'data/intermediate/klimaatmonitor_meta_data_{year}.csv', index_col=[0])

# Preview data
df_km_meta_data
# Out:
#                                                                             Onderwerp  \
# Code
# inwoners                                                              Aantal inwoners
# woningen                                                Aantal woningen per 1 januari
# zonpvtj_won                         Zonnestroom opgewekt door zonnepanelen op woni...
# houtwontj                                           Houtkachels woningen hern. warmte
# houtskool                                                      Houtskool hern. warmte
# warmwontier2                                Verbruik stadswarmte woningen (schatting)
# gaswoningen                                           Totaal aardgasverbruik woningen
# el_woningen_tj_incl_zonachtermeter  Totaal elektriciteitsverbruik woningen (incl. ...
#
#                                        Eenheid  \
# Code
# inwoners                                Aantal
# woningen                                Aantal
# zonpvtj_won                                 TJ
# houtwontj                                   TJ
# houtskool                                   TJ
# warmwontier2                                GJ
# gaswoningen                         miljoen m3
# el_woningen_tj_incl_zonachtermeter          TJ
#
#                                                                                  Bron  \
# Code
# inwoners                                     CBS - Centraal Bureau voor de Statistiek
# woningen                                                                          NaN
# zonpvtj_won                             CBS - Statistiek zonnestroom en schatting RVO
# houtwontj                           Verdeling regionale gegevens hernieuwbare ener...
# houtskool                           Verdeling regionale gegevens hernieuwbare ener...
# warmwontier2                        Extrapolatie gemiddeld gasverbruik naar verbru...
# gaswoningen                         Berekening  totaalverbruik woningen o.b.v. gem...
# el_woningen_tj_incl_zonachtermeter  Berekening  totaalverbruik woningen o.b.v. gem...
#
#                                     Voetnoot  Beschrijving Gegevenstype  \
# Code
# inwoners                                 NaN           NaN     Numeriek
# woningen                                 NaN           NaN     Numeriek
# zonpvtj_won                              NaN           NaN     Numeriek
# houtwontj                                NaN           NaN     Numeriek
# houtskool                                NaN           NaN     Numeriek
# warmwontier2                             NaN           NaN     Numeriek
# gaswoningen                              NaN           NaN     Numeriek
# el_woningen_tj_incl_zonachtermeter       NaN           NaN     Numeriek
#
#                                    Laatste database wijziging
# Code
# inwoners                                   20-1-2023 12:56:43
# woningen                                   20-1-2023 12:54:55
# zonpvtj_won                                16-5-2023 05:57:48
# houtwontj                                 24-12-2022 17:56:42
# houtskool                                 12-11-2022 20:24:59
# warmwontier2                              17-10-2022 19:15:13
# gaswoningen                                20-1-2023 12:54:55
# el_woningen_tj_incl_zonachtermeter         16-5-2023 05:57:48

# %%
# Load application shares
df_application_shares = pd.read_csv(f'data/intermediate/application_shares.csv', header=[0,1], index_col=[0,1])

# Preview data
df_application_shares
# Out:
#                           Metervraag aardgas                                 \
#                                        koken warm tapwater ruimteverwarming
# geo_id bag_vbo_id
# GM0277 '0277010000000003'           5.966168      2.556929        30.847703
#        '0277010000000004'           5.966168      2.556929        25.608763
#        '0277010000000005'           6.272357      2.688153        36.376929
#        '0277010000000006'           5.966168      2.556929        17.995931
#        '0277010000000007'           5.966168      2.556929        29.097010
# ...                                      ...           ...              ...
# GM0096 '0096010000387944'           0.000000      0.000000         0.000000
#        '0096010000387945'           0.000000      0.000000         0.000000
#        '0096010011086854'           4.429159      1.898211        11.430229
#        '0096010011086855'           4.905105      2.102188         6.404114
#        '0096010011095362'           5.531748      2.370749        18.458531
#
#                           Metervraag elektriciteit                \
#                                              koken warm tapwater
# geo_id bag_vbo_id
# GM0277 '0277010000000003'                 0.000000      0.000000
#        '0277010000000004'                 0.000000      0.000000
#        '0277010000000005'                 0.000000      0.000000
#        '0277010000000006'                 0.000000      0.000000
#        '0277010000000007'                 0.000000      0.000000
# ...                                            ...           ...
# GM0096 '0096010000387944'                 2.395992      0.266221
#        '0096010000387945'                 2.369769      0.263308
#        '0096010011086854'                 0.000000      0.000000
#        '0096010011086855'                 0.000000      0.000000
#        '0096010011095362'                 0.000000      0.000000
#
#                                                      Metervraag warmtenet  \
#                           ruimteverwarming hulpvraag        warm tapwater
# geo_id bag_vbo_id
# GM0277 '0277010000000003'         0.000000       0.0                  0.0
#        '0277010000000004'         0.000000       0.0                  0.0
#        '0277010000000005'         0.000000       0.0                  0.0
#        '0277010000000006'         0.000000       0.0                  0.0
#        '0277010000000007'         0.000000       0.0                  0.0
# ...                                    ...       ...                  ...
# GM0096 '0096010000387944'         1.757563       0.0                  0.0
#        '0096010000387945'         2.024532       0.0                  0.0
#        '0096010011086854'         0.000000       0.0                  0.0
#        '0096010011086855'         0.000000       0.0                  0.0
#        '0096010011095362'         0.000000       0.0                  0.0
#
#                                            Metervraag waterstof  ...  \
#                           ruimteverwarming        warm tapwater  ...
# geo_id bag_vbo_id                                                ...
# GM0277 '0277010000000003'              0.0                  0.0  ...
#        '0277010000000004'              0.0                  0.0  ...
#        '0277010000000005'              0.0                  0.0  ...
#        '0277010000000006'              0.0                  0.0  ...
#        '0277010000000007'              0.0                  0.0  ...
# ...                                    ...                  ...  ...
# GM0096 '0096010000387944'              0.0                  0.0  ...
#        '0096010000387945'              0.0                  0.0  ...
#        '0096010011086854'              0.0                  0.0  ...
#        '0096010011086855'              0.0                  0.0  ...
#        '0096010011095362'              0.0                  0.0  ...
#
#                           Metervraag biomassa                   \
#                                 warm tapwater ruimteverwarming
# geo_id bag_vbo_id
# GM0277 '0277010000000003'                 0.0              0.0
#        '0277010000000004'                 0.0              0.0
#        '0277010000000005'                 0.0              0.0
#        '0277010000000006'                 0.0              0.0
#        '0277010000000007'                 0.0              0.0
# ...                                       ...              ...
# GM0096 '0096010000387944'                 0.0              0.0
#        '0096010000387945'                 0.0              0.0
#        '0096010011086854'                 0.0              0.0
#        '0096010011086855'                 0.0              0.0
#        '0096010011095362'                 0.0              0.0
#
#                            Metervraag olie Metervraag totaal                \
#                           ruimteverwarming           aardgas elektriciteit
# geo_id bag_vbo_id
# GM0277 '0277010000000003'              0.0          0.430285           0.0
#        '0277010000000004'              0.0          0.366720           0.0
#        '0277010000000005'              0.0          0.497373           0.0
#        '0277010000000006'              0.0          0.274351           0.0
#        '0277010000000007'              0.0          0.409044           0.0
# ...                                    ...               ...           ...
# GM0096 '0096010000387944'              0.0          6.593966           0.0
#        '0096010000387945'              0.0          7.111171           0.0
#        '0096010011086854'              0.0          0.166687           0.0
#        '0096010011086855'              0.0          0.105703           0.0
#        '0096010011095362'              0.0          0.279964           0.0
#
#
#                           warmtenet waterstof biomassa        olie    totaal
# geo_id bag_vbo_id
# GM0277 '0277010000000003'       0.0       0.0      0.0  112.931290  1.047610
#        '0277010000000004'       0.0       0.0      0.0   95.404591  1.047606
#        '0277010000000005'       0.0       0.0      0.0  132.176085  1.047610
#        '0277010000000006'       0.0       0.0      0.0   69.936118  1.047606
#        '0277010000000007'       0.0       0.0      0.0  107.074405  1.047608
# ...                             ...       ...      ...         ...       ...
# GM0096 '0096010000387944'       0.0       0.0      0.0    6.593966  1.045969
#        '0096010000387945'       0.0       0.0      0.0    7.111171  1.045969
#        '0096010011086854'       0.0       0.0      0.0   45.438031  1.047567
#        '0096010011086855'       0.0       0.0      0.0   29.356276  1.047567
#        '0096010011095362'       0.0       0.0      0.0   70.711041  1.046903
#
# [5909 rows x 21 columns]

# %%
# Import parent data
path = Path("data", "intermediate", f"parent_data.csv")
df_parent = pd.read_csv(path, index_col=0)

# Preview data
df_parent
# Out:
#     agriculture_final_demand_electricity_demand  \
# nl                                    41584.615
#
#     agriculture_final_demand_network_gas_demand  \
# nl                                    91072.918
#
#     agriculture_final_demand_steam_hot_water_demand  \
# nl                                         2783.107
#
#     agriculture_final_demand_wood_pellets_demand  \
# nl                                      5437.224
#
#     input_agriculture_final_demand_crude_oil_demand  \
# nl                                        17965.442
#
#     agriculture_final_demand_hydrogen_demand  \
# nl                                       0.0
#
#     input_percentage_of_diesel_agriculture_final_demand_crude_oil  \
# nl                                           0.857883
#
#     input_percentage_of_biodiesel_agriculture_final_demand_crude_oil  \
# nl                                           0.065969
#
#     input_percentage_of_kerosene_agriculture_final_demand_crude_oil  \
# nl                                                0.0
#
#     input_percentage_of_bio_kerosene_agriculture_final_demand_crude_oil  ...  \
# nl                                                0.0                    ...
#
#     input_transport_ship_biodiesel_demand  \
# nl                                117.581
#
#     transport_final_demand_for_shipping_lng_demand  \
# nl                                             0.0
#
#     transport_final_demand_for_shipping_bio_lng_demand  \
# nl                                                0.0
#
#     input_transport_ship_bio_ethanol_demand  \
# nl                                      0.0
#
#     transport_final_demand_heavy_fuel_oil_demand  \
# nl                                       295.218
#
#     input_transport_ship_electricity_demand  \
# nl                                      0.0
#
#     bunkers_total_useful_demand_ships_demand            area  base_dataset  \
# nl                                478316.636  NL_netherlands            eu
#
#       group
# nl  country
#
# [1 rows x 619 columns]

# %% [markdown]
# #### Checks
#
# Perform checks on accuracy, relevancy, completeness, timeliness and consistency.
#
# **TO DO** | Add checks

# %% [markdown]
# ##### Accuracy checks

# %%
# TODO

# %% [markdown]
# ##### Relevancy checks

# %%
# TODO

# %% [markdown]
# ##### Completeness checks

# %% [markdown]
# Does the data have missing values or miss records?

# %%
# TODO
# checker.has_missing_values(values)

# %% [markdown]
# Are there any NaN values?

# %%
# TODO

# %% [markdown]
# Do all keys occur in the dataset?

# %%
# TODO

# %% [markdown]
# ##### Timeliness checks

# %%
# TODO

# %% [markdown]
# ##### Consistency checks

# %% [markdown]
# Are the data types per column as expected? Are there any columns with non-numerical values? Check for columns with datatype "object". Are these as expected?

# %%
# Check if the parent data has any columns with unexpected non-numerical values
checker.get_non_numeric_columns(df_parent)
# Out:
# Index(['area', 'base_dataset', 'group'], dtype='object')

# %%
# Perform the same check for the Klimaatmonitor source data
checker.get_non_numeric_columns(df_km_source_data)
# Out:
# Index(['Gebieden', 'warmwontier2_2019'], dtype='object')

# %%
# The 'warmwontier2_2019' variable was expected to have only float values.
# Let's dive deeper into this column:
for key, value in df_km_source_data['warmwontier2_2019'].items():
    try:
        float_value = float(value)
    except ValueError:
        print(f"Non float value for {key}: {value}")
# Out:
# Non float value for GM2000: -

# %%
# Let's first check out the entire data row for this municipality
df_km_source_data.loc['GM2000', :]
# Out:
# Gebieden                                   Gemeente onbekend
# inwoners_2019                                            NaN
# woningen_2019                                            NaN
# zonpvtj_won_2019                                         4.0
# houtwontj_2019                                           NaN
# houtskool_2019                                           NaN
# warmwontier2_2019                                          -
# gaswoningen_2019                                         NaN
# el_woningen_tj_incl_zonachtermeter_2019                  1.0
# Name: GM2000, dtype: object

# %%
# GM2000 doesn't seem to be a relevant (and maybe not even existing) municipality.
# Hence, let's remove the entire row from our source data.
df_km_source_data = df_km_source_data.drop('GM2000')

# Check if the data for GM2000 has indeed been removed
df_km_source_data.tail()
# Out:
#                Gebieden  inwoners_2019  woningen_2019  zonpvtj_won_2019  \
# Code
# GM0879          Zundert        21612.0         9455.0              15.0
# GM0301          Zutphen        47609.0        22095.0              22.0
# GM1896  Zwartewaterland        22503.0         8903.0              12.0
# GM0642      Zwijndrecht        44639.0        20454.0              13.0
# GM0193           Zwolle       127497.0        57730.0              88.0
#
#         houtwontj_2019  houtskool_2019 warmwontier2_2019  gaswoningen_2019  \
# Code
# GM0879            49.0             0.0               0.0              14.0
# GM0301            45.0             1.0               0.0              24.5
# GM1896            36.0             0.0               0.0              11.6
# GM0642            29.0             1.0            2000.0              21.5
# GM0193            33.0             2.0           55000.0              58.2
#
#         el_woningen_tj_incl_zonachtermeter_2019
# Code
# GM0879                                    117.0
# GM0301                                    197.0
# GM1896                                     95.0
# GM0642                                    194.0
# GM0193                                    531.0

# %%
# Lastly, check if the application shares data has any columns with unexpected non-numerical values
checker.get_non_numeric_columns(df_application_shares)
# Out:
# MultiIndex([], )

# %% [markdown]
# Are there any negative values or shares?

# %%
# TODO

# %% [markdown]
# #### Load
#
# After all checks and preprocessing steps, make sure to save your data again to the `data / intermediate` directory.

# %%
# Klimaatmonitor source data
df_km_source_data.to_csv(f"data/intermediate/klimaatmonitor_source_data_{year}.csv")

# %%
# Klimaatmonitor meta data
df_km_meta_data.to_csv(f"data/intermediate/klimaatmonitor_meta_data_{year}.csv")

# %%
# Application shares data
df_application_shares.to_csv("data/intermediate/application_shares.csv")

# %%
# Parent data
df_parent.to_csv("data/intermediate/parent_data.csv")

# %% [markdown]
# ### 3. Data transformation

# %% [markdown]
# In the data transformation step, we bring our data together into one final analysis dataset or database.
# The data transformation phase usually involves 4 steps:
#
# * **Edit data** — filter, and select the relevant data
# * **Aggregate data** — aggregate the data into the necessary level
# * **Combine data** — combine all data sources into a single table
# * **Extend data** — create new variables based on existing data

# %% [markdown]
# #### Setup
#
# Setup the transformer and load all intermediate data files for the next step in the pipeline.

# %% [markdown]
# First, setup the transformer class:

# %%
# Initialise transformer class to access transformation functions
transformer = Transformer(municipalities, year)

# %% [markdown]
# Then, setup all data files:
# - dataframe representing data.csv
# - commits.yml
# - dataframe with all etlocal interface elements
# - mapping to map Klimaatmonitor keys to ETLocal keys
# - Klimaatmonitor data and meta data
# - parent data

# %% [markdown]
# ##### Setup ETLocal templates

# %%
# TODO: Describe that by running this cell an empty template is created. This overwrites the filled template.

# Load ETLocal template with target keys from config
path = Path("config", "etlocal_interface_elements.csv")
empty_template = pd.read_csv(path, header=[0], sep=sep)#, index_col=[2])

# Add columns geo_id, value and commit to the template    
for column in ['geo_id', 'value', 'commit']:
    empty_template[column] = float('nan')
    
# Fill the geo_id column with all relevant municipal geo IDs
templates = []
for municipality in municipalities:
    template_to_add = empty_template.copy()
    template_to_add['geo_id'] = municipality
    templates.append(template_to_add)
    
# Concatenate list of templates to one big template with all municipalities
template = pd.concat(templates)

# Transform the templates into a multi-index dataframe
index = pd.MultiIndex.from_frame(template[['geo_id', 'group', 'subgroup', 'key']])
template = template.drop(columns=['geo_id', 'group', 'subgroup', 'key'])
template.index = index

# Preview merged template
template
# Out:
#                                                                                                 unit  \
# geo_id  group      subgroup                key
# GM1680  area       area_emission_factors   file_carriers_imported_heat_lt_co2_conversion_p...  kg/MJ
#                                            file_carriers_imported_heat_mt_co2_conversion_p...  kg/MJ
#                                            file_carriers_imported_heat_ht_co2_conversion_p...  kg/MJ
#         households households_applications households_final_demand_electricity_households_...      %
#                                            households_final_demand_electricity_households_...      %
# ...                                                                                              ...
# DKGM751 energy     energy_heat_production  energy_import_mt_heat_demand                           TJ
#                                            energy_import_lt_heat_demand                           TJ
#                    energy_energy_demand    energy_heat_distribution_ht_loss_share                  %
#                                            energy_heat_distribution_mt_loss_share                  %
#                                            energy_heat_distribution_lt_loss_share                  %
#
#                                                                                                value  \
# geo_id  group      subgroup                key
# GM1680  area       area_emission_factors   file_carriers_imported_heat_lt_co2_conversion_p...    NaN
#                                            file_carriers_imported_heat_mt_co2_conversion_p...    NaN
#                                            file_carriers_imported_heat_ht_co2_conversion_p...    NaN
#         households households_applications households_final_demand_electricity_households_...    NaN
#                                            households_final_demand_electricity_households_...    NaN
# ...                                                                                              ...
# DKGM751 energy     energy_heat_production  energy_import_mt_heat_demand                          NaN
#                                            energy_import_lt_heat_demand                          NaN
#                    energy_energy_demand    energy_heat_distribution_ht_loss_share                NaN
#                                            energy_heat_distribution_mt_loss_share                NaN
#                                            energy_heat_distribution_lt_loss_share                NaN
#
#                                                                                                commit
# geo_id  group      subgroup                key
# GM1680  area       area_emission_factors   file_carriers_imported_heat_lt_co2_conversion_p...     NaN
#                                            file_carriers_imported_heat_mt_co2_conversion_p...     NaN
#                                            file_carriers_imported_heat_ht_co2_conversion_p...     NaN
#         households households_applications households_final_demand_electricity_households_...     NaN
#                                            households_final_demand_electricity_households_...     NaN
# ...                                                                                               ...
# DKGM751 energy     energy_heat_production  energy_import_mt_heat_demand                           NaN
#                                            energy_import_lt_heat_demand                           NaN
#                    energy_energy_demand    energy_heat_distribution_ht_loss_share                 NaN
#                                            energy_heat_distribution_mt_loss_share                 NaN
#                                            energy_heat_distribution_lt_loss_share                 NaN
#
# [844184 rows x 3 columns]

# %%
# TODO: Also make it possible to load the filled template with all municipal values

# %% [markdown]
# ##### Setup Klimaatmonitor mapping files

# %%
# Use mapping from CSV and make sure that it works (TODO!)
path = Path("config", "klimaatmonitor_to_etlocal_mapping.csv")
df_etlocal_to_km = pd.read_csv(str(path))

# %%
# Load intermediate Klimaatmonitor data
df_km_source_data = pd.read_csv(f'data/intermediate/klimaatmonitor_source_data_{year}.csv', index_col=[0])
df_km_meta_data = pd.read_csv(f'data/intermediate/klimaatmonitor_meta_data_{year}.csv', index_col=[0])

# %% [markdown]
# ##### Setup parent data

# %%
# Import parent data
path = Path("data", "intermediate", "parent_data.csv")
df_parent = pd.read_csv(path, index_col=0)

# Preview parent data
df_parent.T.head()
# Out:
#                                                         nl
# agriculture_final_demand_electricity_demand      41584.615
# agriculture_final_demand_network_gas_demand      91072.918
# agriculture_final_demand_steam_hot_water_demand   2783.107
# agriculture_final_demand_wood_pellets_demand      5437.224
# input_agriculture_final_demand_crude_oil_demand  17965.442

# %% [markdown]
# ##### What is your goal?

# %% [markdown]
# At this point, the empty template is ready to fill for all specified datasets and all relevant (config) files have been setup for use. Based on your goal, decide where to continue in the pipeline. If your aim is to fill it with all data, continue running the cells below. If you aim to fill it with specific data, search for the relevant chapter to continue.

# %% [markdown]
# #### Energy demand
# Transform the energy demand data from Klimaatmonitor to the right format.

# %% [markdown]
# ##### List ETLocal keys

# %% [markdown]
# Preview the ETLocal keys that are relevant for the households energy demand category

# %%
# Filter the ETLocal keys that are relevant for the households energy demand category
filter_households_demand = (slice(None), 'households', 'households_energy_demand')

# Preview the filtered template
template.loc[filter_households_demand, :]
# Out:
#                                                                                               unit  \
# geo_id group      subgroup                 key
# GM1896 households households_energy_demand households_final_demand_electricity_demand           TJ
#                                            households_final_demand_network_gas_demand           TJ
#                                            households_final_demand_steam_hot_water_demand       TJ
#                                            households_final_demand_wood_pellets_demand          TJ
#                                            households_final_demand_coal_demand                  TJ
#                                            input_households_final_demand_crude_oil_demand       TJ
#                                            households_final_demand_solar_thermal_demand         TJ
#                                            input_percentage_of_lt_steam_hot_water_househol...    %
#                                            input_percentage_of_mt_steam_hot_water_househol...    %
#                                            input_percentage_of_ht_steam_hot_water_househol...    %
#                                            input_percentage_of_diesel_households_final_dem...    %
#                                            input_percentage_of_biodiesel_households_final_...    %
#                                            input_percentage_of_kerosene_households_final_d...    %
#                                            input_percentage_of_bio_kerosene_households_fin...    %
#                                            input_percentage_of_lpg_households_final_demand...    %
#                                            input_percentage_of_bio_oil_households_final_de...    %
#                                            input_percentage_of_crude_oil_households_final_...    %
#                                            households_final_demand_electricity_demand           TJ
#                                            households_final_demand_network_gas_demand           TJ
#                                            households_final_demand_steam_hot_water_demand       TJ
#                                            households_final_demand_wood_pellets_demand          TJ
#                                            households_final_demand_coal_demand                  TJ
#                                            input_households_final_demand_crude_oil_demand       TJ
#                                            households_final_demand_solar_thermal_demand         TJ
#                                            input_percentage_of_diesel_households_final_dem...    %
#                                            input_percentage_of_biodiesel_households_final_...    %
#                                            input_percentage_of_kerosene_households_final_d...    %
#                                            input_percentage_of_bio_kerosene_households_fin...    %
#                                            input_percentage_of_lpg_households_final_demand...    %
#                                            input_percentage_of_bio_oil_households_final_de...    %
#                                            input_percentage_of_crude_oil_households_final_...    %
#
#                                                                                                value  \
# geo_id group      subgroup                 key
# GM1896 households households_energy_demand households_final_demand_electricity_demand            NaN
#                                            households_final_demand_network_gas_demand            NaN
#                                            households_final_demand_steam_hot_water_demand        NaN
#                                            households_final_demand_wood_pellets_demand           NaN
#                                            households_final_demand_coal_demand                   NaN
#                                            input_households_final_demand_crude_oil_demand        NaN
#                                            households_final_demand_solar_thermal_demand          NaN
#                                            input_percentage_of_lt_steam_hot_water_househol...    NaN
#                                            input_percentage_of_mt_steam_hot_water_househol...    NaN
#                                            input_percentage_of_ht_steam_hot_water_househol...    NaN
#                                            input_percentage_of_diesel_households_final_dem...    NaN
#                                            input_percentage_of_biodiesel_households_final_...    NaN
#                                            input_percentage_of_kerosene_households_final_d...    NaN
#                                            input_percentage_of_bio_kerosene_households_fin...    NaN
#                                            input_percentage_of_lpg_households_final_demand...    NaN
#                                            input_percentage_of_bio_oil_households_final_de...    NaN
#                                            input_percentage_of_crude_oil_households_final_...    NaN
#                                            households_final_demand_electricity_demand            NaN
#                                            households_final_demand_network_gas_demand            NaN
#                                            households_final_demand_steam_hot_water_demand        NaN
#                                            households_final_demand_wood_pellets_demand           NaN
#                                            households_final_demand_coal_demand                   NaN
#                                            input_households_final_demand_crude_oil_demand        NaN
#                                            households_final_demand_solar_thermal_demand          NaN
#                                            input_percentage_of_diesel_households_final_dem...    NaN
#                                            input_percentage_of_biodiesel_households_final_...    NaN
#                                            input_percentage_of_kerosene_households_final_d...    NaN
#                                            input_percentage_of_bio_kerosene_households_fin...    NaN
#                                            input_percentage_of_lpg_households_final_demand...    NaN
#                                            input_percentage_of_bio_oil_households_final_de...    NaN
#                                            input_percentage_of_crude_oil_households_final_...    NaN
#
#                                                                                               commit
# geo_id group      subgroup                 key
# GM1896 households households_energy_demand households_final_demand_electricity_demand            NaN
#                                            households_final_demand_network_gas_demand            NaN
#                                            households_final_demand_steam_hot_water_demand        NaN
#                                            households_final_demand_wood_pellets_demand           NaN
#                                            households_final_demand_coal_demand                   NaN
#                                            input_households_final_demand_crude_oil_demand        NaN
#                                            households_final_demand_solar_thermal_demand          NaN
#                                            input_percentage_of_lt_steam_hot_water_househol...    NaN
#                                            input_percentage_of_mt_steam_hot_water_househol...    NaN
#                                            input_percentage_of_ht_steam_hot_water_househol...    NaN
#                                            input_percentage_of_diesel_households_final_dem...    NaN
#                                            input_percentage_of_biodiesel_households_final_...    NaN
#                                            input_percentage_of_kerosene_households_final_d...    NaN
#                                            input_percentage_of_bio_kerosene_households_fin...    NaN
#                                            input_percentage_of_lpg_households_final_demand...    NaN
#                                            input_percentage_of_bio_oil_households_final_de...    NaN
#                                            input_percentage_of_crude_oil_households_final_...    NaN
#                                            households_final_demand_electricity_demand            NaN
#                                            households_final_demand_network_gas_demand            NaN
#                                            households_final_demand_steam_hot_water_demand        NaN
#                                            households_final_demand_wood_pellets_demand           NaN
#                                            households_final_demand_coal_demand                   NaN
#                                            input_households_final_demand_crude_oil_demand        NaN
#                                            households_final_demand_solar_thermal_demand          NaN
#                                            input_percentage_of_diesel_households_final_dem...    NaN
#                                            input_percentage_of_biodiesel_households_final_...    NaN
#                                            input_percentage_of_kerosene_households_final_d...    NaN
#                                            input_percentage_of_bio_kerosene_households_fin...    NaN
#                                            input_percentage_of_lpg_households_final_demand...    NaN
#                                            input_percentage_of_bio_oil_households_final_de...    NaN
#                                            input_percentage_of_crude_oil_households_final_...    NaN

# %%
# List all ETLocal keys that are relevant for the households energy demand category
keys_households_demand = list(template.loc[filter_households_demand, :].index.get_level_values(3).unique())

# Preview list
keys_households_demand
# Out:
# ['households_final_demand_electricity_demand',
#  'households_final_demand_network_gas_demand',
#  'households_final_demand_steam_hot_water_demand',
#  'households_final_demand_wood_pellets_demand',
#  'households_final_demand_coal_demand',
#  'input_households_final_demand_crude_oil_demand',
#  'households_final_demand_solar_thermal_demand',
#  'input_percentage_of_lt_steam_hot_water_households_final_demand_steam_hot_water',
#  'input_percentage_of_mt_steam_hot_water_households_final_demand_steam_hot_water',
#  'input_percentage_of_ht_steam_hot_water_households_final_demand_steam_hot_water',
#  'input_percentage_of_diesel_households_final_demand_crude_oil',
#  'input_percentage_of_biodiesel_households_final_demand_crude_oil',
#  'input_percentage_of_kerosene_households_final_demand_crude_oil',
#  'input_percentage_of_bio_kerosene_households_final_demand_crude_oil',
#  'input_percentage_of_lpg_households_final_demand_crude_oil',
#  'input_percentage_of_bio_oil_households_final_demand_crude_oil',
#  'input_percentage_of_crude_oil_households_final_demand_crude_oil']

# %% [markdown]
# ##### List Klimaatmonitor keys

# %% [markdown]
# List the Klimaatmonitor keys that are relevant for filling our ETLocal template for the energy demand in households.

# %%
km_keys_household_demand = []

for key in keys_households_demand:
    if df_etlocal_to_km["interface_elements"].isin([key]).any():
        km_keys = df_etlocal_to_km.loc[df_etlocal_to_km["interface_elements"] == key, "klimaatmonitor_keys"].values[0]
        km_key = km_keys.split(',')
        
        km_keys_household_demand += km_key

# %%
# Preview
km_keys_household_demand
# Out:
# ['el_woningen_tj_incl_zonachtermeter',
#  'gaswoningen',
#  'warmwontier2',
#  'houtskool',
#  'houtwontj']

# %% [markdown]
# ##### Extract relevant data from Klimaatmonitor

# %% [markdown]
# For each key that is relevant for section energy demand in households

# %%
# Transform Klimaatmonitor data to the right format and fill the data frame
input_data_households_demand = transformer.filter_km_data(km_keys_household_demand, df_km_source_data, df_km_meta_data)

# Preview
input_data_households_demand.head(len(km_keys_household_demand))
# Out:
#      code                                 key  value        unit  \
# 0  GM0277  el_woningen_tj_incl_zonachtermeter   10.0          TJ
# 1  GM0277                         gaswoningen    1.4  miljoen m3
# 2  GM0277                        warmwontier2    0.0          GJ
# 3  GM0277                           houtskool    0.0          TJ
# 4  GM0277                           houtwontj    4.0          TJ
#
#                                                topic
# 0  Totaal elektriciteitsverbruik woningen (incl. ...
# 1                    Totaal aardgasverbruik woningen
# 2          Verbruik stadswarmte woningen (schatting)
# 3                             Houtskool hern. warmte
# 4                  Houtkachels woningen hern. warmte

# %% [markdown]
# ##### Transform source units to target units

# %% [markdown]
# Some values are specified in GJ. We need to convert this to TJ.

# %%
# Transform all GJ rows to TJ rows

source_unit = "GJ"
target_unit = "TJ"

source_to_target = f"{source_unit.lower()}_to_{target_unit.lower()}"
source_to_target_conversion = transformer.constants[source_to_target]

input_data_households_demand.loc[input_data_households_demand["unit"] == source_unit, "value"] *= source_to_target_conversion
input_data_households_demand.loc[input_data_households_demand["unit"] == source_unit, "unit"] = target_unit

# %% [markdown]
# The gas demand values are specified in mln m3. We need to convert this to TJ by using the lower heating value (LHV).

# %%
# Transform all miljoen m3 rows to TJ rows

source_unit = "miljoen m3"
target_unit = "TJ"
source_to_target = "m3_to_mj" # miljoen m3 to TJ is the same as m3 to mj

source_to_target_conversion = transformer.constants[source_to_target]

input_data_households_demand.loc[input_data_households_demand["unit"] == source_unit, "value"] *= source_to_target_conversion
input_data_households_demand.loc[input_data_households_demand["unit"] == source_unit, "unit"] = target_unit

# %%
# Preview
input_data_households_demand.head(len(km_keys_household_demand))
# Out:
#      code                                 key   value unit  \
# 0  GM0277  el_woningen_tj_incl_zonachtermeter  10.000   TJ
# 1  GM0277                         gaswoningen  49.238   TJ
# 2  GM0277                        warmwontier2   0.000   TJ
# 3  GM0277                           houtskool   0.000   TJ
# 4  GM0277                           houtwontj   4.000   TJ
#
#                                                topic
# 0  Totaal elektriciteitsverbruik woningen (incl. ...
# 1                    Totaal aardgasverbruik woningen
# 2          Verbruik stadswarmte woningen (schatting)
# 3                             Houtskool hern. warmte
# 4                  Houtkachels woningen hern. warmte

# %% [markdown]
# ##### Load Klimaatmonitor data in ETLocal template

# %% [markdown]
# For all municipalities, fill the ETLocal template with the relevant Klimaatmonitor data

# %%
# Load relevant Klimaatmonitor data into template
template = transformer.load_km_data(input_data_households_demand, df_etlocal_to_km, template, keys_households_demand)

# %%
# Preview template (filtered for the households energy demand keys)
template.loc[filter_households_demand, :]
# Out:
#                                                                                                unit  \
# geo_id  group      subgroup                 key
# GM1680  households households_energy_demand households_final_demand_electricity_demand           TJ
#                                             households_final_demand_network_gas_demand           TJ
#                                             households_final_demand_steam_hot_water_demand       TJ
#                                             households_final_demand_wood_pellets_demand          TJ
#                                             households_final_demand_coal_demand                  TJ
# ...                                                                                             ...
# DKGM751 households households_energy_demand input_percentage_of_kerosene_households_final_d...    %
#                                             input_percentage_of_bio_kerosene_households_fin...    %
#                                             input_percentage_of_lpg_households_final_demand...    %
#                                             input_percentage_of_bio_oil_households_final_de...    %
#                                             input_percentage_of_crude_oil_households_final_...    %
#
#                                                                                                 value  \
# geo_id  group      subgroup                 key
# GM1680  households households_energy_demand households_final_demand_electricity_demand            NaN
#                                             households_final_demand_network_gas_demand            NaN
#                                             households_final_demand_steam_hot_water_demand        NaN
#                                             households_final_demand_wood_pellets_demand           NaN
#                                             households_final_demand_coal_demand                   NaN
# ...                                                                                               ...
# DKGM751 households households_energy_demand input_percentage_of_kerosene_households_final_d...    NaN
#                                             input_percentage_of_bio_kerosene_households_fin...    NaN
#                                             input_percentage_of_lpg_households_final_demand...    NaN
#                                             input_percentage_of_bio_oil_households_final_de...    NaN
#                                             input_percentage_of_crude_oil_households_final_...    NaN
#
#                                                                                                commit
# geo_id  group      subgroup                 key
# GM1680  households households_energy_demand households_final_demand_electricity_demand            NaN
#                                             households_final_demand_network_gas_demand            NaN
#                                             households_final_demand_steam_hot_water_demand        NaN
#                                             households_final_demand_wood_pellets_demand           NaN
#                                             households_final_demand_coal_demand                   NaN
# ...                                                                                               ...
# DKGM751 households households_energy_demand input_percentage_of_kerosene_households_final_d...    NaN
#                                             input_percentage_of_bio_kerosene_households_fin...    NaN
#                                             input_percentage_of_lpg_households_final_demand...    NaN
#                                             input_percentage_of_bio_oil_households_final_de...    NaN
#                                             input_percentage_of_crude_oil_households_final_...    NaN
#
# [123442 rows x 3 columns]

# %% [markdown]
# ##### Fill missing data and create fallback values

# %% [markdown]
# Now, create fallback values for the keys for which no data is available on Klimaatmonitor.

# %% [markdown]
# **Oil mix** | There is no public data available about the oil mix in households. Hence, we assume that all oil is crude oil.

# %%
# TODO: retrieve share_groups from ETLocal in df_etlocal, possibly including the flexible share and automatically set fallback

# Define interface element for which the fallback value should be created
interface_element = 'input_percentage_of_crude_oil_households_final_demand_crude_oil'

# Set fallback value to 1.0 and update corresponding commit message
template.loc[(slice(None), slice(None), slice(None), interface_element), 'value'] = 1.0
template.loc[(slice(None), slice(None), slice(None), interface_element), 'commit'] = "No data available on Klimaatmonitor. Fallback value set to 1.0 to ensure share totals sum to 1.0."

# %% [markdown]
# **Temperature levels of district heating networks** | Klimaatmonitor doesn't provide any data about the demand of district heating networks per temperature level. Hence, we assume that all residential district heating networks require MT heat.

# %%
# TODO: we could also use the parent data shares instead?
for temperature_level in ['lt', 'mt', 'ht']:
    key = f'input_percentage_of_{temperature_level}_steam_hot_water_households_final_demand_steam_hot_water'
    
    val = 0.
    
    if temperature_level == 'ht':
        val = 1.
    
    # Update value and corresponding commit message for the temperature level share
    template.loc[(slice(None), slice(None), slice(None), key), 'value'] = val
    template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"No data available. Fallback value set to {val} to ensure share totals sum to 1."

# %% [markdown]
# For all ETLocal keys (or interface elements) that still have a Nan value, we assume there is no relevant data available on Klimaatmonitor. Hence, we set these values to zero.

# %%
# Set NaN values to zero
template.loc[filter_households_demand, 'value'] = template.loc[filter_households_demand, 'value'].fillna(0)

# Add corresponding commit message
template.loc[filter_households_demand, 'commit'] = template.loc[filter_households_demand, 'commit'].fillna("No data available on Klimaatmonitor. Set to 0.0.")
# Out:
#                                                                                               unit  \
# geo_id group      subgroup                 key
# GM0277 households households_energy_demand households_final_demand_electricity_demand           TJ
#                                            households_final_demand_network_gas_demand           TJ
#                                            households_final_demand_steam_hot_water_demand       TJ
#                                            households_final_demand_wood_pellets_demand          TJ
#                                            households_final_demand_coal_demand                  TJ
# ...                                                                                            ...
# GM0096 households households_energy_demand input_percentage_of_kerosene_households_final_d...    %
#                                            input_percentage_of_bio_kerosene_households_fin...    %
#                                            input_percentage_of_lpg_households_final_demand...    %
#                                            input_percentage_of_bio_oil_households_final_de...    %
#                                            input_percentage_of_crude_oil_households_final_...    %
#
#                                                                                                 value  \
# geo_id group      subgroup                 key
# GM0277 households households_energy_demand households_final_demand_electricity_demand          10.000
#                                            households_final_demand_network_gas_demand          49.238
#                                            households_final_demand_steam_hot_water_demand       0.000
#                                            households_final_demand_wood_pellets_demand          4.000
#                                            households_final_demand_coal_demand                  0.000
# ...                                                                                               ...
# GM0096 households households_energy_demand input_percentage_of_kerosene_households_final_d...   0.000
#                                            input_percentage_of_bio_kerosene_households_fin...   0.000
#                                            input_percentage_of_lpg_households_final_demand...   0.000
#                                            input_percentage_of_bio_oil_households_final_de...   0.000
#                                            input_percentage_of_crude_oil_households_final_...   0.000
#
#                                                                                                                                           commit
# geo_id group      subgroup                 key
# GM0277 households households_energy_demand households_final_demand_electricity_demand          Klimaatmonitor. Topic: Totaal elektriciteitsve...
#                                            households_final_demand_network_gas_demand          Klimaatmonitor. Topic: Totaal aardgasverbruik ...
#                                            households_final_demand_steam_hot_water_demand      Klimaatmonitor. Topic: Verbruik stadswarmte wo...
#                                            households_final_demand_wood_pellets_demand         Klimaatmonitor. Topic: Houtskool hern. warmte,...
#                                            households_final_demand_coal_demand                  No data available on Klimaatmonitor. Set to 0.0.
# ...                                                                                                                                          ...
# GM0096 households households_energy_demand input_percentage_of_kerosene_households_final_d...   No data available on Klimaatmonitor. Set to 0.0.
#                                            input_percentage_of_bio_kerosene_households_fin...   No data available on Klimaatmonitor. Set to 0.0.
#                                            input_percentage_of_lpg_households_final_demand...   No data available on Klimaatmonitor. Set to 0.0.
#                                            input_percentage_of_bio_oil_households_final_de...   No data available on Klimaatmonitor. Set to 0.0.
#                                            input_percentage_of_crude_oil_households_final_...   No data available on Klimaatmonitor. Set to 0.0.
#
# [140 rows x 3 columns]

# %%
# Preview filtered template
template.loc[filter_households_demand, :]
# Out:
#                                                                                               unit  \
# geo_id group      subgroup                 key
# GM1896 households households_energy_demand households_final_demand_electricity_demand           TJ
#                                            households_final_demand_network_gas_demand           TJ
#                                            households_final_demand_steam_hot_water_demand       TJ
#                                            households_final_demand_wood_pellets_demand          TJ
#                                            households_final_demand_coal_demand                  TJ
#                                            input_households_final_demand_crude_oil_demand       TJ
#                                            households_final_demand_solar_thermal_demand         TJ
#                                            input_percentage_of_lt_steam_hot_water_househol...    %
#                                            input_percentage_of_mt_steam_hot_water_househol...    %
#                                            input_percentage_of_ht_steam_hot_water_househol...    %
#                                            input_percentage_of_diesel_households_final_dem...    %
#                                            input_percentage_of_biodiesel_households_final_...    %
#                                            input_percentage_of_kerosene_households_final_d...    %
#                                            input_percentage_of_bio_kerosene_households_fin...    %
#                                            input_percentage_of_lpg_households_final_demand...    %
#                                            input_percentage_of_bio_oil_households_final_de...    %
#                                            input_percentage_of_crude_oil_households_final_...    %
#                                            households_final_demand_electricity_demand           TJ
#                                            households_final_demand_network_gas_demand           TJ
#                                            households_final_demand_steam_hot_water_demand       TJ
#                                            households_final_demand_wood_pellets_demand          TJ
#                                            households_final_demand_coal_demand                  TJ
#                                            input_households_final_demand_crude_oil_demand       TJ
#                                            households_final_demand_solar_thermal_demand         TJ
#                                            input_percentage_of_diesel_households_final_dem...    %
#                                            input_percentage_of_biodiesel_households_final_...    %
#                                            input_percentage_of_kerosene_households_final_d...    %
#                                            input_percentage_of_bio_kerosene_households_fin...    %
#                                            input_percentage_of_lpg_households_final_demand...    %
#                                            input_percentage_of_bio_oil_households_final_de...    %
#                                            input_percentage_of_crude_oil_households_final_...    %
#
#                                                                                                value  \
# geo_id group      subgroup                 key
# GM1896 households households_energy_demand households_final_demand_electricity_demand            NaN
#                                            households_final_demand_network_gas_demand            NaN
#                                            households_final_demand_steam_hot_water_demand        NaN
#                                            households_final_demand_wood_pellets_demand           NaN
#                                            households_final_demand_coal_demand                   NaN
#                                            input_households_final_demand_crude_oil_demand        NaN
#                                            households_final_demand_solar_thermal_demand          NaN
#                                            input_percentage_of_lt_steam_hot_water_househol...    0.0
#                                            input_percentage_of_mt_steam_hot_water_househol...    0.0
#                                            input_percentage_of_ht_steam_hot_water_househol...    1.0
#                                            input_percentage_of_diesel_households_final_dem...    NaN
#                                            input_percentage_of_biodiesel_households_final_...    NaN
#                                            input_percentage_of_kerosene_households_final_d...    NaN
#                                            input_percentage_of_bio_kerosene_households_fin...    NaN
#                                            input_percentage_of_lpg_households_final_demand...    NaN
#                                            input_percentage_of_bio_oil_households_final_de...    NaN
#                                            input_percentage_of_crude_oil_households_final_...    NaN
#                                            households_final_demand_electricity_demand            NaN
#                                            households_final_demand_network_gas_demand            NaN
#                                            households_final_demand_steam_hot_water_demand        NaN
#                                            households_final_demand_wood_pellets_demand           NaN
#                                            households_final_demand_coal_demand                   NaN
#                                            input_households_final_demand_crude_oil_demand        NaN
#                                            households_final_demand_solar_thermal_demand          NaN
#                                            input_percentage_of_diesel_households_final_dem...    NaN
#                                            input_percentage_of_biodiesel_households_final_...    NaN
#                                            input_percentage_of_kerosene_households_final_d...    NaN
#                                            input_percentage_of_bio_kerosene_households_fin...    NaN
#                                            input_percentage_of_lpg_households_final_demand...    NaN
#                                            input_percentage_of_bio_oil_households_final_de...    NaN
#                                            input_percentage_of_crude_oil_households_final_...    NaN
#
#                                                                                                                                           commit
# geo_id group      subgroup                 key
# GM1896 households households_energy_demand households_final_demand_electricity_demand                                                        NaN
#                                            households_final_demand_network_gas_demand                                                        NaN
#                                            households_final_demand_steam_hot_water_demand                                                    NaN
#                                            households_final_demand_wood_pellets_demand                                                       NaN
#                                            households_final_demand_coal_demand                                                               NaN
#                                            input_households_final_demand_crude_oil_demand                                                    NaN
#                                            households_final_demand_solar_thermal_demand                                                      NaN
#                                            input_percentage_of_lt_steam_hot_water_househol...  No data available. Fallback value set to 0.0 t...
#                                            input_percentage_of_mt_steam_hot_water_househol...  No data available. Fallback value set to 0.0 t...
#                                            input_percentage_of_ht_steam_hot_water_househol...  No data available. Fallback value set to 1.0 t...
#                                            input_percentage_of_diesel_households_final_dem...                                                NaN
#                                            input_percentage_of_biodiesel_households_final_...                                                NaN
#                                            input_percentage_of_kerosene_households_final_d...                                                NaN
#                                            input_percentage_of_bio_kerosene_households_fin...                                                NaN
#                                            input_percentage_of_lpg_households_final_demand...                                                NaN
#                                            input_percentage_of_bio_oil_households_final_de...                                                NaN
#                                            input_percentage_of_crude_oil_households_final_...                                                NaN
#                                            households_final_demand_electricity_demand                                                        NaN
#                                            households_final_demand_network_gas_demand                                                        NaN
#                                            households_final_demand_steam_hot_water_demand                                                    NaN
#                                            households_final_demand_wood_pellets_demand                                                       NaN
#                                            households_final_demand_coal_demand                                                               NaN
#                                            input_households_final_demand_crude_oil_demand                                                    NaN
#                                            households_final_demand_solar_thermal_demand                                                      NaN
#                                            input_percentage_of_diesel_households_final_dem...                                                NaN
#                                            input_percentage_of_biodiesel_households_final_...                                                NaN
#                                            input_percentage_of_kerosene_households_final_d...                                                NaN
#                                            input_percentage_of_bio_kerosene_households_fin...                                                NaN
#                                            input_percentage_of_lpg_households_final_demand...                                                NaN
#                                            input_percentage_of_bio_oil_households_final_de...                                                NaN
#                                            input_percentage_of_crude_oil_households_final_...                                                NaN

# %% [markdown]
# #### Energy supply
# Transform the energy supply data from Klimaatmonitor to the right format.

# %% [markdown]
# ##### **SETUP** | List ETLocal and Klimaatmonitor keys

# %% [markdown]
# Preview the ETLocal keys that are relevant for the households energy supply category

# %%
# Filter the ETLocal keys that are relevant for the households energy demand category
filter_households_supply = (slice(None), 'households', 'households_energy_supply')

# Preview the filtered template
template.loc[filter_households_supply, :].head()
# Out:
#                                                                                         unit  \
# geo_id group      subgroup                 key
# GM0277 households households_energy_supply input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
#                                            input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
# GM0060 households households_energy_supply input_households_solar_pv_demand               TJ
#
#                                                                                          value  \
# geo_id group      subgroup                 key
# GM0277 households households_energy_supply input_households_solar_pv_demand                NaN
#                                            households_final_demand_solar_thermal_demand    NaN
#                                            input_households_solar_pv_demand                NaN
#                                            households_final_demand_solar_thermal_demand    NaN
# GM0060 households households_energy_supply input_households_solar_pv_demand                NaN
#
#                                                                                         commit
# geo_id group      subgroup                 key
# GM0277 households households_energy_supply input_households_solar_pv_demand                NaN
#                                            households_final_demand_solar_thermal_demand    NaN
#                                            input_households_solar_pv_demand                NaN
#                                            households_final_demand_solar_thermal_demand    NaN
# GM0060 households households_energy_supply input_households_solar_pv_demand                NaN

# %%
# List all ETLocal keys that are relevant for the households energy supply category
keys_households_supply = list(template.loc[filter_households_supply, :].index.get_level_values(3).unique())

# Preview list
keys_households_supply
# Out:
# ['input_households_solar_pv_demand',
#  'households_final_demand_solar_thermal_demand']

# %% [markdown]
# List the Klimaatmonitor keys that are relevant for filling our ETLocal template for the energy supply in households

# %%
km_keys_household_supply = []

for key in keys_households_supply:
    if df_etlocal_to_km["interface_elements"].isin([key]).any():
        km_keys = df_etlocal_to_km.loc[df_etlocal_to_km["interface_elements"] == key, "klimaatmonitor_keys"].values[0]
        km_key = km_keys.split(',')
        
        km_keys_household_supply += km_key

# %%
# Preview Klimaatmonitor keys relevant for energy supply in households
km_keys_household_supply
# Out:
# ['zonpvtj_won']

# %% [markdown]
# ##### **EDIT** | Extract data from Klimaatmonitor

# %% [markdown]
# For each key that is relevant for section energy supply in households

# %%
# Transform Klimaatmonitor data to the right format and fill the data frame
input_data_households_supply = transformer.filter_km_data(km_keys_household_supply, df_km_source_data, df_km_meta_data)

# Preview
input_data_households_supply.head(len(km_keys_household_supply))
# Out:
#      code          key  value unit  \
# 0  GM0277  zonpvtj_won    1.0   TJ
#
#                                                topic
# 0  Zonnestroom opgewekt door zonnepanelen op woni...

# %% [markdown]
# ##### **COMBINE** | Load Klimaatmonitor data in ETLocal template, fill missing data and create fallback values

# %% [markdown]
# For all municipalities, fill the ETLocal template with the relevant Klimaatmonitor data

# %%
# Load relevant Klimaatmonitor data into template
template = transformer.load_km_data(input_data_households_supply, df_etlocal_to_km, template, keys_households_supply)

# %%
# Preview template (filtered for the households energy demand keys)
template.loc[filter_households_supply, :].head()
# Out:
#                                                                                         unit  \
# geo_id group      subgroup                 key
# GM0277 households households_energy_supply input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
#                                            input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
# GM0060 households households_energy_supply input_households_solar_pv_demand               TJ
#
#                                                                                          value  \
# geo_id group      subgroup                 key
# GM0277 households households_energy_supply input_households_solar_pv_demand                1.0
#                                            households_final_demand_solar_thermal_demand    NaN
#                                            input_households_solar_pv_demand                1.0
#                                            households_final_demand_solar_thermal_demand    NaN
# GM0060 households households_energy_supply input_households_solar_pv_demand                2.0
#
#                                                                                                                                     commit
# geo_id group      subgroup                 key
# GM0277 households households_energy_supply input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand                                                NaN
#                                            input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand                                                NaN
# GM0060 households households_energy_supply input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...

# %% [markdown]
# For all ETLocal keys (or interface elements) that still have a Nan value, we assume there is no relevant data available on Klimaatmonitor. Hence, we set these values to zero.

# %%
# Set NaN values to zero
template.loc[filter_households_supply, 'value'] = template.loc[filter_households_supply, 'value'].fillna(0)

# Add corresponding commit message
template.loc[filter_households_supply, 'commit'] = template.loc[filter_households_supply, 'commit'].fillna("No data available on Klimaatmonitor. Set to 0.0.")

# Preview filtered template
template.loc[filter_households_supply, :]
# Out:
#                                                                                         unit  \
# geo_id group      subgroup                 key
# GM0277 households households_energy_supply input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
#                                            input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
# GM0060 households households_energy_supply input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
#                                            input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
# GM0088 households households_energy_supply input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
#                                            input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
# GM0093 households households_energy_supply input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
#                                            input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
# GM0096 households households_energy_supply input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
#                                            input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
#
#                                                                                          value  \
# geo_id group      subgroup                 key
# GM0277 households households_energy_supply input_households_solar_pv_demand                1.0
#                                            households_final_demand_solar_thermal_demand    0.0
#                                            input_households_solar_pv_demand                1.0
#                                            households_final_demand_solar_thermal_demand    0.0
# GM0060 households households_energy_supply input_households_solar_pv_demand                2.0
#                                            households_final_demand_solar_thermal_demand    0.0
#                                            input_households_solar_pv_demand                2.0
#                                            households_final_demand_solar_thermal_demand    0.0
# GM0088 households households_energy_supply input_households_solar_pv_demand                1.0
#                                            households_final_demand_solar_thermal_demand    0.0
#                                            input_households_solar_pv_demand                1.0
#                                            households_final_demand_solar_thermal_demand    0.0
# GM0093 households households_energy_supply input_households_solar_pv_demand                3.0
#                                            households_final_demand_solar_thermal_demand    0.0
#                                            input_households_solar_pv_demand                3.0
#                                            households_final_demand_solar_thermal_demand    0.0
# GM0096 households households_energy_supply input_households_solar_pv_demand                1.0
#                                            households_final_demand_solar_thermal_demand    0.0
#                                            input_households_solar_pv_demand                1.0
#                                            households_final_demand_solar_thermal_demand    0.0
#
#                                                                                                                                     commit
# geo_id group      subgroup                 key
# GM0277 households households_energy_supply input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand   No data available on Klimaatmonitor. Set to 0.0.
#                                            input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand   No data available on Klimaatmonitor. Set to 0.0.
# GM0060 households households_energy_supply input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand   No data available on Klimaatmonitor. Set to 0.0.
#                                            input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand   No data available on Klimaatmonitor. Set to 0.0.
# GM0088 households households_energy_supply input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand   No data available on Klimaatmonitor. Set to 0.0.
#                                            input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand   No data available on Klimaatmonitor. Set to 0.0.
# GM0093 households households_energy_supply input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand   No data available on Klimaatmonitor. Set to 0.0.
#                                            input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand   No data available on Klimaatmonitor. Set to 0.0.
# GM0096 households households_energy_supply input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand   No data available on Klimaatmonitor. Set to 0.0.
#                                            input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand   No data available on Klimaatmonitor. Set to 0.0.

# %%
# Set NaN values to zero
template.loc[filter_households_supply, 'value'] = template.loc[filter_households_supply, 'value'].fillna(0)

# Add corresponding commit message
template.loc[filter_households_supply, 'commit'] = template.loc[filter_households_supply, 'commit'].fillna("No data available on Klimaatmonitor. Set to 0.0.")

# Preview filtered template
template.loc[filter_households_supply, :].head()
# Out:
#                                                                                         unit  \
# geo_id group      subgroup                 key
# GM0277 households households_energy_supply input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
#                                            input_households_solar_pv_demand               TJ
#                                            households_final_demand_solar_thermal_demand   TJ
# GM0060 households households_energy_supply input_households_solar_pv_demand               TJ
#
#                                                                                          value  \
# geo_id group      subgroup                 key
# GM0277 households households_energy_supply input_households_solar_pv_demand                1.0
#                                            households_final_demand_solar_thermal_demand    0.0
#                                            input_households_solar_pv_demand                1.0
#                                            households_final_demand_solar_thermal_demand    0.0
# GM0060 households households_energy_supply input_households_solar_pv_demand                2.0
#
#                                                                                                                                     commit
# geo_id group      subgroup                 key
# GM0277 households households_energy_supply input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand   No data available on Klimaatmonitor. Set to 0.0.
#                                            input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...
#                                            households_final_demand_solar_thermal_demand   No data available on Klimaatmonitor. Set to 0.0.
# GM0060 households households_energy_supply input_households_solar_pv_demand              Klimaatmonitor. Topic: Zonnestroom opgewekt do...

# %% [markdown]
# #### Housing stock
# Transform the housing stock data from Klimaatmonitor to the right format.

# %% [markdown]
# ##### **SETUP** | List ETLocal keys
# Preview the ETLocal keys that are relevant for the housing stock category

# %%
# Filter the ETLocal keys that are relevant for the housing stock category
filter_housing_stock = (slice(None), 'households', 'households_housing_stock')

# Preview the filtered template
template.loc[filter_housing_stock, :].head()
# Out:
#                                                                                     unit  \
# geo_id group      subgroup                 key
# GM0277 households households_housing_stock number_of_inhabitants                       #
#                                            number_of_residences                        #
#                                            residences_roof_surface_available_for_pv  km2
#                                            input_percentage_of_apartments              %
#                                            input_percentage_of_terraced_houses         %
#
#                                                                                      value  \
# geo_id group      subgroup                 key
# GM0277 households households_housing_stock number_of_inhabitants                       NaN
#                                            number_of_residences                        NaN
#                                            residences_roof_surface_available_for_pv    NaN
#                                            input_percentage_of_apartments              NaN
#                                            input_percentage_of_terraced_houses         NaN
#
#                                                                                     commit
# geo_id group      subgroup                 key
# GM0277 households households_housing_stock number_of_inhabitants                       NaN
#                                            number_of_residences                        NaN
#                                            residences_roof_surface_available_for_pv    NaN
#                                            input_percentage_of_apartments              NaN
#                                            input_percentage_of_terraced_houses         NaN

# %%
# List all ETLocal keys that are relevant for the housing stock category
keys_housing_stock = list(template.loc[filter_housing_stock, :].index.get_level_values(3).unique())

# Preview list
keys_housing_stock
# Out:
# ['number_of_inhabitants',
#  'number_of_residences',
#  'residences_roof_surface_available_for_pv',
#  'input_percentage_of_apartments',
#  'input_percentage_of_terraced_houses',
#  'input_percentage_of_corner_houses',
#  'input_percentage_of_semi_detached_houses',
#  'input_percentage_of_detached_houses',
#  'input_households_apartments_heat_demand_reduction',
#  'input_households_terraced_houses_heat_demand_reduction',
#  'input_households_corner_houses_heat_demand_reduction',
#  'input_households_semi_detached_houses_heat_demand_reduction',
#  'input_households_detached_houses_heat_demand_reduction',
#  'heat_share_of_apartments_with_block_heating']

# %% [markdown]
# ##### **SETUP** | List Klimaatmonitor keys
#
# List the Klimaatmonitor keys that are relevant for filling our ETLocal template for the energy supply in households

# %%
km_keys_housing_stock = []

for key in keys_housing_stock:
    if df_etlocal_to_km["interface_elements"].isin([key]).any():
        km_keys = df_etlocal_to_km.loc[df_etlocal_to_km["interface_elements"] == key, "klimaatmonitor_keys"].values[0]
        km_key = km_keys.split(',')
        
        km_keys_housing_stock += km_key

# %%
# Preview Klimaatmonitor keys relevant for energy supply in households
km_keys_housing_stock
# Out:
# ['inwoners', 'woningen']

# %% [markdown]
# ##### **EDIT** | Extract data from Klimaatmonitor
#
# For each key that is relevant for the housing stock category

# %%
# Transform Klimaatmonitor data to the right format and fill the data frame
input_data_housing_stock = transformer.filter_km_data(km_keys_housing_stock, df_km_source_data, df_km_meta_data)

# Preview
input_data_housing_stock.head(len(km_keys_housing_stock))
# Out:
#      code       key   value    unit                          topic
# 0  GM0277  inwoners  1654.0  Aantal                Aantal inwoners
# 1  GM0277  woningen   683.0  Aantal  Aantal woningen per 1 januari

# %% [markdown]
# ##### **COMBINE** | Load Klimaatmonitor data in ETLocal template
#
# For all municipalities, fill the ETLocal template with the relevant Klimaatmonitor data

# %%
# Load relevant Klimaatmonitor data into template
template = transformer.load_km_data(input_data_housing_stock, df_etlocal_to_km, template, keys_housing_stock)

# %%
# Preview template (filtered for the households energy demand keys)
template.loc[filter_housing_stock, :].head()
# Out:
#                                                                                     unit  \
# geo_id group      subgroup                 key
# GM0277 households households_housing_stock number_of_inhabitants                       #
#                                            number_of_residences                        #
#                                            residences_roof_surface_available_for_pv  km2
#                                            input_percentage_of_apartments              %
#                                            input_percentage_of_terraced_houses         %
#
#                                                                                       value  \
# geo_id group      subgroup                 key
# GM0277 households households_housing_stock number_of_inhabitants                     1654.0
#                                            number_of_residences                       683.0
#                                            residences_roof_surface_available_for_pv     NaN
#                                            input_percentage_of_apartments               NaN
#                                            input_percentage_of_terraced_houses          NaN
#
#                                                                                                                                 commit
# geo_id group      subgroup                 key
# GM0277 households households_housing_stock number_of_inhabitants                     Klimaatmonitor. Topic: Aantal inwoners, key: i...
#                                            number_of_residences                      Klimaatmonitor. Topic: Aantal woningen per 1 j...
#                                            residences_roof_surface_available_for_pv                                                NaN
#                                            input_percentage_of_apartments                                                          NaN
#                                            input_percentage_of_terraced_houses                                                     NaN

# %%
# TODO add additional data source for households_housing_stock

# %% [markdown]
# #### Application shares
#
# Calculate the applciation shares for each municipality based on the data from the "referentieverbruiken" study by PBL and transform it to the right format.

# %% [markdown]
# ##### Load relevant files

# %% [markdown]
# Load the intermediate data for application shares and store it in a dict of dataframes per municipality. Also, create a new dataframe in which the totals per municipality can be stored. Further, load the config with ETLocal keys that should be filled with our intermediate data.

# %%
# Filter the ETLocal keys that are relevant for the households application shares category
filter_households_applications = (slice(None), 'households', 'households_applications')

# Preview the filtered template
template.loc[filter_households_applications, :].head()
# Out:
#                                                                                              unit  \
# geo_id group      subgroup                key
# GM0277 households households_applications households_final_demand_electricity_households_...    %
#                                           households_final_demand_electricity_households_...    %
#                                           households_final_demand_electricity_households_...    %
#                                           households_final_demand_electricity_households_...    %
#                                           households_final_demand_electricity_households_...    %
#
#                                                                                               value  \
# geo_id group      subgroup                key
# GM0277 households households_applications households_final_demand_electricity_households_...    NaN
#                                           households_final_demand_electricity_households_...    NaN
#                                           households_final_demand_electricity_households_...    NaN
#                                           households_final_demand_electricity_households_...    NaN
#                                           households_final_demand_electricity_households_...    NaN
#
#                                                                                              commit
# geo_id group      subgroup                key
# GM0277 households households_applications households_final_demand_electricity_households_...    NaN
#                                           households_final_demand_electricity_households_...    NaN
#                                           households_final_demand_electricity_households_...    NaN
#                                           households_final_demand_electricity_households_...    NaN
#                                           households_final_demand_electricity_households_...    NaN

# %%
# List all ETLocal keys that are relevant for the households energy demand category
keys_households_applications = list(template.loc[filter_households_applications, :].index.get_level_values(3).unique())

# Preview list
keys_households_applications
# Out:
# ['households_final_demand_electricity_households_final_demand_for_cooking_electricity_parent_share',
#  'households_final_demand_electricity_households_final_demand_for_cooling_electricity_parent_share',
#  'households_final_demand_electricity_households_final_demand_for_hot_water_electricity_parent_share',
#  'households_final_demand_electricity_households_final_demand_for_lighting_electricity_parent_share',
#  'households_final_demand_electricity_households_final_demand_for_space_heating_electricity_parent_share',
#  'households_final_demand_electricity_households_final_demand_for_appliances_electricity_parent_share',
#  'households_final_demand_network_gas_households_final_demand_for_cooking_network_gas_parent_share',
#  'households_final_demand_network_gas_households_final_demand_for_hot_water_network_gas_parent_share',
#  'households_final_demand_network_gas_households_final_demand_for_space_heating_network_gas_parent_share',
#  'households_final_demand_network_gas_households_final_demand_for_cooling_network_gas_parent_share',
#  'households_final_demand_steam_hot_water_households_final_demand_for_hot_water_steam_hot_water_parent_share',
#  'households_final_demand_steam_hot_water_households_final_demand_for_space_heating_steam_hot_water_parent_share',
#  'households_final_demand_wood_pellets_households_final_demand_for_hot_water_wood_pellets_parent_share',
#  'households_final_demand_wood_pellets_households_final_demand_for_space_heating_wood_pellets_parent_share',
#  'households_final_demand_wood_pellets_households_final_demand_for_cooking_wood_pellets_parent_share',
#  'households_final_demand_crude_oil_households_final_demand_for_space_heating_crude_oil_parent_share',
#  'households_final_demand_crude_oil_households_final_demand_for_hot_water_crude_oil_parent_share',
#  'households_final_demand_coal_households_final_demand_for_space_heating_coal_parent_share',
#  'households_final_demand_coal_households_final_demand_for_hot_water_coal_parent_share',
#  'households_final_demand_for_space_heating_network_gas_households_space_heater_combined_network_gas_parent_share',
#  'households_final_demand_for_space_heating_network_gas_households_space_heater_network_gas_parent_share',
#  'households_final_demand_for_space_heating_network_gas_households_space_heater_hybrid_heatpump_air_water_electricity_parent_share',
#  'households_final_demand_for_space_heating_electricity_households_space_heater_electricity_parent_share',
#  'households_final_demand_for_space_heating_electricity_households_space_heater_heatpump_air_water_electricity_parent_share',
#  'households_final_demand_for_space_heating_electricity_households_space_heater_hybrid_heatpump_air_water_electricity_parent_share',
#  'households_final_demand_for_space_heating_electricity_households_space_heater_heatpump_ground_water_electricity_parent_share',
#  'households_final_demand_for_cooking_electricity_households_cooker_halogen_electricity_parent_share',
#  'households_final_demand_for_cooking_electricity_households_cooker_induction_electricity_parent_share',
#  'households_final_demand_for_cooking_electricity_households_cooker_resistive_electricity_parent_share',
#  'households_final_demand_for_lighting_electricity_households_lighting_incandescent_electricity_parent_share',
#  'households_final_demand_for_lighting_electricity_households_lighting_efficient_fluorescent_electricity_parent_share',
#  'households_final_demand_for_lighting_electricity_households_lighting_led_electricity_parent_share',
#  'households_final_demand_for_appliances_electricity_households_appliances_clothes_dryer_electricity_parent_share',
#  'households_final_demand_for_appliances_electricity_households_appliances_computer_media_electricity_parent_share',
#  'households_final_demand_for_appliances_electricity_households_appliances_dishwasher_electricity_parent_share',
#  'households_final_demand_for_appliances_electricity_households_appliances_fridge_freezer_electricity_parent_share',
#  'households_final_demand_for_appliances_electricity_households_appliances_other_electricity_parent_share',
#  'households_final_demand_for_appliances_electricity_households_appliances_television_electricity_parent_share',
#  'households_final_demand_for_appliances_electricity_households_appliances_vacuum_cleaner_electricity_parent_share',
#  'households_final_demand_for_appliances_electricity_households_appliances_washing_machine_electricity_parent_share',
#  'households_final_demand_for_cooling_electricity_households_cooling_airconditioning_electricity_parent_share',
#  'households_final_demand_for_cooling_electricity_households_cooling_heatpump_ground_water_electricity_parent_share',
#  'households_final_demand_for_cooling_electricity_households_cooling_heatpump_air_water_electricity_parent_share']

# %%
# Load intermediate data for application shares
path = Path("data", "intermediate", "application_shares.csv")
input_data_households_applications = pd.read_csv(path, header=[0,1], index_col=[0,1])

# Preview application shares data
input_data_households_applications.head()
# Out:
#                           Metervraag aardgas                                 \
#                                        koken warm tapwater ruimteverwarming
# geo_id bag_vbo_id
# GM0277 '0277010000000003'           5.966168      2.556929        30.847703
#        '0277010000000004'           5.966168      2.556929        25.608763
#        '0277010000000005'           6.272357      2.688153        36.376929
#        '0277010000000006'           5.966168      2.556929        17.995931
#        '0277010000000007'           5.966168      2.556929        29.097010
#
#                           Metervraag elektriciteit                \
#                                              koken warm tapwater
# geo_id bag_vbo_id
# GM0277 '0277010000000003'                      0.0           0.0
#        '0277010000000004'                      0.0           0.0
#        '0277010000000005'                      0.0           0.0
#        '0277010000000006'                      0.0           0.0
#        '0277010000000007'                      0.0           0.0
#
#                                                      Metervraag warmtenet  \
#                           ruimteverwarming hulpvraag        warm tapwater
# geo_id bag_vbo_id
# GM0277 '0277010000000003'              0.0       0.0                  0.0
#        '0277010000000004'              0.0       0.0                  0.0
#        '0277010000000005'              0.0       0.0                  0.0
#        '0277010000000006'              0.0       0.0                  0.0
#        '0277010000000007'              0.0       0.0                  0.0
#
#                                            Metervraag waterstof  ...  \
#                           ruimteverwarming        warm tapwater  ...
# geo_id bag_vbo_id                                                ...
# GM0277 '0277010000000003'              0.0                  0.0  ...
#        '0277010000000004'              0.0                  0.0  ...
#        '0277010000000005'              0.0                  0.0  ...
#        '0277010000000006'              0.0                  0.0  ...
#        '0277010000000007'              0.0                  0.0  ...
#
#                           Metervraag biomassa                   \
#                                 warm tapwater ruimteverwarming
# geo_id bag_vbo_id
# GM0277 '0277010000000003'                 0.0              0.0
#        '0277010000000004'                 0.0              0.0
#        '0277010000000005'                 0.0              0.0
#        '0277010000000006'                 0.0              0.0
#        '0277010000000007'                 0.0              0.0
#
#                            Metervraag olie Metervraag totaal                \
#                           ruimteverwarming           aardgas elektriciteit
# geo_id bag_vbo_id
# GM0277 '0277010000000003'              0.0          0.430285           0.0
#        '0277010000000004'              0.0          0.366720           0.0
#        '0277010000000005'              0.0          0.497373           0.0
#        '0277010000000006'              0.0          0.274351           0.0
#        '0277010000000007'              0.0          0.409044           0.0
#
#
#                           warmtenet waterstof biomassa        olie    totaal
# geo_id bag_vbo_id
# GM0277 '0277010000000003'       0.0       0.0      0.0  112.931290  1.047610
#        '0277010000000004'       0.0       0.0      0.0   95.404591  1.047606
#        '0277010000000005'       0.0       0.0      0.0  132.176085  1.047610
#        '0277010000000006'       0.0       0.0      0.0   69.936118  1.047606
#        '0277010000000007'       0.0       0.0      0.0  107.074405  1.047608
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### Sum individual building data to totals on municipal level and calculate shares

# %% [markdown]
# First, calculate the sums of the application demands for all municipalities.

# %%
# For each municipality sum the data per column
households_applications_totals = input_data_households_applications.groupby(level='geo_id').sum()

# Preview summed input data
households_applications_totals
# Out:
#        Metervraag aardgas                                 \
#                     koken warm tapwater ruimteverwarming
# geo_id
# GM0060        8568.383818   3672.164493     25117.234161
# GM0088        2715.630157   1163.841496      7415.430773
# GM0093       11017.410508   4721.747361     29536.774108
# GM0096        2427.145963   1040.205413      5498.715783
# GM0277        3782.136826   1620.915782     11876.760842
#
#        Metervraag elektriciteit                                           \
#                           koken warm tapwater ruimteverwarming hulpvraag
# geo_id
# GM0060                38.141484      2.098040        42.089799       0.0
# GM0088                79.879004      4.503853        59.326164       0.0
# GM0093               350.515847     11.953146       216.939679       0.0
# GM0096               223.934628     22.455935       290.299065       0.0
# GM0277               108.747157      5.726905       141.249476       0.0
#
#        Metervraag warmtenet                  Metervraag waterstof  ...  \
#               warm tapwater ruimteverwarming        warm tapwater  ...
# geo_id                                                             ...
# GM0060                  0.0              0.0                  0.0  ...
# GM0088                  0.0              0.0                  0.0  ...
# GM0093                  0.0              0.0                  0.0  ...
# GM0096                  0.0              0.0                  0.0  ...
# GM0277                  0.0              0.0                  0.0  ...
#
#        Metervraag biomassa                   Metervraag olie  \
#              warm tapwater ruimteverwarming ruimteverwarming
# geo_id
# GM0060                 0.0        82.946522              0.0
# GM0088                 0.0       181.618039              0.0
# GM0093                 0.0       917.638320              0.0
# GM0096                 0.0        53.139676              0.0
# GM0277                 0.0       254.242959              0.0
#
#        Metervraag totaal                                                \
#                  aardgas elektriciteit warmtenet    waterstof biomassa
# geo_id
# GM0060        509.782769           0.0       0.0   276.488407      0.0
# GM0088        328.210841           0.0       0.0   605.393463      0.0
# GM0093       1240.434298           0.0       0.0  3058.794398      0.0
# GM0096        893.179134           0.0       0.0   177.132253      0.0
# GM0277        556.626379           0.0       0.0   847.476530      0.0
#
#
#                  olie       totaal
# geo_id
# GM0060   98325.294178  1888.845990
# GM0088   30035.044151   635.510934
# GM0093  120513.683885  2442.994317
# GM0096   23290.892750   628.259329
# GM0277   47162.296309   727.028293
#
# [5 rows x 21 columns]

# %% [markdown]
# Then, create a new dataframe (`households_applications_shares`) to store the application _shares_ for all municipalities. Hereafter, we can calculate the shares based on the summed application (total) demands per municipality.

# %%
# Reuse the headers of the existing dataframes 
households_applications_shares = pd.DataFrame(columns=households_applications_totals.columns)

# Set the index to municipality
households_applications_shares = households_applications_shares.rename_axis('municipality')

# Preview the empty dataframe
households_applications_shares.head()
# Out:
# Empty DataFrame
# Columns: [(Metervraag aardgas, koken), (Metervraag aardgas, warm tapwater), (Metervraag aardgas, ruimteverwarming), (Metervraag elektriciteit, koken), (Metervraag elektriciteit, warm tapwater), (Metervraag elektriciteit, ruimteverwarming), (Metervraag elektriciteit, hulpvraag), (Metervraag warmtenet, warm tapwater), (Metervraag warmtenet, ruimteverwarming), (Metervraag waterstof, warm tapwater), (Metervraag waterstof, ruimteverwarming), (Metervraag biomassa, warm tapwater), (Metervraag biomassa, ruimteverwarming), (Metervraag olie, ruimteverwarming), (Metervraag totaal, aardgas), (Metervraag totaal, elektriciteit), (Metervraag totaal, warmtenet), (Metervraag totaal, waterstof), (Metervraag totaal, biomassa), (Metervraag totaal, olie), (Metervraag totaal, totaal)]
# Index: []
#
# [0 rows x 21 columns]

# %%
for municipality in municipalities:
    for carrier in ['aardgas', 'elektriciteit', 'warmtenet', 'waterstof', 'biomassa', 'olie']:
        application_demands = households_applications_totals.loc[municipality, f'Metervraag {carrier}']
        total_demand = application_demands.sum(axis=0)

        for application in application_demands.keys():
            # Suppress possible warnings
            with np.errstate(divide='ignore', invalid='ignore'):
                # The np.divide method is used to easily handle a division by zero error.
                # If this is the case, the share is set to nan.
                share_of_application_demand = np.divide(application_demands[application], total_demand)

            # Add the share to the application shares dataframe for the given municipality
            households_applications_shares.loc[municipality, (f'Metervraag {carrier}', f'{application}')] = share_of_application_demand
            
# Preview dataframe with application shares
households_applications_shares
# Out:
#              Metervraag aardgas                                 \
#                           koken warm tapwater ruimteverwarming
# municipality
# GM0277                 0.218876      0.093804          0.68732
# GM0060                  0.22936      0.098297         0.672343
# GM0088                  0.24043      0.103041         0.656529
# GM0093                 0.243339      0.104288         0.652373
# GM0096                 0.270704      0.116016         0.613281
#
#              Metervraag elektriciteit                                 \
#                                 koken warm tapwater ruimteverwarming
# municipality
# GM0277                       0.425253      0.022395         0.552352
# GM0060                       0.463279      0.025484         0.511237
# GM0088                       0.555838       0.03134         0.412821
# GM0093                       0.604954       0.02063         0.374416
# GM0096                       0.417252      0.041842         0.540907
#
#                        Metervraag warmtenet                   \
#              hulpvraag        warm tapwater ruimteverwarming
# municipality
# GM0277             0.0                  NaN              NaN
# GM0060             0.0                  NaN              NaN
# GM0088             0.0                  NaN              NaN
# GM0093             0.0                  NaN              NaN
# GM0096             0.0                  NaN              NaN
#
#              Metervraag waterstof  ... Metervraag biomassa                   \
#                     warm tapwater  ...       warm tapwater ruimteverwarming
# municipality                       ...
# GM0277                        NaN  ...                 0.0              1.0
# GM0060                        NaN  ...                 0.0              1.0
# GM0088                        NaN  ...                 0.0              1.0
# GM0093                        NaN  ...                 0.0              1.0
# GM0096                        NaN  ...                 0.0              1.0
#
#               Metervraag olie Metervraag totaal                          \
#              ruimteverwarming           aardgas elektriciteit warmtenet
# municipality
# GM0277                    NaN               NaN           NaN       NaN
# GM0060                    NaN               NaN           NaN       NaN
# GM0088                    NaN               NaN           NaN       NaN
# GM0093                    NaN               NaN           NaN       NaN
# GM0096                    NaN               NaN           NaN       NaN
#
#
#              waterstof biomassa olie totaal
# municipality
# GM0277             NaN      NaN  NaN    NaN
# GM0060             NaN      NaN  NaN    NaN
# GM0088             NaN      NaN  NaN    NaN
# GM0093             NaN      NaN  NaN    NaN
# GM0096             NaN      NaN  NaN    NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### Select the relevant data from the source data

# %% [markdown]
# In order to fill the ETLocal template, we need to map the PBL input data to the ETLocal (dataset manager) interface elements.

# %%
# TODO: this could also be a CSV transformed into a data frame--is this more readable for the notebook user?
mapping = {
    'households_final_demand_electricity_households_final_demand_for_cooking_electricity_parent_share': 
    ('Metervraag elektriciteit', 'koken'),
    
    'households_final_demand_electricity_households_final_demand_for_hot_water_electricity_parent_share': 
    ('Metervraag elektriciteit', 'warm tapwater'),
    
    'households_final_demand_electricity_households_final_demand_for_space_heating_electricity_parent_share': 
    ('Metervraag elektriciteit', 'ruimteverwarming'),
    
    'households_final_demand_network_gas_households_final_demand_for_cooking_network_gas_parent_share': 
    ('Metervraag aardgas', 'koken'),
    
    'households_final_demand_network_gas_households_final_demand_for_hot_water_network_gas_parent_share': 
    ('Metervraag aardgas', 'warm tapwater'),
    
    'households_final_demand_network_gas_households_final_demand_for_space_heating_network_gas_parent_share': 
    ('Metervraag aardgas', 'ruimteverwarming'),
    
    'households_final_demand_steam_hot_water_households_final_demand_for_hot_water_steam_hot_water_parent_share':
    ('Metervraag warmtenet', 'warm tapwater'),
    
    'households_final_demand_steam_hot_water_households_final_demand_for_space_heating_steam_hot_water_parent_share':
    ('Metervraag warmtenet', 'ruimteverwarming'),
    
    'households_final_demand_wood_pellets_households_final_demand_for_hot_water_wood_pellets_parent_share':
    ('Metervraag biomassa', 'warm tapwater'),
    
    'households_final_demand_wood_pellets_households_final_demand_for_space_heating_wood_pellets_parent_share':
    ('Metervraag biomassa', 'ruimteverwarming'),
    
    'households_final_demand_crude_oil_households_final_demand_for_space_heating_crude_oil_parent_share':
    ('Metervraag olie', 'ruimteverwarming')
}

# %% [markdown]
# ##### Add values for application shares to the (ETLocal) dataset manager template

# %% [markdown]
# First, load relevant PBL data into the ETLocal template based on the mapping.

# %%
# Add PBL values to (ETLocal) dataset manager template
for municipality in municipalities:
    for etlocal_key, pbl_key in mapping.items():
        # Update the value
        template.loc[(municipality, slice(None), slice(None), etlocal_key), 'value'] = households_applications_shares.loc[municipality, pbl_key]
        
        # Add a commit message
        template.loc[(municipality, slice(None), slice(None), etlocal_key), 'commit'] = f"Calculated the shares based on the value of {pbl_key} as specified in the Referentieverbruiken data export by PBL"

# %% [markdown]
# Then, fill the missing values for:
# - Coal and crude oil
# - Wood pellets
# - District heating
# - Technology splits

# %% [markdown]
# **Coal** | PBL doesn't provide any data about coal. Also, it doesn't provide any data about crude oil for hot water. Hence, we assume that all coal and crude oil is used for space heating.

# %%
# TODO: we could also use the parent data shares instead?
for carrier in ['coal', 'crude_oil']:
    space_heating_key = f'households_final_demand_{carrier}_households_final_demand_for_space_heating_{carrier}_parent_share'
    hot_water_key = f'households_final_demand_{carrier}_households_final_demand_for_hot_water_{carrier}_parent_share'
    
    # Update value and corresponding commit message for the share of space heating
    template.loc[(slice(None), slice(None), slice(None), space_heating_key), 'value'] = 1.
    template.loc[(slice(None), slice(None), slice(None), space_heating_key), 'commit'] = "No data available. Fallback value set to 1. to ensure share totals sum to 1."
    
    # Update value and corresponding commit message for the share of hot water
    template.loc[(slice(None), slice(None), slice(None), hot_water_key), 'value'] = 0.
    template.loc[(slice(None), slice(None), slice(None), hot_water_key), 'commit'] = "No data available. Fallback value set to 0. to ensure share totals sum to 1."

# %% [markdown]
# **Wood pellets** | PBL doesn't assume wood pellets to be used for cooking. Since the parent data share is also set to zero,
# we will use this value in our template as well.

# %%
# Define the key for which the value should be updated
wood_pellets_key = 'households_final_demand_wood_pellets_households_final_demand_for_cooking_wood_pellets_parent_share'

# Set the value to zero
template.loc[(slice(None), slice(None), slice(None), wood_pellets_key), 'value'] = 0.

# And add the corresponding commit message
template.loc[(slice(None), slice(None), slice(None), wood_pellets_key), 'commit'] = f"No data available. The value of the parent dataset ({parent}) is inherited."

# %% [markdown]
# **District heating** | If there's no discrict heating in a municipality (in other words, no steam/hot water demand at all), the template values haven't been set yet. If this is the case--if the district heating shares are still nan values--use the parent data shares instead.

# %%
# Define the key for which the value should be updated
space_heating_key = 'households_final_demand_steam_hot_water_households_final_demand_for_space_heating_steam_hot_water_parent_share'
hot_water_key = 'households_final_demand_steam_hot_water_households_final_demand_for_hot_water_steam_hot_water_parent_share'

for municipality in municipalities:

    # If the value for the space heating share of district heating is still NaN for the municipality:
    if pd.isna(template.loc[(municipality, slice(None), slice(None), space_heating_key), 'value'].any()): 
        
        # Update it to 1.
        template.loc[(municipality, slice(None), slice(None), space_heating_key), 'value'] = 1.
        
        # Add a corresponding commit message
        template.loc[(municipality, slice(None), slice(None), space_heating_key), 
                     'commit'] = f"Assumed this share to be 100% since the district heating demand is zero according to the Referentieverbruiken data export by PBL"
        
        # Update the value for the hot water share to 0.
        template.loc[(municipality, slice(None), slice(None), hot_water_key), 'value'] = 0.
        
        # Add a corresponding commit message
        template.loc[(municipality, slice(None), slice(None), hot_water_key),
                     'commit'] = f"Assumed this share to be 0% since the district heating demand is zero according to the Referentieverbruiken data export by PBL"

# %% [markdown]
# **Technology splits** | There is no municipal data for the technology splits. Hence, we inherit these values from the parent dataset.

# %%
# Define a list of ETLocal keys that should be inherited from the parent dataset.
# These are typically the technology shares.
inherited_keys = [
    # technology split space heating
    'households_final_demand_for_space_heating_network_gas_households_space_heater_combined_network_gas_parent_share',
    'households_final_demand_for_space_heating_network_gas_households_space_heater_network_gas_parent_share',
    'households_final_demand_for_space_heating_network_gas_households_space_heater_hybrid_heatpump_air_water_electricity_parent_share',
    'households_final_demand_for_space_heating_electricity_households_space_heater_electricity_parent_share',
    'households_final_demand_for_space_heating_electricity_households_space_heater_heatpump_air_water_electricity_parent_share',
    'households_final_demand_for_space_heating_electricity_households_space_heater_hybrid_heatpump_air_water_electricity_parent_share',
    'households_final_demand_for_space_heating_electricity_households_space_heater_heatpump_ground_water_electricity_parent_share',
    
    # technology split cooking
    'households_final_demand_for_cooking_electricity_households_cooker_halogen_electricity_parent_share',
    'households_final_demand_for_cooking_electricity_households_cooker_induction_electricity_parent_share',
    'households_final_demand_for_cooking_electricity_households_cooker_resistive_electricity_parent_share',
    
    # technology split lighting
    'households_final_demand_for_lighting_electricity_households_lighting_incandescent_electricity_parent_share',
    'households_final_demand_for_lighting_electricity_households_lighting_efficient_fluorescent_electricity_parent_share',
    'households_final_demand_for_lighting_electricity_households_lighting_led_electricity_parent_share',
    
    # technology split appliances
    'households_final_demand_for_appliances_electricity_households_appliances_clothes_dryer_electricity_parent_share',
    'households_final_demand_for_appliances_electricity_households_appliances_computer_media_electricity_parent_share',
    'households_final_demand_for_appliances_electricity_households_appliances_dishwasher_electricity_parent_share',
    'households_final_demand_for_appliances_electricity_households_appliances_fridge_freezer_electricity_parent_share',
    'households_final_demand_for_appliances_electricity_households_appliances_other_electricity_parent_share',
    'households_final_demand_for_appliances_electricity_households_appliances_television_electricity_parent_share',
    'households_final_demand_for_appliances_electricity_households_appliances_vacuum_cleaner_electricity_parent_share',
    'households_final_demand_for_appliances_electricity_households_appliances_washing_machine_electricity_parent_share',
    
    # technology split cooling
    'households_final_demand_for_cooling_electricity_households_cooling_airconditioning_electricity_parent_share',
    'households_final_demand_for_cooling_electricity_households_cooling_heatpump_ground_water_electricity_parent_share',
    'households_final_demand_for_cooling_electricity_households_cooling_heatpump_air_water_electricity_parent_share'
]

# %%
# Inherit missing data values from parent dataset
for key in inherited_keys:
    # Update the value
    template.loc[(slice(None), slice(None), slice(None), key), 'value'] = df_parent.at['nl', key]

    # And add a commit message
    template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"Inherited the value of the parent dataset ({parent})"

# %%
# Preview template after changes
template.loc[filter_households_applications, :].head()
# Out:
#                                                                                              unit  \
# geo_id group      subgroup                key
# GM0277 households households_applications households_final_demand_electricity_households_...    %
#                                           households_final_demand_electricity_households_...    %
#                                           households_final_demand_electricity_households_...    %
#                                           households_final_demand_electricity_households_...    %
#                                           households_final_demand_electricity_households_...    %
#
#                                                                                                  value  \
# geo_id group      subgroup                key
# GM0277 households households_applications households_final_demand_electricity_households_...  0.425253
#                                           households_final_demand_electricity_households_...       NaN
#                                           households_final_demand_electricity_households_...  0.022395
#                                           households_final_demand_electricity_households_...       NaN
#                                           households_final_demand_electricity_households_...  0.552352
#
#                                                                                                                                          commit
# geo_id group      subgroup                key
# GM0277 households households_applications households_final_demand_electricity_households_...  Calculated the shares based on the value of ('...
#                                           households_final_demand_electricity_households_...                                                NaN
#                                           households_final_demand_electricity_households_...  Calculated the shares based on the value of ('...
#                                           households_final_demand_electricity_households_...                                                NaN
#                                           households_final_demand_electricity_households_...  Calculated the shares based on the value of ('...

# %% [markdown]
# #### Exceptions
#
# If there are any exceptions for municipal datasets, you can overwrite the values below.

# %% [markdown]
# **TO DO** | Explain to the user that this section should always be checked. Should the exception be overwritten by the update? Or should it remain untouched?

# %% [markdown]
# ##### Gemeente X

# %%
#

# %% [markdown]
# #### Export processed data
# Write the transformed data to our  `data / processed` directory. This is the data we will be using for the next (analysis and visualisation) steps in the pipeline.

# %%
# Write dataframe to intermediate data folder
path = Path("data", "processed", "etlocal_template.csv")
template.to_csv(path)

# %% [markdown]
# #### Export reporting data
# Merge application shares template in the `data.csv` and `commits.yml` files that are necessary for a ETLocal migration.

# %%
# Preview data.csv dataframe
df_data_csv
# Out:
#             country                                    name
# geo_id
# GM1680       nl2019                             Aa en Hunze
# GM0738       nl2019                                 Aalburg
# GM0358       nl2019                                Aalsmeer
# GM0197       nl2019                                  Aalten
# GM0059       nl2019                           Achtkarspelen
# ...             ...                                     ...
# RGHLD01      nl2019                 Heerhugowaard-Langedijk
# BU19660506   nl2019                               Oudeschip
# RGPA01       RGPA01  Panama - Ports of Cristobal and Balboa
# SG               SG                               Singapore
# DKGM751     DKGM751                                  Aarhus
#
# [3983 rows x 2 columns]

# %%
# Load commits.yml file into a Python data structure
path = Path("data", "reporting", "commits.yml")

with open(path, 'r') as file:
    commits = yaml.safe_load(file)

if commits is None:
    commits = []
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[97], line 4
#       1 # Load commits.yml file into a Python data structure
#       2 path = Path("data", "reporting", "commits.yml")
# ----> 4 with open(path, 'r') as file:
#       5     commits = yaml.safe_load(file)
#       7 if commits is None:
#
# File /opt/homebrew/lib/python3.11/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/reporting/commits.yml'

# %%
# List all keys that have been added to the template
keys = list(template.index.get_level_values(3).unique())

# For each municipality fill data.csv and commits.yml
for key in keys:
    df_data_csv.loc[:, key] = float('nan')
    for municipality in municipalities:
        # Add data value to data.csv
        df_data_csv.loc[municipality, key] = template.loc[(municipality, slice(None), slice(None), key), 'value'].values[0]
        
        # Add commit message to commits.yml
        commits.append({'fields': [key], 'message': template.loc[(municipality, slice(None), slice(None), key), 'commit'].values[0]})
    
# Preview (transposed) data for all municipalities in the format required for the data.csv file
df_data_csv.T
# Out:
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# /var/folders/y7/2bztd4296dv6x2qq5f0svrgw0000gn/T/ipykernel_60814/2041643147.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_data_csv.loc[:, key] = float('nan')
# geo_id                                                   GM1680   GM0738  \
# country                                                  nl2019   nl2019
# name                                                Aa en Hunze  Aalburg
# households_final_demand_electricity_households_...          NaN      NaN
# households_final_demand_electricity_households_...          NaN      NaN
# households_final_demand_electricity_households_...          NaN      NaN
# ...                                                         ...      ...
# industry_ict_mt_residual_heat                               NaN      NaN
# industry_ict_lt_residual_heat                               NaN      NaN
# energy_heat_distribution_ht_loss_demand                     NaN      NaN
# energy_heat_distribution_mt_loss_demand                     NaN      NaN
# energy_heat_distribution_lt_loss_demand                     NaN      NaN
#
# geo_id                                                GM0358  GM0197  \
# country                                               nl2019  nl2019
# name                                                Aalsmeer  Aalten
# households_final_demand_electricity_households_...       NaN     NaN
# households_final_demand_electricity_households_...       NaN     NaN
# households_final_demand_electricity_households_...       NaN     NaN
# ...                                                      ...     ...
# industry_ict_mt_residual_heat                            NaN     NaN
# industry_ict_lt_residual_heat                            NaN     NaN
# energy_heat_distribution_ht_loss_demand                  NaN     NaN
# energy_heat_distribution_mt_loss_demand                  NaN     NaN
# energy_heat_distribution_lt_loss_demand                  NaN     NaN
#
# geo_id                                                     GM0059  \
# country                                                    nl2019
# name                                                Achtkarspelen
# households_final_demand_electricity_households_...            NaN
# households_final_demand_electricity_households_...            NaN
# households_final_demand_electricity_households_...            NaN
# ...                                                           ...
# industry_ict_mt_residual_heat                                 NaN
# industry_ict_lt_residual_heat                                 NaN
# energy_heat_distribution_ht_loss_demand                       NaN
# energy_heat_distribution_mt_loss_demand                       NaN
# energy_heat_distribution_lt_loss_demand                       NaN
#
# geo_id                                                    GM0482  \
# country                                                   nl2019
# name                                                Alblasserdam
# households_final_demand_electricity_households_...           NaN
# households_final_demand_electricity_households_...           NaN
# households_final_demand_electricity_households_...           NaN
# ...                                                          ...
# industry_ict_mt_residual_heat                                NaN
# industry_ict_lt_residual_heat                                NaN
# energy_heat_distribution_ht_loss_demand                      NaN
# energy_heat_distribution_mt_loss_demand                      NaN
# energy_heat_distribution_lt_loss_demand                      NaN
#
# geo_id                                                     GM0613   GM0361  \
# country                                                    nl2019   nl2019
# name                                                Albrandswaard  Alkmaar
# households_final_demand_electricity_households_...            NaN      NaN
# households_final_demand_electricity_households_...            NaN      NaN
# households_final_demand_electricity_households_...            NaN      NaN
# ...                                                           ...      ...
# industry_ict_mt_residual_heat                                 NaN      NaN
# industry_ict_lt_residual_heat                                 NaN      NaN
# energy_heat_distribution_ht_loss_demand                       NaN      NaN
# energy_heat_distribution_mt_loss_demand                       NaN      NaN
# energy_heat_distribution_lt_loss_demand                       NaN      NaN
#
# geo_id                                              GM0141  GM0034  ...  \
# country                                             nl2019  nl2019  ...
# name                                                Almelo  Almere  ...
# households_final_demand_electricity_households_...     NaN     NaN  ...
# households_final_demand_electricity_households_...     NaN     NaN  ...
# households_final_demand_electricity_households_...     NaN     NaN  ...
# ...                                                    ...     ...  ...
# industry_ict_mt_residual_heat                          NaN     NaN  ...
# industry_ict_lt_residual_heat                          NaN     NaN  ...
# energy_heat_distribution_ht_loss_demand                NaN     NaN  ...
# energy_heat_distribution_mt_loss_demand                NaN     NaN  ...
# energy_heat_distribution_lt_loss_demand                NaN     NaN  ...
#
# geo_id                                                        UKNI01  \
# country                                                       UKNI01
# name                                                Northern Ireland
# households_final_demand_electricity_households_...               NaN
# households_final_demand_electricity_households_...               NaN
# households_final_demand_electricity_households_...               NaN
# ...                                                              ...
# industry_ict_mt_residual_heat                                    NaN
# industry_ict_lt_residual_heat                                    NaN
# energy_heat_distribution_ht_loss_demand                          NaN
# energy_heat_distribution_mt_loss_demand                          NaN
# energy_heat_distribution_lt_loss_demand                          NaN
#
# geo_id                                                 RGAMS01 BEGM13040  \
# country                                                 nl2019        BE
# name                                                Haven-Stad  Turnhout
# households_final_demand_electricity_households_...         NaN       NaN
# households_final_demand_electricity_households_...         NaN       NaN
# households_final_demand_electricity_households_...         NaN       NaN
# ...                                                        ...       ...
# industry_ict_mt_residual_heat                              NaN       NaN
# industry_ict_lt_residual_heat                              NaN       NaN
# energy_heat_distribution_ht_loss_demand                    NaN       NaN
# energy_heat_distribution_mt_loss_demand                    NaN       NaN
# energy_heat_distribution_lt_loss_demand                    NaN       NaN
#
# geo_id                                                      RGGLD01  \
# country                                                      nl2019
# name                                                Gelderland plus
# households_final_demand_electricity_households_...              NaN
# households_final_demand_electricity_households_...              NaN
# households_final_demand_electricity_households_...              NaN
# ...                                                             ...
# industry_ict_mt_residual_heat                                   NaN
# industry_ict_lt_residual_heat                                   NaN
# energy_heat_distribution_ht_loss_demand                         NaN
# energy_heat_distribution_mt_loss_demand                         NaN
# energy_heat_distribution_lt_loss_demand                         NaN
#
# geo_id                                                           RGBRE01  \
# country                                                           nl2019
# name                                                Breda Steenakker BiZ
# households_final_demand_electricity_households_...                   NaN
# households_final_demand_electricity_households_...                   NaN
# households_final_demand_electricity_households_...                   NaN
# ...                                                                  ...
# industry_ict_mt_residual_heat                                        NaN
# industry_ict_lt_residual_heat                                        NaN
# energy_heat_distribution_ht_loss_demand                              NaN
# energy_heat_distribution_mt_loss_demand                              NaN
# energy_heat_distribution_lt_loss_demand                              NaN
#
# geo_id                                                              RGHLD01  \
# country                                                              nl2019
# name                                                Heerhugowaard-Langedijk
# households_final_demand_electricity_households_...                      NaN
# households_final_demand_electricity_households_...                      NaN
# households_final_demand_electricity_households_...                      NaN
# ...                                                                     ...
# industry_ict_mt_residual_heat                                           NaN
# industry_ict_lt_residual_heat                                           NaN
# energy_heat_distribution_ht_loss_demand                                 NaN
# energy_heat_distribution_mt_loss_demand                                 NaN
# energy_heat_distribution_lt_loss_demand                                 NaN
#
# geo_id                                             BU19660506  \
# country                                                nl2019
# name                                                Oudeschip
# households_final_demand_electricity_households_...        NaN
# households_final_demand_electricity_households_...        NaN
# households_final_demand_electricity_households_...        NaN
# ...                                                       ...
# industry_ict_mt_residual_heat                             NaN
# industry_ict_lt_residual_heat                             NaN
# energy_heat_distribution_ht_loss_demand                   NaN
# energy_heat_distribution_mt_loss_demand                   NaN
# energy_heat_distribution_lt_loss_demand                   NaN
#
# geo_id                                                                              RGPA01  \
# country                                                                             RGPA01
# name                                                Panama - Ports of Cristobal and Balboa
# households_final_demand_electricity_households_...                                     NaN
# households_final_demand_electricity_households_...                                     NaN
# households_final_demand_electricity_households_...                                     NaN
# ...                                                                                    ...
# industry_ict_mt_residual_heat                                                          NaN
# industry_ict_lt_residual_heat                                                          NaN
# energy_heat_distribution_ht_loss_demand                                                NaN
# energy_heat_distribution_mt_loss_demand                                                NaN
# energy_heat_distribution_lt_loss_demand                                                NaN
#
# geo_id                                                     SG  DKGM751
# country                                                    SG  DKGM751
# name                                                Singapore   Aarhus
# households_final_demand_electricity_households_...        NaN      NaN
# households_final_demand_electricity_households_...        NaN      NaN
# households_final_demand_electricity_households_...        NaN      NaN
# ...                                                       ...      ...
# industry_ict_mt_residual_heat                             NaN      NaN
# industry_ict_lt_residual_heat                             NaN      NaN
# energy_heat_distribution_ht_loss_demand                   NaN      NaN
# energy_heat_distribution_mt_loss_demand                   NaN      NaN
# energy_heat_distribution_lt_loss_demand                   NaN      NaN
#
# [129 rows x 3983 columns]

# %%
# Write data.csv to processed data directory
df_data_csv.to_csv(f"data/reporting/data.csv", index=False)

# %%
# TODO: Beautify the yaml data and make it more readable
# commits_yaml = yaml.dump(commits, sort_keys=False, indent=4, default_flow_style=False, default_style='|')

# Write the updated data back to the YAML file
path = Path("data", "reporting", "commits.yml")

with open(path, 'w') as file:
    yaml.safe_dump(commits, file)

# %% [markdown]
# ### 4. Data analysis and visualisation (sanity check)

# %% [markdown]
# When we have a complete dataset, we can apply exploratory data analysis and visualisation to validate our data and perform sanity checks such as:
#
# * Do the totals of energy demand per sector correspond to the original (or alternative) source data?
# * Does the distribution per sector / category / carrier make sense? Or does it imply inaccurate data?
# * Do the totals of energy demand and supply per carrier correspond to the original (or alternative) source data?
# * Does the distribution of energy demand and supply per carrier make sense? Or does it imply inaccurate data?
# * How does the energy demand per inhabitant compare to the parent value?
# * How do the added hourly curves relate to the parent ones?
#
# A dashboard of charts and key figures will be designed to support the sanity check. The visualisations will make it easier to detect flaws and insanities at a glance. Here, among others, parent values are compared to child values to check whether the results meet our expectations. Same goes for the balance between demand and supply for each carrier.

# %%
# TODO: Create reusable modules to visualise charts/data

# %%
# TODO: Reporting MW installed capacities based on demands per carrier and full load hours

# %%
# TODO: Reporting application split per transport mode based on demands and modal split per carrier

# %%
# TODO: Reporting change log compared to current version of the dataset in the ETM dataset manager (e.g. have you changed the year?)

# %% [markdown]
# #### Setup
#
# Setup the checker (if not setup yet) and load all processed data files for the next step in the pipeline.

# %%
# Initialise checker class to access transformation functions
checker = Checker()

# %% [markdown]
# Then, load the processed data file(s):
# - etlocal_template.csv

# %%
# Load data
template = pd.read_csv(f'data/processed/etlocal_template.csv', index_col=[0,1,2,3])

# %%
# Preview data
template
# Out:
#                                                                                               unit  \
# geo_id group      subgroup                 key
# GM0277 households households_applications  households_final_demand_electricity_households_...    %
#                                            households_final_demand_electricity_households_...    %
#                                            households_final_demand_electricity_households_...    %
#                                            households_final_demand_electricity_households_...    %
#                                            households_final_demand_electricity_households_...    %
# ...                                                                                            ...
# GM0096 households households_housing_stock input_households_terraced_houses_heat_demand_re...    %
#                                            input_households_corner_houses_heat_demand_redu...    %
#                                            input_households_semi_detached_houses_heat_dema...    %
#                                            input_households_detached_houses_heat_demand_re...    %
#                                            heat_share_of_apartments_with_block_heating           %
#
#                                                                                                   value  \
# geo_id group      subgroup                 key
# GM0277 households households_applications  households_final_demand_electricity_households_...  0.425253
#                                            households_final_demand_electricity_households_...       NaN
#                                            households_final_demand_electricity_households_...  0.022395
#                                            households_final_demand_electricity_households_...       NaN
#                                            households_final_demand_electricity_households_...  0.552352
# ...                                                                                                 ...
# GM0096 households households_housing_stock input_households_terraced_houses_heat_demand_re...       NaN
#                                            input_households_corner_houses_heat_demand_redu...       NaN
#                                            input_households_semi_detached_houses_heat_dema...       NaN
#                                            input_households_detached_houses_heat_demand_re...       NaN
#                                            heat_share_of_apartments_with_block_heating              NaN
#
#                                                                                                                                           commit
# geo_id group      subgroup                 key
# GM0277 households households_applications  households_final_demand_electricity_households_...  Calculated the shares based on the value of ('...
#                                            households_final_demand_electricity_households_...                                                NaN
#                                            households_final_demand_electricity_households_...  Calculated the shares based on the value of ('...
#                                            households_final_demand_electricity_households_...                                                NaN
#                                            households_final_demand_electricity_households_...  Calculated the shares based on the value of ('...
# ...                                                                                                                                          ...
# GM0096 households households_housing_stock input_households_terraced_houses_heat_demand_re...                                                NaN
#                                            input_households_corner_houses_heat_demand_redu...                                                NaN
#                                            input_households_semi_detached_houses_heat_dema...                                                NaN
#                                            input_households_detached_houses_heat_demand_re...                                                NaN
#                                            heat_share_of_apartments_with_block_heating                                                       NaN
#
# [730 rows x 3 columns]

# %% [markdown]
# #### Sanity check
#
# Visualise datasets in order to perform a sanity check
#
# **TO DO** | Create methods for visualisations
#
# **TO DO** | Expand sanity checks and visualisations

# %%
data_to_plot = template.swaplevel(0,3).loc[[
    "households_final_demand_electricity_demand", 
    "households_final_demand_network_gas_demand", 
    "households_final_demand_steam_hot_water_demand", 
    "households_final_demand_wood_pellets_demand",
    "households_final_demand_coal_demand",
    "input_households_final_demand_crude_oil_demand",
    "households_final_demand_solar_thermal_demand"
]]

data_to_plot.index = data_to_plot.index.droplevel([1,2,3])

data_to_plot = data_to_plot["value"].reset_index()

plt.figure(figsize=(8, 6), dpi = 100)

sns.boxplot(data=data_to_plot, y='key', x='value')
sns.set_theme(style="darkgrid")
sns.set()

plt.show()

# %%
# For households: visualise distribution of inhabitants and residences across all municipalities

data_to_plot = "number_of_inhabitants"
variable_to_plot = "value"
df_to_plot = template.loc[(slice(None), slice(None), slice(None), data_to_plot), :]

plt.figure(figsize=(8, 6), dpi = 100)

sns.histplot(data=df_to_plot, x=variable_to_plot)
sns.set_theme(style="darkgrid")
sns.set()

plt.xlabel('Number of inhabitants')
plt.ylabel('Count of municipalities')

plt.show()

# %%
data_to_plot = template.swaplevel(0,3).loc[["number_of_inhabitants", "number_of_residences"]]

data_to_plot.index = data_to_plot.index.droplevel([1,2,3])

data_to_plot = data_to_plot["value"].reset_index()

plt.figure(figsize=(8, 6), dpi = 100)

sns.boxplot(data=data_to_plot, y='key', x='value')
sns.set_theme(style="darkgrid")
sns.set()

plt.show()

# %%
# For households: visualise ratio between residences and inhabitants as scatterplot

# Transform code below to function

variable_x_to_plot = template.loc[(slice(None), slice(None), slice(None), 'number_of_inhabitants'), 'value'].values
variable_x_to_plot = pd.DataFrame(variable_x_to_plot, columns=['number_of_inhabitants'])

variable_y_to_plot = template.loc[(slice(None), slice(None), slice(None), 'number_of_residences'), 'value'].values
variable_y_to_plot = pd.DataFrame(variable_y_to_plot, columns=['number_of_residences'])

data_to_plot = pd.concat([variable_x_to_plot, variable_y_to_plot], axis=1)

plt.figure(figsize=(8, 6), dpi = 100)

sns.scatterplot(data=data_to_plot, x='number_of_inhabitants', y='number_of_residences')
sns.set_theme(style="darkgrid")
sns.set()

plt.xlabel('Number of inhabitants')
plt.ylabel('Number of residences')

plt.show()

# %%
# For households: visualise energy demand per inhabitant or per residence

data_to_convert = template.swaplevel(0,3).loc[[
    "households_final_demand_electricity_demand", 
    "households_final_demand_network_gas_demand", 
    "households_final_demand_steam_hot_water_demand", 
    "households_final_demand_wood_pellets_demand",
    "households_final_demand_coal_demand",
    "input_households_final_demand_crude_oil_demand",
    "households_final_demand_solar_thermal_demand"
]]

data_to_convert.index = data_to_convert.index.droplevel([1,2])
data_to_convert = data_to_convert.swaplevel(0,1)

data_to_use = template.swaplevel(0,3).loc[[
    "number_of_inhabitants"
]]

data_to_use.index = data_to_use.index.droplevel([1,2])
data_to_use = data_to_use.swaplevel(0,1)
data_to_use.index = data_to_use.index.droplevel(1)
data_to_use = data_to_use['value']

data_to_convert["relative"] = data_to_convert["value"] / data_to_use
 
data_to_convert.index = data_to_convert.index.droplevel(0)

data_to_plot = data_to_convert["relative"].reset_index()

plt.figure(figsize=(8, 6), dpi = 100)

sns.boxplot(data=data_to_plot, y='key', x='relative')
sns.set_theme(style="darkgrid")
sns.set()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[119], line 25
#      22 data_to_use.index = data_to_use.index.droplevel(1)
#      23 data_to_use = data_to_use['value']
# ---> 25 data_to_convert["relative"] = data_to_convert["value"] / data_to_use
#      27 data_to_convert.index = data_to_convert.index.droplevel(0)
#      29 data_to_plot = data_to_convert["relative"].reset_index()
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/series.py:6111, in Series._arith_method(self, other, op)
#    6110 def _arith_method(self, other, op):
# -> 6111     self, other = ops.align_method_SERIES(self, other)
#    6112     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/ops/__init__.py:171, in align_method_SERIES(left, right, align_asobject)
#     168             left = left.astype(object)
#     169             right = right.astype(object)
# --> 171         left, right = left.align(right, copy=False)
#     173 return left, right
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/series.py:4720, in Series.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    4702 @doc(
#    4703     NDFrame.align,  # type: ignore[has-type]
#    4704     klass=_shared_doc_kwargs["klass"],
#    (...)
#    4718     broadcast_axis: Axis | None = None,
#    4719 ) -> Series:
# -> 4720     return super().align(
#    4721         other,
#    4722         join=join,
#    4723         axis=axis,
#    4724         level=level,
#    4725         copy=copy,
#    4726         fill_value=fill_value,
#    4727         method=method,
#    4728         limit=limit,
#    4729         fill_axis=fill_axis,
#    4730         broadcast_axis=broadcast_axis,
#    4731     )
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/generic.py:9449, in NDFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    9437     return self._align_frame(
#    9438         other,
#    9439         join=join,
#    (...)
#    9446         fill_axis=fill_axis,
#    9447     )
#    9448 elif isinstance(other, ABCSeries):
# -> 9449     return self._align_series(
#    9450         other,
#    9451         join=join,
#    9452         axis=axis,
#    9453         level=level,
#    9454         copy=copy,
#    9455         fill_value=fill_value,
#    9456         method=method,
#    9457         limit=limit,
#    9458         fill_axis=fill_axis,
#    9459     )
#    9460 else:  # pragma: no cover
#    9461     raise TypeError(f"unsupported type: {type(other)}")
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/generic.py:9556, in NDFrame._align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    9554     join_index, lidx, ridx = None, None, None
#    9555 else:
# -> 9556     join_index, lidx, ridx = self.index.join(
#    9557         other.index, how=join, level=level, return_indexers=True
#    9558     )
#    9560 if is_series:
#    9561     left = self._reindex_indexer(join_index, lidx, copy)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:259, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     249 @functools.wraps(meth)
#     250 def join(
#     251     self,
#    (...)
#     257     sort: bool = False,
#     258 ):
# --> 259     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     260     if not return_indexers:
#     261         return join_index
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:4455, in Index.join(self, other, how, level, return_indexers, sort)
#    4453         pass
#    4454     else:
# -> 4455         return self._join_multi(other, how=how)
#    4457 # join on the level
#    4458 if level is not None and (self._is_multi or other._is_multi):
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:4638, in Index._join_multi(self, other, how)
#    4635     how = flip.get(how, how)
#    4637 level = other.names.index(jl)
# -> 4638 result = self._join_level(other, level, how=how)
#    4640 if flip_order:
#    4641     return result[0], result[2], result[1]
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:4725, in Index._join_level(self, other, level, how, keep_order)
#    4722 old_level = left.levels[level]
#    4724 if not right.is_unique:
# -> 4725     raise NotImplementedError(
#    4726         "Index._join_level on non-unique index is not implemented"
#    4727     )
#    4729 new_level, left_lev_indexer, right_lev_indexer = old_level.join(
#    4730     right, how=how, return_indexers=True
#    4731 )
#    4733 if left_lev_indexer is None:
#
# NotImplementedError: Index._join_level on non-unique index is not implemented

# %%
data_to_plot = template.swaplevel(0,3).loc[[
    "households_final_demand_electricity_demand", 
    "households_final_demand_network_gas_demand", 
    "households_final_demand_steam_hot_water_demand", 
    "households_final_demand_wood_pellets_demand",
    "households_final_demand_coal_demand",
    "input_households_final_demand_crude_oil_demand",
    "households_final_demand_solar_thermal_demand"
]]

data_to_plot.index = data_to_plot.index.droplevel([1,2,3])

data_to_plot = data_to_plot["value"].reset_index()

plt.figure(figsize=(8, 6), dpi = 100)

sns.boxplot(data=data_to_plot, y='key', x='value')
sns.set_theme(style="darkgrid")
sns.set()

plt.show()

# %% [markdown]
# ## Services

# %% [markdown]
# ### 1. Data collection

# %% [markdown]
# In the data collection phase, we make an overview of the required data and design a data model to efficiently build our database. If possible, we call the API to collect our data. Otherwise, we first manually collect a data export and store it in the `data / raw` directory.
#
# ![image.png](attachment:75b96a93-92f4-444a-9a96-18eb4a6d5295.png)
#
# For the municipal datasets we use the following data sources:
# * **??** | ...
# * **Dataset manager** | to collect the parent dataset
#
# For each data source, the following steps are followed:
# * **Extract** | Extracting the raw data from its source
# * **Transform** | Transforming the raw data to a 'workable' format
# * **Load** | Writing the processed data to the intermediate data directory

# %%
# TODO

# %% [markdown]
# #### ETM dataset manager (parent dataset)

# %% [markdown]
# In case certain data points are not available for the given region, we want to inherit the values of the parent dataset. For the municipality datasets, the parent is the NL2019 dataset.

# %% [markdown]
# ##### Extract
# In this step we call the ETM Dataset Manager API to get the parent dataset.

# %%
# Connect to the ETM dataset manager API and collect the parent dataset 
response = requests.get(f"https://data.energytransitionmodel.com/api/v1/exports/{parent}")

# %%
# Check if the response has been successful. If the code is anything else than 200, something went wrong.
response.status_code
# Out:
# 200

# %% [markdown]
# Here is an overview of the different status codes and what these imply:
#
# - **200**: Everything went okay, and the result has been returned (if any).
# - **301**: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# - **400**: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
# - **401**: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t send the right credentials to access an API.
# - **403**: The resource you’re trying to access is forbidden: you don’t have the right perlessons to see it.
# - **404**: The resource you tried to access wasn’t found on the server.
# - **503**: The server is not ready to handle the request.

# %%
# In that case, print the error message to see what caused the error
response.reason
# Out:
# 'OK'

# %% [markdown]
# ##### Transform
# Create a dataframe from the API response in which the parent dataset is included.

# %%
# If the reponse has been successful, collect its data.

# The data is stored as a dict in a single-itemed array. To get the dict, get the first item of the array.
raw_parent_data = response.json()[0]

# Then, create a dataframe from the dict.
df_parent = pd.DataFrame(raw_parent_data, index=[0])

# Rename the index to nl
df_parent = df_parent.rename(index={0: 'nl'})

# %%
# Preview the data in its transposed form (by using .T)
df_parent.T
# Out:
#                                                              nl
# agriculture_final_demand_electricity_demand           41584.615
# agriculture_final_demand_network_gas_demand           91072.918
# agriculture_final_demand_steam_hot_water_demand        2783.107
# agriculture_final_demand_wood_pellets_demand           5437.224
# input_agriculture_final_demand_crude_oil_demand       17965.442
# ...                                                         ...
# input_transport_ship_electricity_demand                     0.0
# bunkers_total_useful_demand_ships_demand             478316.636
# area                                             NL_netherlands
# base_dataset                                                 eu
# group                                                   country
#
# [619 rows x 1 columns]

# %% [markdown]
# ##### Load
# Save the parent data set to the intermediate data folder.

# %%
# Write dataframe to intermediate data folder
df_parent.to_csv(f"data/intermediate/parent_data.csv")

# %% [markdown]
# ### 2. Data quality

# %%
# TODO

# %% [markdown]
# #### Setup
#
# Setup the checker and load all files from the `data / intermediate` directory.

# %% [markdown]
# First, setup the checker class

# %%
# Initialise checker class to access transformation functions
checker = Checker()

# %% [markdown]
# Then, setup all data files:
# - ...
# - parent data

# %% [markdown]
# ### 3. Data transformation

# %%
# TODO

# %% [markdown]
# #### Setup
#
# Setup the transformer and load all intermediate data files for the next step in the pipeline.

# %% [markdown]
# First, setup the transformer class:

# %%
# Initialise transformer class to access transformation functions
transformer = Transformer(municipalities, year)

# %% [markdown]
# Then, setup all data files:
# - dataframe representing data.csv
# - commits.yml
# - dataframe with all etlocal interface elements
# - ...
# - parent data

# %% [markdown]
# ##### Create empty ETLocal templates

# %% [markdown]
# Only run these cells if you want to create empty ETLocal templates. If the templates have been filled in previous steps, these changes will be overwritten. If you don't want to overwrite your changes, **DON'T** run the cells below. :-)

# %%
# First, initialize data.csv file based on the config file
path = Path("config", "data.csv")
df_data_csv = pd.read_csv(path, index_col=[0], sep=sep)

# Drop unnamed columns
df_data_csv = df_data_csv.drop(columns=df_data_csv.columns[df_data_csv.columns.str.startswith('Unnamed')])

# %%
# Preview dataframe representing data.csv
df_data_csv
# Out:
#        country             name
# geo_id
# GM0277  nl2019        Rozendaal
# GM0060  nl2019          Ameland
# GM0088  nl2019  Schiermonnikoog
# GM0093  nl2019     Terschelling
# GM0096  nl2019         Vlieland

# %%
# Then, initialize commits.yml file by specifying the file path where you want to create the YAML file
path = Path("data", "reporting", "commits.yml")

# Write the document separator to the YAML file
with open(path, 'w') as file:
    file.write('---\n')

# %%
# TODO: Describe that by running this cell an empty template is created. This overwrites the filled template.

# Load ETLocal template with target keys from config
path = Path("config", "etlocal_interface_elements.csv")
empty_template = pd.read_csv(path, header=[0])#, index_col=[2])

# Add columns geo_id, value and commit to the template    
for column in ['geo_id', 'value', 'commit']:
    empty_template[column] = float('nan')
    
# Fill the geo_id column with all relevant municipal geo IDs
templates = []
for municipality in municipalities:
    template_to_add = empty_template.copy()
    template_to_add['geo_id'] = municipality
    templates.append(template_to_add)
    
# Concatenate list of templates to one big template with all municipalities
template = pd.concat(templates)

# Transform the templates into a multi-index dataframe
index = pd.MultiIndex.from_frame(template[['geo_id', 'group', 'subgroup', 'key']])
template = template.drop(columns=['geo_id', 'group', 'subgroup', 'key'])
template.index = index

# Preview merged template
template
# Out:
#                                                                                                 unit  \
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
# ...                                                                                              ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...    %
#                                              input_percentage_of_mt_steam_hot_water_building...    %
#                                              input_percentage_of_ht_steam_hot_water_building...    %
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    %
#                                              input_percentage_of_ht_steam_hot_water_agricult...    %
#
#                                                                                                  value  \
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
# ...                                                                                                ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...    NaN
#                                              input_percentage_of_mt_steam_hot_water_building...    NaN
#                                              input_percentage_of_ht_steam_hot_water_building...    NaN
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    NaN
#                                              input_percentage_of_ht_steam_hot_water_agricult...    NaN
#
#                                                                                                  commit
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
# ...                                                                                                 ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...     NaN
#                                              input_percentage_of_mt_steam_hot_water_building...     NaN
#                                              input_percentage_of_ht_steam_hot_water_building...     NaN
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...     NaN
#                                              input_percentage_of_ht_steam_hot_water_agricult...     NaN
#
# [770 rows x 3 columns]

# %% [markdown]
# ##### Load parent data

# %%
# Import parent data
path = Path("data", "intermediate", "parent_data.csv")
df_parent = pd.read_csv(path, index_col=0)

# Preview parent data
df_parent.T.head()
# Out:
#                                                         nl
# agriculture_final_demand_electricity_demand      41584.615
# agriculture_final_demand_network_gas_demand      91072.918
# agriculture_final_demand_steam_hot_water_demand   2783.107
# agriculture_final_demand_wood_pellets_demand      5437.224
# input_agriculture_final_demand_crude_oil_demand  17965.442

# %% [markdown]
# #### Energy demand
# Transform the energy demand data to the right format.

# %% [markdown]
# ##### List ETLocal keys

# %% [markdown]
# Preview the ETLocal keys that are relevant for the services energy demand category

# %%
# Filter the ETLocal keys that are relevant for the services energy demand category
filter_buildings_demand = (slice(None), 'buildings', 'buildings_energy_demand')

# Preview the filtered template
template.loc[filter_buildings_demand, :]
# Out:
#                                                                                             unit  \
# geo_id group     subgroup                key
# GM1896 buildings buildings_energy_demand input_percentage_of_lt_steam_hot_water_building...    %
#                                          input_percentage_of_mt_steam_hot_water_building...    %
#                                          input_percentage_of_ht_steam_hot_water_building...    %
#
#                                                                                              value  \
# geo_id group     subgroup                key
# GM1896 buildings buildings_energy_demand input_percentage_of_lt_steam_hot_water_building...    0.0
#                                          input_percentage_of_mt_steam_hot_water_building...    0.0
#                                          input_percentage_of_ht_steam_hot_water_building...    1.0
#
#                                                                                                                                         commit
# geo_id group     subgroup                key
# GM1896 buildings buildings_energy_demand input_percentage_of_lt_steam_hot_water_building...  No data available. Fallback value set to 0.0 t...
#                                          input_percentage_of_mt_steam_hot_water_building...  No data available. Fallback value set to 0.0 t...
#                                          input_percentage_of_ht_steam_hot_water_building...  No data available. Fallback value set to 1.0 t...

# %% [markdown]
# ##### Fill missing values

# %% [markdown]
# Then, fill the missing values for:
# - Temperature levels of district heating networks
# - ...

# %% [markdown]
# **Temperature levels of district heating networks** | Klimaatmonitor doesn't provide any data about the demand of district heating networks per temperature level. Hence, we assume that all residential district heating networks require MT heat.

# %%
# TODO: we could also use the parent data shares instead?
for temperature_level in ['lt', 'mt', 'ht']:
    key = f'input_percentage_of_{temperature_level}_steam_hot_water_buildings_final_demand_steam_hot_water'
    
    val = 0.
    
    if temperature_level == 'ht':
        val = 1.
    
    # Update value and corresponding commit message for the temperature level share
    template.loc[(slice(None), slice(None), slice(None), key), 'value'] = val
    template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"No data available. Fallback value set to {val} to ensure share totals sum to 1."

# %%
# Preview template after changes
template.loc[filter_buildings_demand, :].head()
# Out:
#                                                                                             unit  \
# geo_id group     subgroup                key
# GM1896 buildings buildings_energy_demand input_percentage_of_lt_steam_hot_water_building...    %
#                                          input_percentage_of_mt_steam_hot_water_building...    %
#                                          input_percentage_of_ht_steam_hot_water_building...    %
#
#                                                                                              value  \
# geo_id group     subgroup                key
# GM1896 buildings buildings_energy_demand input_percentage_of_lt_steam_hot_water_building...    0.0
#                                          input_percentage_of_mt_steam_hot_water_building...    0.0
#                                          input_percentage_of_ht_steam_hot_water_building...    1.0
#
#                                                                                                                                         commit
# geo_id group     subgroup                key
# GM1896 buildings buildings_energy_demand input_percentage_of_lt_steam_hot_water_building...  No data available. Fallback value set to 0.0 t...
#                                          input_percentage_of_mt_steam_hot_water_building...  No data available. Fallback value set to 0.0 t...
#                                          input_percentage_of_ht_steam_hot_water_building...  No data available. Fallback value set to 1.0 t...

# %% [markdown]
# ### 4. Data analysis and visualisation

# %%
# TODO

# %% [markdown]
# ## Agriculture

# %% [markdown]
# ### 1. Data collection

# %%
# TODO

# %% [markdown]
# In the data collection phase, we make an overview of the required data and design a data model to efficiently build our database. If possible, we call the API to collect our data. Otherwise, we first manually collect a data export and store it in the `data / raw` directory.
#
# ![image.png](attachment:75b96a93-92f4-444a-9a96-18eb4a6d5295.png)
#
# For the municipal datasets we use the following data sources:
# * **??** | ...
# * **Dataset manager** | to collect the parent dataset
#
# For each data source, the following steps are followed:
# * **Extract** | Extracting the raw data from its source
# * **Transform** | Transforming the raw data to a 'workable' format
# * **Load** | Writing the processed data to the intermediate data directory

# %%
# TODO

# %% [markdown]
# #### ETM dataset manager (parent dataset)

# %% [markdown]
# In case certain data points are not available for the given region, we want to inherit the values of the parent dataset. For the municipality datasets, the parent is the NL2019 dataset.

# %% [markdown]
# ##### Extract
# In this step we call the ETM Dataset Manager API to get the parent dataset.

# %%
# Connect to the ETM dataset manager API and collect the parent dataset 
response = requests.get(f"https://data.energytransitionmodel.com/api/v1/exports/{parent}")

# %%
# Check if the response has been successful. If the code is anything else than 200, something went wrong.
response.status_code
# Out:
# 200

# %% [markdown]
# Here is an overview of the different status codes and what these imply:
#
# - **200**: Everything went okay, and the result has been returned (if any).
# - **301**: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# - **400**: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
# - **401**: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t send the right credentials to access an API.
# - **403**: The resource you’re trying to access is forbidden: you don’t have the right perlessons to see it.
# - **404**: The resource you tried to access wasn’t found on the server.
# - **503**: The server is not ready to handle the request.

# %%
# In that case, print the error message to see what caused the error
response.reason
# Out:
# 'OK'

# %% [markdown]
# ##### Transform
# Create a dataframe from the API response in which the parent dataset is included.

# %%
# If the reponse has been successful, collect its data.

# The data is stored as a dict in a single-itemed array. To get the dict, get the first item of the array.
raw_parent_data = response.json()[0]

# Then, create a dataframe from the dict.
df_parent = pd.DataFrame(raw_parent_data, index=[0])

# Rename the index to nl
df_parent = df_parent.rename(index={0: 'nl'})

# %%
# Preview the data in its transposed form (by using .T)
df_parent.T
# Out:
#                                                              nl
# agriculture_final_demand_electricity_demand           41584.615
# agriculture_final_demand_network_gas_demand           91072.918
# agriculture_final_demand_steam_hot_water_demand        2783.107
# agriculture_final_demand_wood_pellets_demand           5437.224
# input_agriculture_final_demand_crude_oil_demand       17965.442
# ...                                                         ...
# input_transport_ship_electricity_demand                     0.0
# bunkers_total_useful_demand_ships_demand             478316.636
# area                                             NL_netherlands
# base_dataset                                                 eu
# group                                                   country
#
# [619 rows x 1 columns]

# %% [markdown]
# ##### Load
# Save the parent data set to the intermediate data folder.

# %%
# Write dataframe to intermediate data folder
df_parent.to_csv(f"data/intermediate/parent_data.csv")

# %% [markdown]
# ### 2. Data quality

# %%
# TODO

# %% [markdown]
# #### Setup
#
# Setup the checker and load all files from the `data / intermediate` directory.

# %% [markdown]
# First, setup the checker class

# %%
# Initialise checker class to access transformation functions
checker = Checker()

# %% [markdown]
# Then, setup all data files:
# - ...
# - parent data

# %% [markdown]
# ### 3. Data transformation

# %%
# TODO

# %% [markdown]
# #### Setup
#
# Setup the transformer and load all intermediate data files for the next step in the pipeline.

# %% [markdown]
# First, setup the transformer class:

# %%
# Initialise transformer class to access transformation functions
transformer = Transformer(municipalities, year)

# %% [markdown]
# Then, setup all data files:
# - dataframe representing data.csv
# - commits.yml
# - dataframe with all etlocal interface elements
# - ...
# - parent data

# %% [markdown]
# ##### Create empty ETLocal templates

# %% [markdown]
# Only run these cells if you want to create empty ETLocal templates. If the templates have been filled in previous steps, these changes will be overwritten. If you don't want to overwrite your changes, **DON'T** run the cells below. :-)

# %%
# First, initialize data.csv file based on the config file
path = Path("config", "data.csv")
df_data_csv = pd.read_csv(path, index_col=[0])

# Drop unnamed columns
df_data_csv = df_data_csv.drop(columns=df_data_csv.columns[df_data_csv.columns.str.startswith('Unnamed')])

# Preview dataframe representing data.csv
df_data_csv
# Out:
#        country             name
# geo_id
# GM0277  nl2019        Rozendaal
# GM0060  nl2019          Ameland
# GM0088  nl2019  Schiermonnikoog
# GM0093  nl2019     Terschelling
# GM0096  nl2019         Vlieland

# %%
# Then, initialize commits.yml file by specifying the file path where you want to create the YAML file
path = Path("data", "reporting", "commits.yml")

# Write the document separator to the YAML file
with open(path, 'w') as file:
    file.write('---\n')

# %%
# TODO: Describe that by running this cell an empty template is created. This overwrites the filled template.

# Load ETLocal template with target keys from config
path = Path("config", "etlocal_interface_elements.csv")
empty_template = pd.read_csv(path, header=[0])#, index_col=[2])

# Add columns geo_id, value and commit to the template    
for column in ['geo_id', 'value', 'commit']:
    empty_template[column] = float('nan')
    
# Fill the geo_id column with all relevant municipal geo IDs
templates = []
for municipality in municipalities:
    template_to_add = empty_template.copy()
    template_to_add['geo_id'] = municipality
    templates.append(template_to_add)
    
# Concatenate list of templates to one big template with all municipalities
template = pd.concat(templates)

# Transform the templates into a multi-index dataframe
index = pd.MultiIndex.from_frame(template[['geo_id', 'group', 'subgroup', 'key']])
template = template.drop(columns=['geo_id', 'group', 'subgroup', 'key'])
template.index = index

# Preview merged template
template
# Out:
#                                                                                                 unit  \
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
# ...                                                                                              ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...    %
#                                              input_percentage_of_mt_steam_hot_water_building...    %
#                                              input_percentage_of_ht_steam_hot_water_building...    %
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    %
#                                              input_percentage_of_ht_steam_hot_water_agricult...    %
#
#                                                                                                  value  \
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
# ...                                                                                                ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...    NaN
#                                              input_percentage_of_mt_steam_hot_water_building...    NaN
#                                              input_percentage_of_ht_steam_hot_water_building...    NaN
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    NaN
#                                              input_percentage_of_ht_steam_hot_water_agricult...    NaN
#
#                                                                                                  commit
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
# ...                                                                                                 ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...     NaN
#                                              input_percentage_of_mt_steam_hot_water_building...     NaN
#                                              input_percentage_of_ht_steam_hot_water_building...     NaN
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...     NaN
#                                              input_percentage_of_ht_steam_hot_water_agricult...     NaN
#
# [770 rows x 3 columns]

# %% [markdown]
# ##### Load parent data

# %%
# Import parent data
path = Path("data", "intermediate", "parent_data.csv")
df_parent = pd.read_csv(path, index_col=0)

# Preview parent data
df_parent.T.head()
# Out:
#                                                         nl
# agriculture_final_demand_electricity_demand      41584.615
# agriculture_final_demand_network_gas_demand      91072.918
# agriculture_final_demand_steam_hot_water_demand   2783.107
# agriculture_final_demand_wood_pellets_demand      5437.224
# input_agriculture_final_demand_crude_oil_demand  17965.442

# %% [markdown]
# #### Energy demand
# Transform the energy demand data from Klimaatmonitor to the right format.

# %% [markdown]
# ##### List ETLocal keys

# %% [markdown]
# Preview the ETLocal keys that are relevant for the agriculture energy demand category

# %%
# Filter the ETLocal keys that are relevant for the agriculture energy demand category
filter_agriculture_demand = (slice(None), 'agriculture', 'agriculture_energy_demand')

# Preview the filtered template
template.loc[filter_agriculture_demand, :]
# Out:
#                                                                                                 unit  \
# geo_id group       subgroup                  key
# GM1896 agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    %
#                                              input_percentage_of_ht_steam_hot_water_agricult...    %
#
#                                                                                                  value  \
# geo_id group       subgroup                  key
# GM1896 agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    NaN
#                                              input_percentage_of_ht_steam_hot_water_agricult...    NaN
#
#                                                                                                 commit
# geo_id group       subgroup                  key
# GM1896 agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    NaN
#                                              input_percentage_of_ht_steam_hot_water_agricult...    NaN

# %% [markdown]
# ##### Fill missing values

# %% [markdown]
# Then, fill the missing values for:
# - Temperature levels of district heating networks
# - ...

# %% [markdown]
# **Temperature levels of district heating networks** | Klimaatmonitor doesn't provide any data about the demand of district heating networks per temperature level. Hence, we assume that all agricultural district heating networks require MT heat.

# %%
# TODO: we could also use the parent data shares instead?
for temperature_level in ['mt', 'ht']:
    key = f'input_percentage_of_central_{temperature_level}_steam_hot_water_agriculture_final_demand_steam_hot_water'
    
    val = 0.
    
    if temperature_level == 'ht':
        val = 1.
    
    # Update value and corresponding commit message for the temperature level share
    template.loc[(slice(None), slice(None), slice(None), key), 'value'] = val
    template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"No data available. Fallback value set to {val} to ensure share totals sum to 1."

# %%
key = f'input_percentage_of_local_steam_hot_water_agriculture_final_demand_steam_hot_water'

val = 0.

# Update value and corresponding commit message for the temperature level share
template.loc[(slice(None), slice(None), slice(None), key), 'value'] = val
template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"No data available. Fallback value set to {val} to ensure share totals sum to 1."

# %%
# Preview template after changes
template.loc[filter_agriculture_demand, :].head()
# Out:
#                                                                                                 unit  \
# geo_id group       subgroup                  key
# GM1896 agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    %
#                                              input_percentage_of_ht_steam_hot_water_agricult...    %
#
#                                                                                                  value  \
# geo_id group       subgroup                  key
# GM1896 agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    0.0
#                                              input_percentage_of_ht_steam_hot_water_agricult...    1.0
#
#                                                                                                                                             commit
# geo_id group       subgroup                  key
# GM1896 agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...  No data available. Fallback value set to 0.0 t...
#                                              input_percentage_of_ht_steam_hot_water_agricult...  No data available. Fallback value set to 1.0 t...

# %% [markdown]
# #### Exceptions
#
# If there are any exceptions for municipal datasets, you can overwrite the values below.

# %% [markdown]
# **TO DO** | Explain to the user that this section should always be checked. Should the exception be overwritten by the update? Or should it remain untouched?

# %% [markdown]
# ##### Gemeente X

# %%
#

# %% [markdown]
# #### Export processed data
# Write the transformed data to our  `data / processed` directory. This is the data we will be using for the next (analysis and visualisation) steps in the pipeline.

# %%
# Write dataframe to intermediate data folder
path = Path("data", "processed", "etlocal_template.csv")
template.to_csv(path)

# %% [markdown]
# ### 4. Data analysis and visualisation

# %%
# TODO

# %% [markdown]
# ## Transport

# %% [markdown]
# ### 1. Data collection

# %%
# TODO

# %% [markdown]
# In the data collection phase, we make an overview of the required data and design a data model to efficiently build our database. If possible, we call the API to collect our data. Otherwise, we first manually collect a data export and store it in the `data / raw` directory.
#
# ![image.png](attachment:75b96a93-92f4-444a-9a96-18eb4a6d5295.png)
#
# For the municipal datasets we use the following data sources:
# * **??** | ...
# * **Dataset manager** | to collect the parent dataset
#
# For each data source, the following steps are followed:
# * **Extract** | Extracting the raw data from its source
# * **Transform** | Transforming the raw data to a 'workable' format
# * **Load** | Writing the processed data to the intermediate data directory

# %%
# TODO

# %% [markdown]
# #### ETM dataset manager (parent dataset)

# %% [markdown]
# In case certain data points are not available for the given region, we want to inherit the values of the parent dataset. For the municipality datasets, the parent is the NL2019 dataset.

# %% [markdown]
# ##### Extract
# In this step we call the ETM Dataset Manager API to get the parent dataset.

# %%
# Connect to the ETM dataset manager API and collect the parent dataset 
response = requests.get(f"https://data.energytransitionmodel.com/api/v1/exports/{parent}")

# %%
# Check if the response has been successful. If the code is anything else than 200, something went wrong.
response.status_code
# Out:
# 200

# %% [markdown]
# Here is an overview of the different status codes and what these imply:
#
# - **200**: Everything went okay, and the result has been returned (if any).
# - **301**: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# - **400**: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
# - **401**: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t send the right credentials to access an API.
# - **403**: The resource you’re trying to access is forbidden: you don’t have the right perlessons to see it.
# - **404**: The resource you tried to access wasn’t found on the server.
# - **503**: The server is not ready to handle the request.

# %%
# In that case, print the error message to see what caused the error
response.reason
# Out:
# 'OK'

# %% [markdown]
# ##### Transform
# Create a dataframe from the API response in which the parent dataset is included.

# %%
# If the reponse has been successful, collect its data.

# The data is stored as a dict in a single-itemed array. To get the dict, get the first item of the array.
raw_parent_data = response.json()[0]

# Then, create a dataframe from the dict.
df_parent = pd.DataFrame(raw_parent_data, index=[0])

# Rename the index to nl
df_parent = df_parent.rename(index={0: 'nl'})

# %%
# Preview the data in its transposed form (by using .T)
df_parent.T
# Out:
#                                                              nl
# agriculture_final_demand_electricity_demand           41584.615
# agriculture_final_demand_network_gas_demand           91072.918
# agriculture_final_demand_steam_hot_water_demand        2783.107
# agriculture_final_demand_wood_pellets_demand           5437.224
# input_agriculture_final_demand_crude_oil_demand       17965.442
# ...                                                         ...
# input_transport_ship_electricity_demand                     0.0
# bunkers_total_useful_demand_ships_demand             478316.636
# area                                             NL_netherlands
# base_dataset                                                 eu
# group                                                   country
#
# [619 rows x 1 columns]

# %% [markdown]
# ##### Load
# Save the parent data set to the intermediate data folder.

# %%
# Write dataframe to intermediate data folder
df_parent.to_csv(f"data/intermediate/parent_data.csv")

# %% [markdown]
# ### 2. Data quality

# %%
# TODO

# %% [markdown]
# #### Setup
#
# Setup the checker and load all files from the `data / intermediate` directory.

# %% [markdown]
# First, setup the checker class

# %%
# Initialise checker class to access transformation functions
checker = Checker()

# %% [markdown]
# Then, setup all data files:
# - ...
# - parent data

# %% [markdown]
# ### 3. Data transformation

# %%
# TODO

# %% [markdown]
# #### Setup
#
# Setup the transformer and load all intermediate data files for the next step in the pipeline.

# %% [markdown]
# First, setup the transformer class:

# %%
# Initialise transformer class to access transformation functions
transformer = Transformer(municipalities, year)

# %% [markdown]
# Then, setup all data files:
# - dataframe representing data.csv
# - commits.yml
# - dataframe with all etlocal interface elements
# - ...
# - parent data

# %% [markdown]
# ##### Create empty ETLocal templates

# %% [markdown]
# Only run these cells if you want to create empty ETLocal templates. If the templates have been filled in previous steps, these changes will be overwritten. If you don't want to overwrite your changes, **DON'T** run the cells below. :-)

# %%
# First, initialize data.csv file based on the config file
path = Path("config", "data.csv")
df_data_csv = pd.read_csv(path, index_col=[0])

# Drop unnamed columns
df_data_csv = df_data_csv.drop(columns=df_data_csv.columns[df_data_csv.columns.str.startswith('Unnamed')])

# Preview dataframe representing data.csv
df_data_csv
# Out:
#        country             name
# geo_id
# GM0277  nl2019        Rozendaal
# GM0060  nl2019          Ameland
# GM0088  nl2019  Schiermonnikoog
# GM0093  nl2019     Terschelling
# GM0096  nl2019         Vlieland

# %%
# Then, initialize commits.yml file by specifying the file path where you want to create the YAML file
path = Path("data", "reporting", "commits.yml")

# Write the document separator to the YAML file
with open(path, 'w') as file:
    file.write('---\n')

# %%
# TODO: Describe that by running this cell an empty template is created. This overwrites the filled template.

# Load ETLocal template with target keys from config
path = Path("config", "etlocal_interface_elements.csv")
empty_template = pd.read_csv(path, header=[0])#, index_col=[2])

# Add columns geo_id, value and commit to the template    
for column in ['geo_id', 'value', 'commit']:
    empty_template[column] = float('nan')
    
# Fill the geo_id column with all relevant municipal geo IDs
templates = []
for municipality in municipalities:
    template_to_add = empty_template.copy()
    template_to_add['geo_id'] = municipality
    templates.append(template_to_add)
    
# Concatenate list of templates to one big template with all municipalities
template = pd.concat(templates)

# Transform the templates into a multi-index dataframe
index = pd.MultiIndex.from_frame(template[['geo_id', 'group', 'subgroup', 'key']])
template = template.drop(columns=['geo_id', 'group', 'subgroup', 'key'])
template.index = index

# Preview merged template
template
# Out:
#                                                                                                 unit  \
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
# ...                                                                                              ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...    %
#                                              input_percentage_of_mt_steam_hot_water_building...    %
#                                              input_percentage_of_ht_steam_hot_water_building...    %
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    %
#                                              input_percentage_of_ht_steam_hot_water_agricult...    %
#
#                                                                                                  value  \
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
# ...                                                                                                ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...    NaN
#                                              input_percentage_of_mt_steam_hot_water_building...    NaN
#                                              input_percentage_of_ht_steam_hot_water_building...    NaN
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    NaN
#                                              input_percentage_of_ht_steam_hot_water_agricult...    NaN
#
#                                                                                                  commit
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
# ...                                                                                                 ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...     NaN
#                                              input_percentage_of_mt_steam_hot_water_building...     NaN
#                                              input_percentage_of_ht_steam_hot_water_building...     NaN
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...     NaN
#                                              input_percentage_of_ht_steam_hot_water_agricult...     NaN
#
# [770 rows x 3 columns]

# %% [markdown]
# ##### Load parent data

# %%
# Import parent data
path = Path("data", "intermediate", "parent_data.csv")
df_parent = pd.read_csv(path, index_col=0)

# Preview parent data
df_parent.T.head()
# Out:
#                                                         nl
# agriculture_final_demand_electricity_demand      41584.615
# agriculture_final_demand_network_gas_demand      91072.918
# agriculture_final_demand_steam_hot_water_demand   2783.107
# agriculture_final_demand_wood_pellets_demand      5437.224
# input_agriculture_final_demand_crude_oil_demand  17965.442

# %% [markdown]
# #### Energy demand
# Transform the energy demand data from Klimaatmonitor to the right format.

# %% [markdown]
# ##### List ETLocal keys

# %% [markdown]
# Preview the ETLocal keys that are relevant for the transport energy demand category

# %%
# Filter the ETLocal keys that are relevant for the agriculture energy demand category
filter_transport_demand = (slice(None), 'transport', 'transport_energy_demand')

# Preview the filtered template
template.loc[filter_transport_demand, :]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transport'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 5
#       2 filter_transport_demand = (slice(None), 'transport', 'transport_energy_demand')
#       4 # Preview the filtered template
# ----> 5 template.loc[filter_transport_demand, :]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
#    1283 tup = self._validate_tuple_indexer(tup)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexing.py:976, in _LocationIndexer._getitem_lowerdim(self, tup)
#     974 # we may have a nested tuples indexer here
#     975 if self._is_nested_tuple_indexer(tup):
# --> 976     return self._getitem_nested_tuple(tup)
#     978 # we maybe be using a tuple to represent multiple dimensions here
#     979 ax0 = self.obj._get_axis(0)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexing.py:1077, in _LocationIndexer._getitem_nested_tuple(self, tup)
#    1074     axis -= 1
#    1075     continue
# -> 1077 obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1078 axis -= 1
#    1080 # if we have a scalar, we are done
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexing.py:1336, in _LocIndexer._getitem_axis(self, key, axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
# -> 1336     locs = labels.get_locs(key)
#    1337     indexer = [slice(None)] * self.ndim
#    1338     indexer[axis] = locs
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3303, in MultiIndex.get_locs(self, seq)
#    3299     continue
#    3301 else:
#    3302     # a slice or a single label
# -> 3303     lvl_indexer = self._get_level_indexer(k, level=i, indexer=indexer)
#    3305 # update indexer
#    3306 lvl_indexer = _to_bool_indexer(lvl_indexer)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3160, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3157         return slice(i, j, step)
#    3159 else:
# -> 3160     idx = self._get_loc_single_level_index(level_index, key)
#    3162     if level > 0 or self._lexsort_depth == 0:
#    3163         # Desired level is not sorted
#    3164         if isinstance(idx, slice):
#    3165             # test_get_loc_partial_timestamp_multiindex
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/multi.py:2752, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2750     return -1
#    2751 else:
# -> 2752     return level_index.get_loc(key)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'transport'

# %% [markdown]
# ##### Fill missing values

# %% [markdown]
# Then, fill the missing values for:
# - ...

# %% [markdown]
# **??** | ..

# %%
# Preview template after changes
template.loc[filter_transport_demand, :].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /usr/local/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transport'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Preview template after changes
# ----> 2 template.loc[filter_transport_demand, :].head()
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
#    1283 tup = self._validate_tuple_indexer(tup)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexing.py:976, in _LocationIndexer._getitem_lowerdim(self, tup)
#     974 # we may have a nested tuples indexer here
#     975 if self._is_nested_tuple_indexer(tup):
# --> 976     return self._getitem_nested_tuple(tup)
#     978 # we maybe be using a tuple to represent multiple dimensions here
#     979 ax0 = self.obj._get_axis(0)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexing.py:1077, in _LocationIndexer._getitem_nested_tuple(self, tup)
#    1074     axis -= 1
#    1075     continue
# -> 1077 obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1078 axis -= 1
#    1080 # if we have a scalar, we are done
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexing.py:1336, in _LocIndexer._getitem_axis(self, key, axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
# -> 1336     locs = labels.get_locs(key)
#    1337     indexer = [slice(None)] * self.ndim
#    1338     indexer[axis] = locs
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3303, in MultiIndex.get_locs(self, seq)
#    3299     continue
#    3301 else:
#    3302     # a slice or a single label
# -> 3303     lvl_indexer = self._get_level_indexer(k, level=i, indexer=indexer)
#    3305 # update indexer
#    3306 lvl_indexer = _to_bool_indexer(lvl_indexer)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3160, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3157         return slice(i, j, step)
#    3159 else:
# -> 3160     idx = self._get_loc_single_level_index(level_index, key)
#    3162     if level > 0 or self._lexsort_depth == 0:
#    3163         # Desired level is not sorted
#    3164         if isinstance(idx, slice):
#    3165             # test_get_loc_partial_timestamp_multiindex
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/multi.py:2752, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2750     return -1
#    2751 else:
# -> 2752     return level_index.get_loc(key)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'transport'

# %% [markdown]
# #### Exceptions
#
# If there are any exceptions for municipal datasets, you can overwrite the values below.

# %% [markdown]
# **TO DO** | Explain to the user that this section should always be checked. Should the exception be overwritten by the update? Or should it remain untouched?

# %% [markdown]
# ##### Gemeente X

# %%
#

# %% [markdown]
# #### Export processed data
# Write the transformed data to our  `data / processed` directory. This is the data we will be using for the next (analysis and visualisation) steps in the pipeline.

# %%
# Write dataframe to intermediate data folder
path = Path("data", "processed", "etlocal_template.csv")
template.to_csv(path)

# %% [markdown]
# ### 4. Data analysis and visualisation

# %%
# TODO

# %% [markdown]
# ## Industry

# %%
# TODO

# %% [markdown]
# ### 1. Data collection

# %%
# TODO

# %% [markdown]
# In the data collection phase, we make an overview of the required data and design a data model to efficiently build our database. If possible, we call the API to collect our data. Otherwise, we first manually collect a data export and store it in the `data / raw` directory.
#
# ![image.png](attachment:75b96a93-92f4-444a-9a96-18eb4a6d5295.png)
#
# For the municipal datasets we use the following data sources:
# * **??** | ...
# * **Dataset manager** | to collect the parent dataset
#
# For each data source, the following steps are followed:
# * **Extract** | Extracting the raw data from its source
# * **Transform** | Transforming the raw data to a 'workable' format
# * **Load** | Writing the processed data to the intermediate data directory

# %%
# TODO

# %% [markdown]
# #### ETM dataset manager (parent dataset)

# %% [markdown]
# In case certain data points are not available for the given region, we want to inherit the values of the parent dataset. For the municipality datasets, the parent is the NL2019 dataset.

# %% [markdown]
# ##### Extract
# In this step we call the ETM Dataset Manager API to get the parent dataset.

# %%
# Connect to the ETM dataset manager API and collect the parent dataset 
response = requests.get(f"https://data.energytransitionmodel.com/api/v1/exports/{parent}")

# %%
# Check if the response has been successful. If the code is anything else than 200, something went wrong.
response.status_code
# Out:
# 200

# %% [markdown]
# Here is an overview of the different status codes and what these imply:
#
# - **200**: Everything went okay, and the result has been returned (if any).
# - **301**: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# - **400**: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
# - **401**: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t send the right credentials to access an API.
# - **403**: The resource you’re trying to access is forbidden: you don’t have the right perlessons to see it.
# - **404**: The resource you tried to access wasn’t found on the server.
# - **503**: The server is not ready to handle the request.

# %%
# In that case, print the error message to see what caused the error
response.reason
# Out:
# 'OK'

# %% [markdown]
# ##### Transform
# Create a dataframe from the API response in which the parent dataset is included.

# %%
# If the reponse has been successful, collect its data.

# The data is stored as a dict in a single-itemed array. To get the dict, get the first item of the array.
raw_parent_data = response.json()[0]

# Then, create a dataframe from the dict.
df_parent = pd.DataFrame(raw_parent_data, index=[0])

# Rename the index to nl
df_parent = df_parent.rename(index={0: 'nl'})

# %%
# Preview the data in its transposed form (by using .T)
df_parent.T
# Out:
#                                                              nl
# agriculture_final_demand_electricity_demand           41584.615
# agriculture_final_demand_network_gas_demand           91072.918
# agriculture_final_demand_steam_hot_water_demand        2783.107
# agriculture_final_demand_wood_pellets_demand           5437.224
# input_agriculture_final_demand_crude_oil_demand       17965.442
# ...                                                         ...
# input_transport_ship_electricity_demand                     0.0
# bunkers_total_useful_demand_ships_demand             478316.636
# area                                             NL_netherlands
# base_dataset                                                 eu
# group                                                   country
#
# [619 rows x 1 columns]

# %% [markdown]
# ##### Load
# Save the parent data set to the intermediate data folder.

# %%
# Write dataframe to intermediate data folder
df_parent.to_csv(f"data/intermediate/parent_data.csv")

# %% [markdown]
# ### 2. Data quality

# %%
# TODO

# %% [markdown]
# #### Setup
#
# Setup the checker and load all files from the `data / intermediate` directory.

# %% [markdown]
# First, setup the checker class

# %%
# Initialise checker class to access transformation functions
checker = Checker()

# %% [markdown]
# Then, setup all data files:
# - ...
# - parent data

# %% [markdown]
# ### 3. Data transformation

# %%
# TODO

# %% [markdown]
# #### Setup
#
# Setup the transformer and load all intermediate data files for the next step in the pipeline.

# %% [markdown]
# First, setup the transformer class:

# %%
# Initialise transformer class to access transformation functions
transformer = Transformer(municipalities, year)

# %% [markdown]
# Then, setup all data files:
# - dataframe representing data.csv
# - commits.yml
# - dataframe with all etlocal interface elements
# - ...
# - parent data

# %% [markdown]
# ##### Create empty ETLocal templates

# %% [markdown]
# Only run these cells if you want to create empty ETLocal templates. If the templates have been filled in previous steps, these changes will be overwritten. If you don't want to overwrite your changes, **DON'T** run the cells below. :-)

# %%
# First, initialize data.csv file based on the config file
path = Path("config", "data.csv")
df_data_csv = pd.read_csv(path, index_col=[0])

# Drop unnamed columns
df_data_csv = df_data_csv.drop(columns=df_data_csv.columns[df_data_csv.columns.str.startswith('Unnamed')])

# Preview dataframe representing data.csv
df_data_csv
# Out:
#        country             name
# geo_id
# GM0277  nl2019        Rozendaal
# GM0060  nl2019          Ameland
# GM0088  nl2019  Schiermonnikoog
# GM0093  nl2019     Terschelling
# GM0096  nl2019         Vlieland

# %%
# Then, initialize commits.yml file by specifying the file path where you want to create the YAML file
path = Path("data", "reporting", "commits.yml")

# Write the document separator to the YAML file
with open(path, 'w') as file:
    file.write('---\n')

# %%
# TODO: Describe that by running this cell an empty template is created. This overwrites the filled template.

# Load ETLocal template with target keys from config
path = Path("config", "etlocal_interface_elements.csv")
empty_template = pd.read_csv(path, header=[0])#, index_col=[2])

# Add columns geo_id, value and commit to the template    
for column in ['geo_id', 'value', 'commit']:
    empty_template[column] = float('nan')
    
# Fill the geo_id column with all relevant municipal geo IDs
templates = []
for municipality in municipalities:
    template_to_add = empty_template.copy()
    template_to_add['geo_id'] = municipality
    templates.append(template_to_add)
    
# Concatenate list of templates to one big template with all municipalities
template = pd.concat(templates)

# Transform the templates into a multi-index dataframe
index = pd.MultiIndex.from_frame(template[['geo_id', 'group', 'subgroup', 'key']])
template = template.drop(columns=['geo_id', 'group', 'subgroup', 'key'])
template.index = index

# Preview merged template
template
# Out:
#                                                                                                 unit  \
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
# ...                                                                                              ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...    %
#                                              input_percentage_of_mt_steam_hot_water_building...    %
#                                              input_percentage_of_ht_steam_hot_water_building...    %
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    %
#                                              input_percentage_of_ht_steam_hot_water_agricult...    %
#
#                                                                                                  value  \
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
# ...                                                                                                ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...    NaN
#                                              input_percentage_of_mt_steam_hot_water_building...    NaN
#                                              input_percentage_of_ht_steam_hot_water_building...    NaN
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    NaN
#                                              input_percentage_of_ht_steam_hot_water_agricult...    NaN
#
#                                                                                                  commit
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
# ...                                                                                                 ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...     NaN
#                                              input_percentage_of_mt_steam_hot_water_building...     NaN
#                                              input_percentage_of_ht_steam_hot_water_building...     NaN
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...     NaN
#                                              input_percentage_of_ht_steam_hot_water_agricult...     NaN
#
# [770 rows x 3 columns]

# %% [markdown]
# ##### Load parent data

# %%
# Import parent data
path = Path("data", "intermediate", "parent_data.csv")
df_parent = pd.read_csv(path, index_col=0)

# Preview parent data
df_parent.T.head()
# Out:
#                                                         nl
# agriculture_final_demand_electricity_demand      41584.615
# agriculture_final_demand_network_gas_demand      91072.918
# agriculture_final_demand_steam_hot_water_demand   2783.107
# agriculture_final_demand_wood_pellets_demand      5437.224
# input_agriculture_final_demand_crude_oil_demand  17965.442

# %% [markdown]
# #### Energy demand
# Transform the energy demand data from Klimaatmonitor to the right format.

# %% [markdown]
# ##### List ETLocal keys

# %% [markdown]
# Preview the ETLocal keys that are relevant for the industry energy demand category

# %%
# Filter the ETLocal keys that are relevant for the industry energy demand category
filter_industry_demand = (slice(None), 'industry', 'industry_energy_demand')

# Preview the filtered template
template.loc[filter_industry_demand, :]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'industry'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 5
#       2 filter_industry_demand = (slice(None), 'industry', 'industry_energy_demand')
#       4 # Preview the filtered template
# ----> 5 template.loc[filter_industry_demand, :]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
#    1283 tup = self._validate_tuple_indexer(tup)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexing.py:976, in _LocationIndexer._getitem_lowerdim(self, tup)
#     974 # we may have a nested tuples indexer here
#     975 if self._is_nested_tuple_indexer(tup):
# --> 976     return self._getitem_nested_tuple(tup)
#     978 # we maybe be using a tuple to represent multiple dimensions here
#     979 ax0 = self.obj._get_axis(0)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexing.py:1077, in _LocationIndexer._getitem_nested_tuple(self, tup)
#    1074     axis -= 1
#    1075     continue
# -> 1077 obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1078 axis -= 1
#    1080 # if we have a scalar, we are done
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexing.py:1336, in _LocIndexer._getitem_axis(self, key, axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
# -> 1336     locs = labels.get_locs(key)
#    1337     indexer = [slice(None)] * self.ndim
#    1338     indexer[axis] = locs
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3303, in MultiIndex.get_locs(self, seq)
#    3299     continue
#    3301 else:
#    3302     # a slice or a single label
# -> 3303     lvl_indexer = self._get_level_indexer(k, level=i, indexer=indexer)
#    3305 # update indexer
#    3306 lvl_indexer = _to_bool_indexer(lvl_indexer)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3160, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3157         return slice(i, j, step)
#    3159 else:
# -> 3160     idx = self._get_loc_single_level_index(level_index, key)
#    3162     if level > 0 or self._lexsort_depth == 0:
#    3163         # Desired level is not sorted
#    3164         if isinstance(idx, slice):
#    3165             # test_get_loc_partial_timestamp_multiindex
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/multi.py:2752, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2750     return -1
#    2751 else:
# -> 2752     return level_index.get_loc(key)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'industry'

# %% [markdown]
# ##### Fill missing values

# %% [markdown]
# Then, fill the missing values for:
# - ...

# %% [markdown]
# **??** | ..

# %%
# Preview template after changes
template.loc[filter_industry_demand, :].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /usr/local/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transport'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Preview template after changes
# ----> 2 template.loc[filter_transport_demand, :].head()
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
#    1283 tup = self._validate_tuple_indexer(tup)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexing.py:976, in _LocationIndexer._getitem_lowerdim(self, tup)
#     974 # we may have a nested tuples indexer here
#     975 if self._is_nested_tuple_indexer(tup):
# --> 976     return self._getitem_nested_tuple(tup)
#     978 # we maybe be using a tuple to represent multiple dimensions here
#     979 ax0 = self.obj._get_axis(0)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexing.py:1077, in _LocationIndexer._getitem_nested_tuple(self, tup)
#    1074     axis -= 1
#    1075     continue
# -> 1077 obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1078 axis -= 1
#    1080 # if we have a scalar, we are done
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexing.py:1336, in _LocIndexer._getitem_axis(self, key, axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
# -> 1336     locs = labels.get_locs(key)
#    1337     indexer = [slice(None)] * self.ndim
#    1338     indexer[axis] = locs
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3303, in MultiIndex.get_locs(self, seq)
#    3299     continue
#    3301 else:
#    3302     # a slice or a single label
# -> 3303     lvl_indexer = self._get_level_indexer(k, level=i, indexer=indexer)
#    3305 # update indexer
#    3306 lvl_indexer = _to_bool_indexer(lvl_indexer)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3160, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3157         return slice(i, j, step)
#    3159 else:
# -> 3160     idx = self._get_loc_single_level_index(level_index, key)
#    3162     if level > 0 or self._lexsort_depth == 0:
#    3163         # Desired level is not sorted
#    3164         if isinstance(idx, slice):
#    3165             # test_get_loc_partial_timestamp_multiindex
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/multi.py:2752, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2750     return -1
#    2751 else:
# -> 2752     return level_index.get_loc(key)
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'transport'

# %% [markdown]
# #### Exceptions
#
# If there are any exceptions for municipal datasets, you can overwrite the values below.

# %% [markdown]
# **TO DO** | Explain to the user that this section should always be checked. Should the exception be overwritten by the update? Or should it remain untouched?

# %% [markdown]
# ##### Gemeente X

# %%
#

# %% [markdown]
# #### Export processed data
# Write the transformed data to our  `data / processed` directory. This is the data we will be using for the next (analysis and visualisation) steps in the pipeline.

# %%
# Write dataframe to intermediate data folder
path = Path("data", "processed", "etlocal_template.csv")
template.to_csv(path)

# %% [markdown]
# ### 4. Data analysis and visualisation

# %%
# TODO

# %% [markdown]
# ## Energy production

# %%
# TODO

# %% [markdown]
# ### 1. Data collection

# %%
# TODO

# %% [markdown]
# In the data collection phase, we make an overview of the required data and design a data model to efficiently build our database. If possible, we call the API to collect our data. Otherwise, we first manually collect a data export and store it in the `data / raw` directory.
#
# ![image.png](attachment:75b96a93-92f4-444a-9a96-18eb4a6d5295.png)
#
# For the municipal datasets we use the following data sources:
# * **??** | ...
# * **Dataset manager** | to collect the parent dataset
#
# For each data source, the following steps are followed:
# * **Extract** | Extracting the raw data from its source
# * **Transform** | Transforming the raw data to a 'workable' format
# * **Load** | Writing the processed data to the intermediate data directory

# %%
# TODO

# %% [markdown]
# #### ETM dataset manager (parent dataset)

# %% [markdown]
# In case certain data points are not available for the given region, we want to inherit the values of the parent dataset. For the municipality datasets, the parent is the NL2019 dataset.

# %% [markdown]
# ##### Extract
# In this step we call the ETM Dataset Manager API to get the parent dataset.

# %%
# Connect to the ETM dataset manager API and collect the parent dataset 
response = requests.get(f"https://data.energytransitionmodel.com/api/v1/exports/{parent}")

# %%
# Check if the response has been successful. If the code is anything else than 200, something went wrong.
response.status_code
# Out:
# 200

# %% [markdown]
# Here is an overview of the different status codes and what these imply:
#
# - **200**: Everything went okay, and the result has been returned (if any).
# - **301**: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# - **400**: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
# - **401**: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t send the right credentials to access an API.
# - **403**: The resource you’re trying to access is forbidden: you don’t have the right perlessons to see it.
# - **404**: The resource you tried to access wasn’t found on the server.
# - **503**: The server is not ready to handle the request.

# %%
# In that case, print the error message to see what caused the error
response.reason
# Out:
# 'OK'

# %% [markdown]
# ##### Transform
# Create a dataframe from the API response in which the parent dataset is included.

# %%
# If the reponse has been successful, collect its data.

# The data is stored as a dict in a single-itemed array. To get the dict, get the first item of the array.
raw_parent_data = response.json()[0]

# Then, create a dataframe from the dict.
df_parent = pd.DataFrame(raw_parent_data, index=[0])

# Rename the index to nl
df_parent = df_parent.rename(index={0: 'nl'})

# %%
# Preview the data in its transposed form (by using .T)
df_parent.T
# Out:
#                                                              nl
# agriculture_final_demand_electricity_demand           41584.615
# agriculture_final_demand_network_gas_demand           91072.918
# agriculture_final_demand_steam_hot_water_demand        2783.107
# agriculture_final_demand_wood_pellets_demand           5437.224
# input_agriculture_final_demand_crude_oil_demand       17965.442
# ...                                                         ...
# input_transport_ship_electricity_demand                     0.0
# bunkers_total_useful_demand_ships_demand             478316.636
# area                                             NL_netherlands
# base_dataset                                                 eu
# group                                                   country
#
# [619 rows x 1 columns]

# %% [markdown]
# ##### Load
# Save the parent data set to the intermediate data folder.

# %%
# Write dataframe to intermediate data folder
df_parent.to_csv(f"data/intermediate/parent_data.csv")

# %% [markdown]
# ### 2. Data quality

# %%
# TODO

# %% [markdown]
# #### Setup
#
# Setup the checker and load all files from the `data / intermediate` directory.

# %% [markdown]
# First, setup the checker class

# %%
# Initialise checker class to access transformation functions
checker = Checker()

# %% [markdown]
# Then, setup all data files:
# - ...
# - parent data

# %% [markdown]
# ### 3. Data transformation

# %%
# TODO

# %% [markdown]
# #### Setup
#
# Setup the transformer and load all intermediate data files for the next step in the pipeline.

# %% [markdown]
# First, setup the transformer class:

# %%
# Initialise transformer class to access transformation functions
transformer = Transformer(municipalities, year)

# %% [markdown]
# Then, setup all data files:
# - dataframe representing data.csv
# - commits.yml
# - dataframe with all etlocal interface elements
# - ...
# - parent data

# %% [markdown]
# ##### Create empty ETLocal templates

# %% [markdown]
# Only run these cells if you want to create empty ETLocal templates. If the templates have been filled in previous steps, these changes will be overwritten. If you don't want to overwrite your changes, **DON'T** run the cells below. :-)

# %%
# First, initialize data.csv file based on the config file
path = Path("config", "data.csv")
df_data_csv = pd.read_csv(path, index_col=[0])

# Drop unnamed columns
df_data_csv = df_data_csv.drop(columns=df_data_csv.columns[df_data_csv.columns.str.startswith('Unnamed')])

# Preview dataframe representing data.csv
df_data_csv
# Out:
#        country             name
# geo_id
# GM0277  nl2019        Rozendaal
# GM0060  nl2019          Ameland
# GM0088  nl2019  Schiermonnikoog
# GM0093  nl2019     Terschelling
# GM0096  nl2019         Vlieland

# %%
# Then, initialize commits.yml file by specifying the file path where you want to create the YAML file
path = Path("data", "reporting", "commits.yml")

# Write the document separator to the YAML file
with open(path, 'w') as file:
    file.write('---\n')

# %%
# TODO: Describe that by running this cell an empty template is created. This overwrites the filled template.

# Load ETLocal template with target keys from config
path = Path("config", "etlocal_interface_elements.csv")
empty_template = pd.read_csv(path, header=[0])#, index_col=[2])

# Add columns geo_id, value and commit to the template    
for column in ['geo_id', 'value', 'commit']:
    empty_template[column] = float('nan')
    
# Fill the geo_id column with all relevant municipal geo IDs
templates = []
for municipality in municipalities:
    template_to_add = empty_template.copy()
    template_to_add['geo_id'] = municipality
    templates.append(template_to_add)
    
# Concatenate list of templates to one big template with all municipalities
template = pd.concat(templates)

# Transform the templates into a multi-index dataframe
index = pd.MultiIndex.from_frame(template[['geo_id', 'group', 'subgroup', 'key']])
template = template.drop(columns=['geo_id', 'group', 'subgroup', 'key'])
template.index = index

# Preview merged template
template
# Out:
#                                                                                                 unit  \
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
#                                              households_final_demand_electricity_households_...    %
# ...                                                                                              ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...    %
#                                              input_percentage_of_mt_steam_hot_water_building...    %
#                                              input_percentage_of_ht_steam_hot_water_building...    %
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    %
#                                              input_percentage_of_ht_steam_hot_water_agricult...    %
#
#                                                                                                  value  \
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
#                                              households_final_demand_electricity_households_...    NaN
# ...                                                                                                ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...    NaN
#                                              input_percentage_of_mt_steam_hot_water_building...    NaN
#                                              input_percentage_of_ht_steam_hot_water_building...    NaN
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...    NaN
#                                              input_percentage_of_ht_steam_hot_water_agricult...    NaN
#
#                                                                                                  commit
# geo_id group       subgroup                  key
# GM0277 households  households_applications   households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
#                                              households_final_demand_electricity_households_...     NaN
# ...                                                                                                 ...
# GM0096 buildings   buildings_energy_demand   input_percentage_of_lt_steam_hot_water_building...     NaN
#                                              input_percentage_of_mt_steam_hot_water_building...     NaN
#                                              input_percentage_of_ht_steam_hot_water_building...     NaN
#        agriculture agriculture_energy_demand input_percentage_of_mt_steam_hot_water_agricult...     NaN
#                                              input_percentage_of_ht_steam_hot_water_agricult...     NaN
#
# [770 rows x 3 columns]

# %% [markdown]
# ##### Load parent data

# %%
# Import parent data
path = Path("data", "intermediate", "parent_data.csv")
df_parent = pd.read_csv(path, index_col=0)

# Preview parent data
df_parent.T.head()
# Out:
#                                                         nl
# agriculture_final_demand_electricity_demand      41584.615
# agriculture_final_demand_network_gas_demand      91072.918
# agriculture_final_demand_steam_hot_water_demand   2783.107
# agriculture_final_demand_wood_pellets_demand      5437.224
# input_agriculture_final_demand_crude_oil_demand  17965.442

# %% [markdown]
# #### Energy demand (own use)
# Transform the energy demand (own use) production data to the right format.

# %% [markdown]
# ##### List ETLocal keys

# %% [markdown]
# Preview the ETLocal keys that are relevant for the fossil electricity production category

# %%
# Filter the ETLocal keys that are relevant for the energy demand (own use) category
filter_energy_energy_demand = (slice(None), 'energy', 'energy_energy_demand')

# Preview the filtered template
template.loc[filter_energy_energy_demand, :]
# Out:
#                                                                           unit  \
# geo_id group  subgroup             key
# GM1896 energy energy_energy_demand energy_heat_distribution_ht_loss_share    %
#                                    energy_heat_distribution_mt_loss_share    %
#                                    energy_heat_distribution_lt_loss_share    %
#
#                                                                            value  \
# geo_id group  subgroup             key
# GM1896 energy energy_energy_demand energy_heat_distribution_ht_loss_share    NaN
#                                    energy_heat_distribution_mt_loss_share    NaN
#                                    energy_heat_distribution_lt_loss_share    NaN
#
#                                                                           commit
# geo_id group  subgroup             key
# GM1896 energy energy_energy_demand energy_heat_distribution_ht_loss_share    NaN
#                                    energy_heat_distribution_mt_loss_share    NaN
#                                    energy_heat_distribution_lt_loss_share    NaN

# %% [markdown]
# ##### Fill missing values

# %% [markdown]
# Then, fill the missing values for:
# - Heat network distribution losses
# - ...

# %% [markdown]
# **Heat network distribution losses** | In the present situation we presume all residual heat networks to be HT. Hence, all distribution losses are allocated to HT networks.

# %%
for temperature_level in ['lt', 'mt', 'ht']:
    key = f'input_energy_heat_distribution_{temperature_level}_loss_share'
    # The parent data hasn't been migrated yet so for now we're using a static value
    # val = df_parent[key]
    val = 100-75.71885721737949

    # Update value and corresponding commit message for the temperature level share
    template.loc[(slice(None), slice(None), slice(None), key), 'value'] = val
    template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"No data available. We assume the share of loss is equal to the parent dataset ({parent})."

# %% [markdown]
# **Preview** the template to see all changes

# %%
# Preview template after changes
template.loc[filter_energy_energy_demand, :].head()
# Out:
#                                                                           unit  \
# geo_id group  subgroup             key
# GM1896 energy energy_energy_demand energy_heat_distribution_ht_loss_share    %
#                                    energy_heat_distribution_mt_loss_share    %
#                                    energy_heat_distribution_lt_loss_share    %
#
#                                                                                value  \
# geo_id group  subgroup             key
# GM1896 energy energy_energy_demand energy_heat_distribution_ht_loss_share  24.281143
#                                    energy_heat_distribution_mt_loss_share  24.281143
#                                    energy_heat_distribution_lt_loss_share  24.281143
#
#                                                                                                                       commit
# geo_id group  subgroup             key
# GM1896 energy energy_energy_demand energy_heat_distribution_ht_loss_share  No data available. We assume the share of loss...
#                                    energy_heat_distribution_mt_loss_share  No data available. We assume the share of loss...
#                                    energy_heat_distribution_lt_loss_share  No data available. We assume the share of loss...

# %% [markdown]
# #### Fossil electricity production
# Transform the fossil electricity production data to the right format.

# %% [markdown]
# ##### List ETLocal keys

# %% [markdown]
# Preview the ETLocal keys that are relevant for the fossil electricity production category

# %%
# Filter the ETLocal keys that are relevant for the fossil electricity production category
filter_fossil_electricity_production = (slice(None), 'energy', 'energy_fossil_electricity_production')

# Preview the filtered template
template.loc[filter_fossil_electricity_production, :]
# Out:
#                                                                                                       unit  \
# geo_id group  subgroup                             key
# GM1896 energy energy_fossil_electricity_production input_energy_chp_ultra_supercritical_ht_coal_pr...   TJ
#                                                    input_energy_chp_ultra_supercritical_mt_coal_pr...   TJ
#                                                    input_energy_chp_ultra_supercritical_cofiring_h...   TJ
#                                                    input_energy_chp_ultra_supercritical_cofiring_m...   TJ
#                                                    input_energy_chp_ultra_supercritical_ht_lignite...   TJ
#                                                    input_energy_chp_ultra_supercritical_mt_lignite...   TJ
#                                                    input_energy_chp_combined_cycle_ht_network_gas_...   TJ
#                                                    input_energy_chp_combined_cycle_mt_network_gas_...   TJ
#                                                    input_energy_chp_local_engine_ht_network_gas_pr...   TJ
#                                                    input_energy_chp_local_engine_mt_network_gas_pr...   TJ
#
#                                                                                                        value  \
# geo_id group  subgroup                             key
# GM1896 energy energy_fossil_electricity_production input_energy_chp_ultra_supercritical_ht_coal_pr...    NaN
#                                                    input_energy_chp_ultra_supercritical_mt_coal_pr...    NaN
#                                                    input_energy_chp_ultra_supercritical_cofiring_h...    NaN
#                                                    input_energy_chp_ultra_supercritical_cofiring_m...    NaN
#                                                    input_energy_chp_ultra_supercritical_ht_lignite...    NaN
#                                                    input_energy_chp_ultra_supercritical_mt_lignite...    NaN
#                                                    input_energy_chp_combined_cycle_ht_network_gas_...    NaN
#                                                    input_energy_chp_combined_cycle_mt_network_gas_...    NaN
#                                                    input_energy_chp_local_engine_ht_network_gas_pr...    NaN
#                                                    input_energy_chp_local_engine_mt_network_gas_pr...    NaN
#
#                                                                                                       commit
# geo_id group  subgroup                             key
# GM1896 energy energy_fossil_electricity_production input_energy_chp_ultra_supercritical_ht_coal_pr...    NaN
#                                                    input_energy_chp_ultra_supercritical_mt_coal_pr...    NaN
#                                                    input_energy_chp_ultra_supercritical_cofiring_h...    NaN
#                                                    input_energy_chp_ultra_supercritical_cofiring_m...    NaN
#                                                    input_energy_chp_ultra_supercritical_ht_lignite...    NaN
#                                                    input_energy_chp_ultra_supercritical_mt_lignite...    NaN
#                                                    input_energy_chp_combined_cycle_ht_network_gas_...    NaN
#                                                    input_energy_chp_combined_cycle_mt_network_gas_...    NaN
#                                                    input_energy_chp_local_engine_ht_network_gas_pr...    NaN
#                                                    input_energy_chp_local_engine_mt_network_gas_pr...    NaN

# %% [markdown]
# ##### Fill missing values

# %% [markdown]
# Then, fill the missing values for:
# - MT CHPs
# - ...

# %% [markdown]
# **MT CHPs** | In the present situatie we presume all CHPs to produce HT heat, meaning the production of MT heat by CHPs can be set to zero for all producers.

# %%
# TODO: we could also use the parent data shares instead?
for producer in ['ultra_supercritical_mt_coal', 'ultra_supercritical_cofiring_mt_coal', 'ultra_supercritical_mt_lignite', 'combined_cycle_mt_network_gas', 'local_engine_mt_network_gas']:
    key = f'input_energy_chp_{producer}_production'
    val = 0.
    
    # Update value and corresponding commit message for the temperature level share
    template.loc[(slice(None), slice(None), slice(None), key), 'value'] = val
    template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"No data available. All CHPs are assumed to produce only HT heat and zero MT heat."

# %% [markdown]
# **Preview** the template to see all changes

# %%
# Preview template after changes
template.loc[filter_fossil_electricity_production, :].head()
# Out:
#                                                                                                       unit  \
# geo_id group  subgroup                             key
# GM1896 energy energy_fossil_electricity_production input_energy_chp_ultra_supercritical_ht_coal_pr...   TJ
#                                                    input_energy_chp_ultra_supercritical_mt_coal_pr...   TJ
#                                                    input_energy_chp_ultra_supercritical_cofiring_h...   TJ
#                                                    input_energy_chp_ultra_supercritical_cofiring_m...   TJ
#                                                    input_energy_chp_ultra_supercritical_ht_lignite...   TJ
#
#                                                                                                        value  \
# geo_id group  subgroup                             key
# GM1896 energy energy_fossil_electricity_production input_energy_chp_ultra_supercritical_ht_coal_pr...    NaN
#                                                    input_energy_chp_ultra_supercritical_mt_coal_pr...    0.0
#                                                    input_energy_chp_ultra_supercritical_cofiring_h...    NaN
#                                                    input_energy_chp_ultra_supercritical_cofiring_m...    0.0
#                                                    input_energy_chp_ultra_supercritical_ht_lignite...    NaN
#
#                                                                                                                                                   commit
# geo_id group  subgroup                             key
# GM1896 energy energy_fossil_electricity_production input_energy_chp_ultra_supercritical_ht_coal_pr...                                                NaN
#                                                    input_energy_chp_ultra_supercritical_mt_coal_pr...  No data available. All CHPs are assumed to pro...
#                                                    input_energy_chp_ultra_supercritical_cofiring_h...                                                NaN
#                                                    input_energy_chp_ultra_supercritical_cofiring_m...  No data available. All CHPs are assumed to pro...
#                                                    input_energy_chp_ultra_supercritical_ht_lignite...                                                NaN

# %% [markdown]
# #### Renewable electricity production
# Transform the renewable electricity production data to the right format.

# %% [markdown]
# ##### List ETLocal keys

# %% [markdown]
# Preview the ETLocal keys that are relevant for the renewable electricity production category

# %%
# Filter the ETLocal keys that are relevant for the renewable electricity production category
filter_renewable_electricity_production = (slice(None), 'energy', 'energy_renewable_electricity_production')

# Preview the filtered template
template.loc[filter_renewable_electricity_production, :]
# Out:
#                                                                                                          unit  \
# geo_id group  subgroup                                key
# GM1896 energy energy_renewable_electricity_production input_energy_chp_supercritical_ht_waste_mix_pro...   TJ
#                                                       input_energy_chp_supercritical_mt_waste_mix_pro...   TJ
#                                                       input_energy_chp_local_ht_wood_pellets_production    TJ
#                                                       input_energy_chp_local_mt_wood_pellets_production    TJ
#                                                       input_energy_chp_local_engine_ht_biogas_production   TJ
#                                                       input_energy_chp_local_engine_mt_biogas_production   TJ
#
#                                                                                                           value  \
# geo_id group  subgroup                                key
# GM1896 energy energy_renewable_electricity_production input_energy_chp_supercritical_ht_waste_mix_pro...    NaN
#                                                       input_energy_chp_supercritical_mt_waste_mix_pro...    NaN
#                                                       input_energy_chp_local_ht_wood_pellets_production     NaN
#                                                       input_energy_chp_local_mt_wood_pellets_production     NaN
#                                                       input_energy_chp_local_engine_ht_biogas_production    NaN
#                                                       input_energy_chp_local_engine_mt_biogas_production    NaN
#
#                                                                                                          commit
# geo_id group  subgroup                                key
# GM1896 energy energy_renewable_electricity_production input_energy_chp_supercritical_ht_waste_mix_pro...    NaN
#                                                       input_energy_chp_supercritical_mt_waste_mix_pro...    NaN
#                                                       input_energy_chp_local_ht_wood_pellets_production     NaN
#                                                       input_energy_chp_local_mt_wood_pellets_production     NaN
#                                                       input_energy_chp_local_engine_ht_biogas_production    NaN
#                                                       input_energy_chp_local_engine_mt_biogas_production    NaN

# %% [markdown]
# ##### Fill missing values

# %% [markdown]
# Then, fill the missing values for:
# - MT CHPs
# - ...

# %% [markdown]
# **MT CHPs** | In the present situatie we presume all CHPs to produce HT heat, meaning the production of MT heat by CHPs can be set to zero for all producers.

# %%
# TODO: we could also use the parent data shares instead?
for producer in ['supercritical_mt_waste_mix', 'local_mt_wood_pellets', 'local_engine_mt_biogas']:
    key = f'input_energy_chp_{producer}_production'
    val = 0.
    
    # Update value and corresponding commit message for the temperature level share
    template.loc[(slice(None), slice(None), slice(None), key), 'value'] = val
    template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"No data available. All CHPs are assumed to produce only HT heat and zero MT heat."

# %% [markdown]
# Preview the template to see all changes

# %%
# Preview template after changes
template.loc[filter_renewable_electricity_production, :].head()
# Out:
#                                                                                                          unit  \
# geo_id group  subgroup                                key
# GM1896 energy energy_renewable_electricity_production input_energy_chp_supercritical_ht_waste_mix_pro...   TJ
#                                                       input_energy_chp_supercritical_mt_waste_mix_pro...   TJ
#                                                       input_energy_chp_local_ht_wood_pellets_production    TJ
#                                                       input_energy_chp_local_mt_wood_pellets_production    TJ
#                                                       input_energy_chp_local_engine_ht_biogas_production   TJ
#
#                                                                                                           value  \
# geo_id group  subgroup                                key
# GM1896 energy energy_renewable_electricity_production input_energy_chp_supercritical_ht_waste_mix_pro...    NaN
#                                                       input_energy_chp_supercritical_mt_waste_mix_pro...    0.0
#                                                       input_energy_chp_local_ht_wood_pellets_production     NaN
#                                                       input_energy_chp_local_mt_wood_pellets_production     0.0
#                                                       input_energy_chp_local_engine_ht_biogas_production    NaN
#
#                                                                                                                                                      commit
# geo_id group  subgroup                                key
# GM1896 energy energy_renewable_electricity_production input_energy_chp_supercritical_ht_waste_mix_pro...                                                NaN
#                                                       input_energy_chp_supercritical_mt_waste_mix_pro...  No data available. All CHPs are assumed to pro...
#                                                       input_energy_chp_local_ht_wood_pellets_production                                                 NaN
#                                                       input_energy_chp_local_mt_wood_pellets_production   No data available. All CHPs are assumed to pro...
#                                                       input_energy_chp_local_engine_ht_biogas_production                                                NaN

# %% [markdown]
# #### Heat production
# Transform the heat production data to the right format.

# %% [markdown]
# ##### List ETLocal keys

# %% [markdown]
# Preview the ETLocal keys that are relevant for the heat production category

# %%
# Filter the ETLocal keys that are relevant for the energy heat production category
filter_energy_heat_production = (slice(None), 'energy', 'energy_heat_production')

# Preview the filtered template
template.loc[filter_energy_heat_production, :]
# Out:
#                                                                                         unit  \
# geo_id group  subgroup               key
# GM1896 energy energy_heat_production input_energy_heat_well_ht_geothermal_production      TJ
#                                      input_energy_heat_well_mt_geothermal_production      TJ
#                                      input_energy_heat_well_shallow_mt_geothermal_pr...   TJ
#                                      input_energy_heat_well_shallow_lt_geothermal_pr...   TJ
#                                      input_energy_heat_burner_ht_wood_pellets_produc...   TJ
#                                      input_energy_heat_burner_mt_wood_pellets_produc...   TJ
#                                      input_energy_heat_burner_ht_waste_mix_production     TJ
#                                      input_energy_heat_burner_mt_waste_mix_production     TJ
#                                      input_energy_heat_burner_ht_hydrogen_production      TJ
#                                      input_energy_heat_burner_mt_hydrogen_production      TJ
#                                      input_energy_heat_burner_lt_hydrogen_production      TJ
#                                      input_energy_heat_lt_solar_thermal_production        TJ
#                                      input_energy_heat_mt_solar_thermal_production        TJ
#                                      input_energy_heat_heatpump_water_water_ht_elect...   TJ
#                                      input_energy_heat_heatpump_water_water_mt_elect...   TJ
#                                      input_energy_heat_heatpump_water_water_lt_elect...   TJ
#                                      input_energy_heat_boiler_ht_electricity_production   TJ
#                                      input_energy_heat_boiler_mt_electricity_production   TJ
#                                      input_energy_heat_boiler_lt_electricity_production   TJ
#                                      input_energy_heat_burner_ht_network_gas_production   TJ
#                                      input_energy_heat_burner_mt_network_gas_production   TJ
#                                      input_energy_heat_burner_ht_coal_production          TJ
#                                      input_energy_heat_burner_mt_coal_production          TJ
#                                      input_energy_heat_burner_ht_crude_oil_production     TJ
#                                      input_energy_heat_burner_mt_crude_oil_production     TJ
#                                      industry_chemicals_other_ht_residual_heat             %
#                                      industry_chemicals_other_mt_residual_heat             %
#                                      industry_chemicals_refineries_ht_residual_heat        %
#                                      industry_chemicals_refineries_mt_residual_heat        %
#                                      industry_chemicals_fertilizers_ht_residual_heat       %
#                                      industry_chemicals_fertilizers_mt_residual_heat       %
#                                      industry_ict_mt_residual_heat                         %
#                                      industry_ict_lt_residual_heat                         %
#                                      energy_import_ht_heat_demand                         TJ
#                                      energy_import_mt_heat_demand                         TJ
#                                      energy_import_lt_heat_demand                         TJ
#
#                                                                                          value  \
# geo_id group  subgroup               key
# GM1896 energy energy_heat_production input_energy_heat_well_ht_geothermal_production       NaN
#                                      input_energy_heat_well_mt_geothermal_production       NaN
#                                      input_energy_heat_well_shallow_mt_geothermal_pr...    NaN
#                                      input_energy_heat_well_shallow_lt_geothermal_pr...    NaN
#                                      input_energy_heat_burner_ht_wood_pellets_produc...    NaN
#                                      input_energy_heat_burner_mt_wood_pellets_produc...    NaN
#                                      input_energy_heat_burner_ht_waste_mix_production      NaN
#                                      input_energy_heat_burner_mt_waste_mix_production      NaN
#                                      input_energy_heat_burner_ht_hydrogen_production       NaN
#                                      input_energy_heat_burner_mt_hydrogen_production       NaN
#                                      input_energy_heat_burner_lt_hydrogen_production       NaN
#                                      input_energy_heat_lt_solar_thermal_production         NaN
#                                      input_energy_heat_mt_solar_thermal_production         NaN
#                                      input_energy_heat_heatpump_water_water_ht_elect...    NaN
#                                      input_energy_heat_heatpump_water_water_mt_elect...    NaN
#                                      input_energy_heat_heatpump_water_water_lt_elect...    NaN
#                                      input_energy_heat_boiler_ht_electricity_production    NaN
#                                      input_energy_heat_boiler_mt_electricity_production    NaN
#                                      input_energy_heat_boiler_lt_electricity_production    NaN
#                                      input_energy_heat_burner_ht_network_gas_production    NaN
#                                      input_energy_heat_burner_mt_network_gas_production    NaN
#                                      input_energy_heat_burner_ht_coal_production           NaN
#                                      input_energy_heat_burner_mt_coal_production           NaN
#                                      input_energy_heat_burner_ht_crude_oil_production      NaN
#                                      input_energy_heat_burner_mt_crude_oil_production      NaN
#                                      industry_chemicals_other_ht_residual_heat             NaN
#                                      industry_chemicals_other_mt_residual_heat             NaN
#                                      industry_chemicals_refineries_ht_residual_heat        NaN
#                                      industry_chemicals_refineries_mt_residual_heat        NaN
#                                      industry_chemicals_fertilizers_ht_residual_heat       NaN
#                                      industry_chemicals_fertilizers_mt_residual_heat       NaN
#                                      industry_ict_mt_residual_heat                         NaN
#                                      industry_ict_lt_residual_heat                         NaN
#                                      energy_import_ht_heat_demand                          NaN
#                                      energy_import_mt_heat_demand                          NaN
#                                      energy_import_lt_heat_demand                          NaN
#
#                                                                                         commit
# geo_id group  subgroup               key
# GM1896 energy energy_heat_production input_energy_heat_well_ht_geothermal_production       NaN
#                                      input_energy_heat_well_mt_geothermal_production       NaN
#                                      input_energy_heat_well_shallow_mt_geothermal_pr...    NaN
#                                      input_energy_heat_well_shallow_lt_geothermal_pr...    NaN
#                                      input_energy_heat_burner_ht_wood_pellets_produc...    NaN
#                                      input_energy_heat_burner_mt_wood_pellets_produc...    NaN
#                                      input_energy_heat_burner_ht_waste_mix_production      NaN
#                                      input_energy_heat_burner_mt_waste_mix_production      NaN
#                                      input_energy_heat_burner_ht_hydrogen_production       NaN
#                                      input_energy_heat_burner_mt_hydrogen_production       NaN
#                                      input_energy_heat_burner_lt_hydrogen_production       NaN
#                                      input_energy_heat_lt_solar_thermal_production         NaN
#                                      input_energy_heat_mt_solar_thermal_production         NaN
#                                      input_energy_heat_heatpump_water_water_ht_elect...    NaN
#                                      input_energy_heat_heatpump_water_water_mt_elect...    NaN
#                                      input_energy_heat_heatpump_water_water_lt_elect...    NaN
#                                      input_energy_heat_boiler_ht_electricity_production    NaN
#                                      input_energy_heat_boiler_mt_electricity_production    NaN
#                                      input_energy_heat_boiler_lt_electricity_production    NaN
#                                      input_energy_heat_burner_ht_network_gas_production    NaN
#                                      input_energy_heat_burner_mt_network_gas_production    NaN
#                                      input_energy_heat_burner_ht_coal_production           NaN
#                                      input_energy_heat_burner_mt_coal_production           NaN
#                                      input_energy_heat_burner_ht_crude_oil_production      NaN
#                                      input_energy_heat_burner_mt_crude_oil_production      NaN
#                                      industry_chemicals_other_ht_residual_heat             NaN
#                                      industry_chemicals_other_mt_residual_heat             NaN
#                                      industry_chemicals_refineries_ht_residual_heat        NaN
#                                      industry_chemicals_refineries_mt_residual_heat        NaN
#                                      industry_chemicals_fertilizers_ht_residual_heat       NaN
#                                      industry_chemicals_fertilizers_mt_residual_heat       NaN
#                                      industry_ict_mt_residual_heat                         NaN
#                                      industry_ict_lt_residual_heat                         NaN
#                                      energy_import_ht_heat_demand                          NaN
#                                      energy_import_mt_heat_demand                          NaN
#                                      energy_import_lt_heat_demand                          NaN

# %% [markdown]
# ##### Fill missing values

# %% [markdown]
# Then, fill the missing values for:
# - MT/LT heat production
# - Imported heat
# - ...

# %% [markdown]
# **MT/LT heat production** | In the present situation we presume all HT/MT producers to produce only HT heat, meaning the production of MT heat by those producers can be set to zero. Furthermore, there is no data available about LT heat production. Hence, we assume that all production of LT heat is zero.

# %%
for producer in ['well_mt_geothermal', 'burner_mt_wood_pellets', 'burner_mt_waste_mix', 'burner_lt_hydrogen', 'burner_mt_hydrogen', 'burner_mt_network_gas', 'heatpump_water_water_mt_electricity', 'boiler_mt_electricity', 'boiler_lt_electricity', 'burner_mt_coal', 'burner_mt_crude_oil']:
    key = f'input_energy_heat_{producer}_production'
    val = 0.
    
    # Update value and corresponding commit message for the temperature level share
    template.loc[(slice(None), slice(None), slice(None), key), 'value'] = val
    template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"No data available. All heat producers are assumed to produce only HT heat and zero MT or LT heat."

# %%
for producer in ['well_shallow_mt_geothermal', 'mt_solar_thermal']:
    key = f'input_energy_heat_{producer}_production'
    val = 0.
    
    # Update value and corresponding commit message for the temperature level share
    template.loc[(slice(None), slice(None), slice(None), key), 'value'] = val
    template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"No data available. Production of MT heat is set to zero."

# %%
for producer in ['well_shallow_lt_geothermal', 'heatpump_water_water_lt_electricity', 'lt_solar_thermal']:
    key = f'input_energy_heat_{producer}_production'
    val = 0.
    
    # Update value and corresponding commit message for the temperature level share
    template.loc[(slice(None), slice(None), slice(None), key), 'value'] = val
    template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"No data available. Production of LT heat is set to zero."

# %% [markdown]
# **Imported heat** | In the present situation we assume no heat is imported.

# %%
for temperature_level in ['lt', 'mt', 'ht']:
    # TODO: turn into method
    key = f'energy_import_{temperature_level}_heat_demand'
    val = 0.

    # Update value and corresponding commit message for the temperature level share
    template.loc[(slice(None), slice(None), slice(None), key), 'value'] = val
    template.loc[(slice(None), slice(None), slice(None), key), 'commit'] = f"No data available. By default, the import of heat is set to zero."

# %% [markdown]
# **Preview** the template to see all changes

# %%
# Preview template after changes
template.loc[filter_energy_heat_production, :].head()
# Out:
#                                                                                         unit  \
# geo_id group  subgroup               key
# GM1896 energy energy_heat_production input_energy_heat_well_ht_geothermal_production      TJ
#                                      input_energy_heat_well_mt_geothermal_production      TJ
#                                      input_energy_heat_well_shallow_mt_geothermal_pr...   TJ
#                                      input_energy_heat_well_shallow_lt_geothermal_pr...   TJ
#                                      input_energy_heat_burner_ht_wood_pellets_produc...   TJ
#
#                                                                                          value  \
# geo_id group  subgroup               key
# GM1896 energy energy_heat_production input_energy_heat_well_ht_geothermal_production       NaN
#                                      input_energy_heat_well_mt_geothermal_production       0.0
#                                      input_energy_heat_well_shallow_mt_geothermal_pr...    0.0
#                                      input_energy_heat_well_shallow_lt_geothermal_pr...    0.0
#                                      input_energy_heat_burner_ht_wood_pellets_produc...    NaN
#
#                                                                                                                                     commit
# geo_id group  subgroup               key
# GM1896 energy energy_heat_production input_energy_heat_well_ht_geothermal_production                                                   NaN
#                                      input_energy_heat_well_mt_geothermal_production     No data available. All heat producers are assu...
#                                      input_energy_heat_well_shallow_mt_geothermal_pr...  No data available. Production of MT heat is se...
#                                      input_energy_heat_well_shallow_lt_geothermal_pr...  No data available. Production of LT heat is se...
#                                      input_energy_heat_burner_ht_wood_pellets_produc...                                                NaN

# %% [markdown]
# #### Exceptions
#
# If there are any exceptions for municipal datasets, you can overwrite the values below.

# %% [markdown]
# **TO DO** | Explain to the user that this section should always be checked. Should the exception be overwritten by the update? Or should it remain untouched?

# %% [markdown]
# ##### Gemeente X

# %%
#

# %% [markdown]
# #### Export processed data
# Write the transformed data to our  `data / processed` directory. This is the data we will be using for the next (analysis and visualisation) steps in the pipeline.

# %%
# Write dataframe to intermediate data folder
path = Path("data", "processed", "etlocal_template.csv")
template.to_csv(path)

# %% [markdown]
# ### 4. Data analysis and visualisation

# %%
# TODO

# %% [markdown]
# ## Migration

# %% [markdown]
# #### Initialize migration files

# %%
# First, initialize data.csv file based on the config file
path = Path("config", "data.csv")
df_data_csv = pd.read_csv(path, sep=sep, index_col=[0])

# Drop unnamed columns
df_data_csv = df_data_csv.drop(columns=df_data_csv.columns[df_data_csv.columns.str.startswith('Unnamed')])

# %%
# Preview dataframe representing data.csv
df_data_csv
# Out:
#             country                                    name
# geo_id
# GM1680       nl2019                             Aa en Hunze
# GM0738       nl2019                                 Aalburg
# GM0358       nl2019                                Aalsmeer
# GM0197       nl2019                                  Aalten
# GM0059       nl2019                           Achtkarspelen
# ...             ...                                     ...
# RGBRE01      nl2019                    Breda Steenakker BiZ
# RGHLD01      nl2019                 Heerhugowaard-Langedijk
# BU19660506   nl2019                               Oudeschip
# RGPA01       RGPA01  Panama - Ports of Cristobal and Balboa
# DKGM751     DKGM751                                  Aarhus
#
# [3982 rows x 2 columns]

# %%
# Then, initialize commits.yml file by specifying the file path where you want to create the YAML file
path = Path("data", "reporting", "commits.yml")

# Write the document separator to the YAML file
with open(path, 'w') as file:
    file.write('---\n')

# %% [markdown]
# #### Fill migration files
# Fill the relevant processed data from the ETLocal template in the `data.csv` and `commits.yml` files that are necessary for a ETLocal migration.

# %%
# Preview ETLocal template
template
# Out:
#                                                                                                unit  \
# geo_id group      subgroup                key
# GM1896 area       area_emission_factors   file_carriers_imported_heat_lt_co2_conversion_p...  kg/MJ
#                                           file_carriers_imported_heat_mt_co2_conversion_p...  kg/MJ
#                                           file_carriers_imported_heat_ht_co2_conversion_p...  kg/MJ
#        households households_applications households_final_demand_electricity_households_...      %
#                                           households_final_demand_electricity_households_...      %
# ...                                                                                             ...
#        energy     energy_heat_production  energy_import_mt_heat_demand                           TJ
#                                           energy_import_lt_heat_demand                           TJ
#                   energy_energy_demand    energy_heat_distribution_ht_loss_share                  %
#                                           energy_heat_distribution_mt_loss_share                  %
#                                           energy_heat_distribution_lt_loss_share                  %
#
#                                                                                                   value  \
# geo_id group      subgroup                key
# GM1896 area       area_emission_factors   file_carriers_imported_heat_lt_co2_conversion_p...   0.036000
#                                           file_carriers_imported_heat_mt_co2_conversion_p...   0.036000
#                                           file_carriers_imported_heat_ht_co2_conversion_p...   0.036000
#        households households_applications households_final_demand_electricity_households_...        NaN
#                                           households_final_demand_electricity_households_...        NaN
# ...                                                                                                 ...
#        energy     energy_heat_production  energy_import_mt_heat_demand                         0.000000
#                                           energy_import_lt_heat_demand                         0.000000
#                   energy_energy_demand    energy_heat_distribution_ht_loss_share              24.281143
#                                           energy_heat_distribution_mt_loss_share              24.281143
#                                           energy_heat_distribution_lt_loss_share              24.281143
#
#                                                                                                                                          commit
# geo_id group      subgroup                key
# GM1896 area       area_emission_factors   file_carriers_imported_heat_lt_co2_conversion_p...  Based on https://www.co2emissiefactoren.nl/lij...
#                                           file_carriers_imported_heat_mt_co2_conversion_p...  Based on https://www.co2emissiefactoren.nl/lij...
#                                           file_carriers_imported_heat_ht_co2_conversion_p...  Based on https://www.co2emissiefactoren.nl/lij...
#        households households_applications households_final_demand_electricity_households_...                                                NaN
#                                           households_final_demand_electricity_households_...                                                NaN
# ...                                                                                                                                         ...
#        energy     energy_heat_production  energy_import_mt_heat_demand                        No data available. By default, the import of h...
#                                           energy_import_lt_heat_demand                        No data available. By default, the import of h...
#                   energy_energy_demand    energy_heat_distribution_ht_loss_share              No data available. We assume the share of loss...
#                                           energy_heat_distribution_mt_loss_share              No data available. We assume the share of loss...
#                                           energy_heat_distribution_lt_loss_share              No data available. We assume the share of loss...
#
# [212 rows x 3 columns]

# %%
# List all keys for which values have been added to the template
keys = list(template.dropna().index.get_level_values(3).unique())

# Preview list of keys
keys
# Out:
# ['file_carriers_imported_heat_lt_co2_conversion_per_mj',
#  'file_carriers_imported_heat_mt_co2_conversion_per_mj',
#  'file_carriers_imported_heat_ht_co2_conversion_per_mj',
#  'input_percentage_of_lt_steam_hot_water_households_final_demand_steam_hot_water',
#  'input_percentage_of_mt_steam_hot_water_households_final_demand_steam_hot_water',
#  'input_percentage_of_ht_steam_hot_water_households_final_demand_steam_hot_water',
#  'input_percentage_of_lt_steam_hot_water_buildings_final_demand_steam_hot_water',
#  'input_percentage_of_mt_steam_hot_water_buildings_final_demand_steam_hot_water',
#  'input_percentage_of_ht_steam_hot_water_buildings_final_demand_steam_hot_water',
#  'input_percentage_of_mt_steam_hot_water_agriculture_final_demand_steam_hot_water',
#  'input_percentage_of_ht_steam_hot_water_agriculture_final_demand_steam_hot_water',
#  'input_energy_chp_ultra_supercritical_mt_coal_production',
#  'input_energy_chp_ultra_supercritical_cofiring_mt_coal_production',
#  'input_energy_chp_ultra_supercritical_mt_lignite_production',
#  'input_energy_chp_combined_cycle_mt_network_gas_production',
#  'input_energy_chp_local_engine_mt_network_gas_production',
#  'input_energy_chp_supercritical_mt_waste_mix_production',
#  'input_energy_chp_local_mt_wood_pellets_production',
#  'input_energy_chp_local_engine_mt_biogas_production',
#  'input_energy_heat_well_mt_geothermal_production',
#  'input_energy_heat_well_shallow_mt_geothermal_production',
#  'input_energy_heat_well_shallow_lt_geothermal_production',
#  'input_energy_heat_burner_mt_wood_pellets_production',
#  'input_energy_heat_burner_mt_waste_mix_production',
#  'input_energy_heat_burner_mt_hydrogen_production',
#  'input_energy_heat_burner_lt_hydrogen_production',
#  'input_energy_heat_lt_solar_thermal_production',
#  'input_energy_heat_mt_solar_thermal_production',
#  'input_energy_heat_heatpump_water_water_mt_electricity_production',
#  'input_energy_heat_heatpump_water_water_lt_electricity_production',
#  'input_energy_heat_boiler_mt_electricity_production',
#  'input_energy_heat_boiler_lt_electricity_production',
#  'input_energy_heat_burner_mt_network_gas_production',
#  'input_energy_heat_burner_mt_coal_production',
#  'input_energy_heat_burner_mt_crude_oil_production',
#  'industry_chemicals_other_ht_residual_heat',
#  'industry_chemicals_other_mt_residual_heat',
#  'industry_chemicals_refineries_ht_residual_heat',
#  'industry_chemicals_refineries_mt_residual_heat',
#  'industry_chemicals_fertilizers_ht_residual_heat',
#  'industry_chemicals_fertilizers_mt_residual_heat',
#  'industry_ict_mt_residual_heat',
#  'industry_ict_lt_residual_heat',
#  'energy_import_ht_heat_demand',
#  'energy_import_mt_heat_demand',
#  'energy_import_lt_heat_demand',
#  'energy_heat_distribution_ht_loss_share',
#  'energy_heat_distribution_mt_loss_share',
#  'energy_heat_distribution_lt_loss_share']

# %%
# Add keys to data.csv migration file
for key in keys:
    df_data_csv.loc[:, key] = float('nan')
    
# Preview data.csv
df_data_csv
# Out:
#        country             name  \
# geo_id
# GM1896  nl2019  Zwartewaterland
#
#         file_carriers_imported_heat_lt_co2_conversion_per_mj  \
# geo_id
# GM1896                                                NaN
#
#         file_carriers_imported_heat_mt_co2_conversion_per_mj  \
# geo_id
# GM1896                                                NaN
#
#         file_carriers_imported_heat_ht_co2_conversion_per_mj  \
# geo_id
# GM1896                                                NaN
#
#         input_percentage_of_lt_steam_hot_water_households_final_demand_steam_hot_water  \
# geo_id
# GM1896                                                NaN
#
#         input_percentage_of_mt_steam_hot_water_households_final_demand_steam_hot_water  \
# geo_id
# GM1896                                                NaN
#
#         input_percentage_of_ht_steam_hot_water_households_final_demand_steam_hot_water  \
# geo_id
# GM1896                                                NaN
#
#         input_percentage_of_lt_steam_hot_water_buildings_final_demand_steam_hot_water  \
# geo_id
# GM1896                                                NaN
#
#         input_percentage_of_mt_steam_hot_water_buildings_final_demand_steam_hot_water  \
# geo_id
# GM1896                                                NaN
#
#         ...  industry_chemicals_fertilizers_ht_residual_heat  \
# geo_id  ...
# GM1896  ...                                              NaN
#
#         industry_chemicals_fertilizers_mt_residual_heat  \
# geo_id
# GM1896                                              NaN
#
#         industry_ict_mt_residual_heat  industry_ict_lt_residual_heat  \
# geo_id
# GM1896                            NaN                            NaN
#
#         energy_import_ht_heat_demand  energy_import_mt_heat_demand  \
# geo_id
# GM1896                           NaN                           NaN
#
#         energy_import_lt_heat_demand  energy_heat_distribution_ht_loss_share  \
# geo_id
# GM1896                           NaN                                     NaN
#
#         energy_heat_distribution_mt_loss_share  \
# geo_id
# GM1896                                     NaN
#
#         energy_heat_distribution_lt_loss_share
# geo_id
# GM1896                                     NaN
#
# [1 rows x 51 columns]

# %%
# Initialize an empty array for the commits
commits = []

# For all relevant keys and for each municipality fill data.csv and commits.yml
for key in keys:
    for municipality in municipalities:
        # Add data value to data.csv
        df_data_csv.loc[municipality, key] = template.loc[(municipality, slice(None), slice(None), key), 'value'].values[0]
        
    # Add commit message to commits.yml
    commits.append({'fields': [key], 'message': template.loc[(slice(None), slice(None), slice(None), key), 'commit'].values[0]})
    
# Preview data for all municipalities in the format required for the data.csv file
df_data_csv
# Out:
#        country             name  \
# geo_id
# GM1896  nl2019  Zwartewaterland
#
#         file_carriers_imported_heat_lt_co2_conversion_per_mj  \
# geo_id
# GM1896                                              0.036
#
#         file_carriers_imported_heat_mt_co2_conversion_per_mj  \
# geo_id
# GM1896                                              0.036
#
#         file_carriers_imported_heat_ht_co2_conversion_per_mj  \
# geo_id
# GM1896                                              0.036
#
#         input_percentage_of_lt_steam_hot_water_households_final_demand_steam_hot_water  \
# geo_id
# GM1896                                                0.0
#
#         input_percentage_of_mt_steam_hot_water_households_final_demand_steam_hot_water  \
# geo_id
# GM1896                                                0.0
#
#         input_percentage_of_ht_steam_hot_water_households_final_demand_steam_hot_water  \
# geo_id
# GM1896                                                1.0
#
#         input_percentage_of_lt_steam_hot_water_buildings_final_demand_steam_hot_water  \
# geo_id
# GM1896                                                0.0
#
#         input_percentage_of_mt_steam_hot_water_buildings_final_demand_steam_hot_water  \
# geo_id
# GM1896                                                0.0
#
#         ...  industry_chemicals_fertilizers_ht_residual_heat  \
# geo_id  ...
# GM1896  ...                                              1.0
#
#         industry_chemicals_fertilizers_mt_residual_heat  \
# geo_id
# GM1896                                              0.0
#
#         industry_ict_mt_residual_heat  industry_ict_lt_residual_heat  \
# geo_id
# GM1896                            1.0                            0.0
#
#         energy_import_ht_heat_demand  energy_import_mt_heat_demand  \
# geo_id
# GM1896                           0.0                           0.0
#
#         energy_import_lt_heat_demand  energy_heat_distribution_ht_loss_share  \
# geo_id
# GM1896                           0.0                               24.281143
#
#         energy_heat_distribution_mt_loss_share  \
# geo_id
# GM1896                               24.281143
#
#         energy_heat_distribution_lt_loss_share
# geo_id
# GM1896                               24.281143
#
# [1 rows x 51 columns]

# %%
# Write data.csv to processed data directory
df_data_csv.to_csv(f"data/reporting/data.csv")

# %%
# TODO: Beautify the yaml data and make it more readable
# commits_yaml = yaml.dump(commits, sort_keys=False, indent=4, default_flow_style=False, default_style='|')

# Write the updated data back to the YAML file
path = Path("data", "reporting", "commits.yml")

with open(path, 'w') as file:
    yaml.safe_dump(commits, file)
