# %% [markdown]
# # Rails amalgamator command generator

# %% [markdown]
# This notebook generates the rails commands for the ETLocal amalgamator. It processes the CBS regional data to arrive at sets of municipal codes for each RES region and province.

# %% [markdown]
# ## Setup

# %%
# internal modules
import csv
import os
import sys
import importlib

# external modules
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
import xlwings as xw
import yaml
from pathlib import Path
import src.load_data_manager
from src.load_data_manager import LoadDataManager
from typing import List

# Reload
importlib.reload(src.load_data_manager)
# Out:
# <module 'src.load_data_manager' from '/Users/koenvanbemmelen/work/etdataset/pipelines/src/load_data_manager.py'>

# %% [markdown]
# ## General

# %% [markdown]
# ## Extract

# %%
path = Path("config", "CBS Gebieden in Nederland 2023 - ETM version.csv")
sep = ','
df_cbs = pd.read_csv(path, sep=sep)
df_cbs
# Out:
#     Codes en namen van gemeenten|Naam Codes en namen van gemeenten|Code  \
# 0                         Aa en Hunze                            GM1680
# 1                            Aalsmeer                            GM0358
# 2                              Aalten                            GM0197
# 3                       Achtkarspelen                            GM0059
# 4                        Alblasserdam                            GM0482
# ..                                ...                               ...
# 337                           Zundert                            GM0879
# 338                           Zutphen                            GM0301
# 339                   Zwartewaterland                            GM1896
# 340                       Zwijndrecht                            GM0642
# 341                            Zwolle                            GM0193
#
#     Lokaliseringen van gemeenten|Provincies|Code  \
# 0                                           PV22
# 1                                           PV27
# 2                                           PV25
# 3                                           PV21
# 4                                           PV28
# ..                                           ...
# 337                                         PV30
# 338                                         PV25
# 339                                         PV23
# 340                                         PV28
# 341                                         PV23
#
#     Lokaliseringen van gemeenten|Provincies|Naam  \
# 0                                        Drenthe
# 1                                  Noord-Holland
# 2                                     Gelderland
# 3                                        Fryslân
# 4                                   Zuid-Holland
# ..                                           ...
# 337                                Noord-Brabant
# 338                                   Gelderland
# 339                                   Overijssel
# 340                                 Zuid-Holland
# 341                                   Overijssel
#
#     Lokaliseringen van gemeenten|Regionale Energiestrategie regio’s|Code  \
# 0                                                 ES03
# 1                                                 ES16
# 2                                                 ES07
# 3                                                 ES02
# 4                                                 ES18
# ..                                                 ...
# 337                                               ES28
# 338                                               ES12
# 339                                               ES05
# 340                                               ES18
# 341                                               ES05
#
#     Lokaliseringen van gemeenten|Regionale Energiestrategie regio’s|Naam
# 0                                              Drenthe
# 1                                   Noord-Holland Zuid
# 2                                           Achterhoek
# 3                                            Friesland
# 4                                         Drechtsteden
# ..                                                 ...
# 337                                       West-Brabant
# 338                                     Stedendriehoek
# 339                                    West-Overijssel
# 340                                       Drechtsteden
# 341                                    West-Overijssel
#
# [342 rows x 6 columns]

# %% [markdown]
# Define the RES regions as dictionary

# %%
# Create dictionary for RES regions
res_dict = {}
res_codes = df_cbs["Lokaliseringen van gemeenten|Regionale Energiestrategie regio’s|Code"].unique().tolist()
res_codes.sort()

for res_code in res_codes:
    res_name = df_cbs[df_cbs["Lokaliseringen van gemeenten|Regionale Energiestrategie regio’s|Code"] == res_code]["Lokaliseringen van gemeenten|Regionale Energiestrategie regio’s|Naam"].values[0]
    municipalities = df_cbs[df_cbs["Lokaliseringen van gemeenten|Regionale Energiestrategie regio’s|Code"] == res_code]["Codes en namen van gemeenten|Code"].tolist()
    # For each res code, add a dictionary with keys 'name' and 'municipalities'
    res_dict[res_code] = {
        "name": res_name,
        "municipalities": municipalities
    }

# %%
# Validate: count the number of municipalities in the res_dict
total_municipalities = sum([len(res_dict[res_code]["municipalities"]) for res_code in res_dict])
total_municipalities
# Out:
# 342

# %% [markdown]
# Now do the same for provinces

# %%
# Create dictionary for RES regions
province_dict = {}
province_codes = df_cbs["Lokaliseringen van gemeenten|Provincies|Code"].unique().tolist()
province_codes.sort()

for province_code in province_codes:
    province_name = df_cbs[df_cbs["Lokaliseringen van gemeenten|Provincies|Code"] == province_code]["Lokaliseringen van gemeenten|Provincies|Naam"].values[0]
    municipalities = df_cbs[df_cbs["Lokaliseringen van gemeenten|Provincies|Code"] == province_code]["Codes en namen van gemeenten|Code"].tolist()
    # For each province code, add a dictionary with keys 'name' and 'municipalities'
    province_dict[province_code] = {
        "name": province_name,
        "municipalities": municipalities
    }

# Rename Fryslân to Fryslan to avoid encoding issues
province_dict['PV21']['name'] = 'Fryslan'

province_dict
# Out:
# {'PV20': {'name': 'Groningen',
#   'municipalities': ['GM1979',
#    'GM0014',
#    'GM1966',
#    'GM1952',
#    'GM1895',
#    'GM0765',
#    'GM0037',
#    'GM0047',
#    'GM1969',
#    'GM1950']},
#  'PV21': {'name': 'Fryslan',
#   'municipalities': ['GM0059',
#    'GM0060',
#    'GM1891',
#    'GM1940',
#    'GM0072',
#    'GM0074',
#    'GM0080',
#    'GM1970',
#    'GM0085',
#    'GM0086',
#    'GM0088',
#    'GM0090',
#    'GM1900',
#    'GM0093',
#    'GM0737',
#    'GM0096',
#    'GM1949',
#    'GM0098']},
#  'PV22': {'name': 'Drenthe',
#   'municipalities': ['GM1680',
#    'GM0106',
#    'GM1681',
#    'GM0109',
#    'GM0114',
#    'GM0118',
#    'GM0119',
#    'GM1731',
#    'GM1699',
#    'GM1730',
#    'GM1701',
#    'GM1690']},
#  'PV23': {'name': 'Overijssel',
#   'municipalities': ['GM0141',
#    'GM0147',
#    'GM0148',
#    'GM0150',
#    'GM1774',
#    'GM0153',
#    'GM0158',
#    'GM0160',
#    'GM0163',
#    'GM0164',
#    'GM1735',
#    'GM0166',
#    'GM0168',
#    'GM0173',
#    'GM1773',
#    'GM0175',
#    'GM0177',
#    'GM1742',
#    'GM0180',
#    'GM1708',
#    'GM0183',
#    'GM1700',
#    'GM0189',
#    'GM1896',
#    'GM0193']},
#  'PV24': {'name': 'Flevoland',
#   'municipalities': ['GM0034',
#    'GM0303',
#    'GM0995',
#    'GM0171',
#    'GM0184',
#    'GM0050']},
#  'PV25': {'name': 'Gelderland',
#   'municipalities': ['GM0197',
#    'GM0200',
#    'GM0202',
#    'GM0203',
#    'GM1945',
#    'GM1859',
#    'GM0209',
#    'GM1876',
#    'GM0213',
#    'GM0214',
#    'GM0216',
#    'GM0221',
#    'GM0222',
#    'GM0225',
#    'GM0226',
#    'GM0228',
#    'GM0230',
#    'GM0232',
#    'GM0233',
#    'GM0243',
#    'GM0244',
#    'GM0246',
#    'GM0252',
#    'GM1705',
#    'GM0262',
#    'GM0263',
#    'GM1955',
#    'GM1740',
#    'GM0267',
#    'GM0268',
#    'GM0302',
#    'GM0269',
#    'GM1586',
#    'GM1509',
#    'GM1734',
#    'GM0273',
#    'GM0274',
#    'GM0275',
#    'GM0277',
#    'GM0279',
#    'GM0281',
#    'GM0285',
#    'GM0289',
#    'GM1960',
#    'GM0668',
#    'GM0293',
#    'GM0296',
#    'GM0294',
#    'GM0297',
#    'GM0299',
#    'GM0301']},
#  'PV26': {'name': 'Utrecht',
#   'municipalities': ['GM0307',
#    'GM0308',
#    'GM0310',
#    'GM0312',
#    'GM0313',
#    'GM0317',
#    'GM0321',
#    'GM0353',
#    'GM0327',
#    'GM0331',
#    'GM0335',
#    'GM0356',
#    'GM0589',
#    'GM0339',
#    'GM0340',
#    'GM0736',
#    'GM0342',
#    'GM1904',
#    'GM0344',
#    'GM1581',
#    'GM0345',
#    'GM1961',
#    'GM0352',
#    'GM0632',
#    'GM0351',
#    'GM0355']},
#  'PV27': {'name': 'Noord-Holland',
#   'municipalities': ['GM0358',
#    'GM0361',
#    'GM0362',
#    'GM0363',
#    'GM0373',
#    'GM0375',
#    'GM0376',
#    'GM0377',
#    'GM0383',
#    'GM0384',
#    'GM1980',
#    'GM0498',
#    'GM0385',
#    'GM0388',
#    'GM1942',
#    'GM0392',
#    'GM0394',
#    'GM0396',
#    'GM0397',
#    'GM0399',
#    'GM0400',
#    'GM0402',
#    'GM1911',
#    'GM0405',
#    'GM0406',
#    'GM1598',
#    'GM0415',
#    'GM0417',
#    'GM0420',
#    'GM0431',
#    'GM0432',
#    'GM0437',
#    'GM0439',
#    'GM0441',
#    'GM0532',
#    'GM0448',
#    'GM0450',
#    'GM0451',
#    'GM0453',
#    'GM0852',
#    'GM1696',
#    'GM0880',
#    'GM0479',
#    'GM0473']},
#  'PV28': {'name': 'Zuid-Holland',
#   'municipalities': ['GM0482',
#    'GM0613',
#    'GM0484',
#    'GM0489',
#    'GM1901',
#    'GM0502',
#    'GM0503',
#    'GM0505',
#    'GM1924',
#    'GM0512',
#    'GM0513',
#    'GM0518',
#    'GM0523',
#    'GM0531',
#    'GM0534',
#    'GM1963',
#    'GM1884',
#    'GM0537',
#    'GM0542',
#    'GM1931',
#    'GM1621',
#    'GM0546',
#    'GM0547',
#    'GM1916',
#    'GM0553',
#    'GM0556',
#    'GM1842',
#    'GM1978',
#    'GM0569',
#    'GM1930',
#    'GM0575',
#    'GM0579',
#    'GM0590',
#    'GM1926',
#    'GM0597',
#    'GM0603',
#    'GM0599',
#    'GM0606',
#    'GM0610',
#    'GM1525',
#    'GM0622',
#    'GM1992',
#    'GM0626',
#    'GM0627',
#    'GM0629',
#    'GM1783',
#    'GM0637',
#    'GM0638',
#    'GM1892',
#    'GM0642']},
#  'PV29': {'name': 'Zeeland',
#   'municipalities': ['GM0654',
#    'GM0664',
#    'GM0677',
#    'GM0678',
#    'GM0687',
#    'GM1695',
#    'GM0703',
#    'GM1676',
#    'GM1714',
#    'GM0715',
#    'GM0716',
#    'GM0717',
#    'GM0718']},
#  'PV30': {'name': 'Noord-Brabant',
#   'municipalities': ['GM1723',
#    'GM1959',
#    'GM0743',
#    'GM0744',
#    'GM1724',
#    'GM0748',
#    'GM1721',
#    'GM0753',
#    'GM1728',
#    'GM0755',
#    'GM0757',
#    'GM0758',
#    'GM1706',
#    'GM0762',
#    'GM0766',
#    'GM1719',
#    'GM0770',
#    'GM0772',
#    'GM0777',
#    'GM0779',
#    'GM1771',
#    'GM1652',
#    'GM0784',
#    'GM0785',
#    'GM1655',
#    'GM1658',
#    'GM0794',
#    'GM0796',
#    'GM0797',
#    'GM0798',
#    'GM1659',
#    'GM1982',
#    'GM0809',
#    'GM1991',
#    'GM1948',
#    'GM1709',
#    'GM0820',
#    'GM0823',
#    'GM0824',
#    'GM0826',
#    'GM0828',
#    'GM1667',
#    'GM1674',
#    'GM0840',
#    'GM0845',
#    'GM0847',
#    'GM0848',
#    'GM0851',
#    'GM0855',
#    'GM0858',
#    'GM0861',
#    'GM0865',
#    'GM0866',
#    'GM0867',
#    'GM0873',
#    'GM0879']},
#  'PV31': {'name': 'Limburg',
#   'municipalities': ['GM0888',
#    'GM1954',
#    'GM0889',
#    'GM0893',
#    'GM0899',
#    'GM1711',
#    'GM1903',
#    'GM0907',
#    'GM1729',
#    'GM0917',
#    'GM1507',
#    'GM0928',
#    'GM0882',
#    'GM1640',
#    'GM1641',
#    'GM0935',
#    'GM0938',
#    'GM0944',
#    'GM0946',
#    'GM1894',
#    'GM1669',
#    'GM0957',
#    'GM0965',
#    'GM1883',
#    'GM0971',
#    'GM0981',
#    'GM0994',
#    'GM0983',
#    'GM0984',
#    'GM0986',
#    'GM0988']}}

# %%
# Validate: count the number of municipalities in the province_dict
total_municipalities = sum([len(province_dict[province_code]["municipalities"]) for province_code in province_dict])
total_municipalities
# Out:
# 342

# %% [markdown]
# ## Generate amalgamator code

# %% [markdown]
# ### RES regions

# %%
# Script to generate Ruby code from res_dict
def generate_ruby_code_for_res_dict(res_dict):
    ruby_code_lines = []
    
    for res_code, res_data in res_dict.items():
        # Convert ES01 to es01 for variable naming
        variable_name = res_code.lower()
        
        # Sort municipalities for consistent output
        sorted_municipalities = sorted(res_data['municipalities'])
        
        # Format municipalities as Ruby %w array
        municipalities_str = ' '.join(sorted_municipalities)
        
        # Generate the combiner code block
        combiner_block = f"""{variable_name}_combiner = Amalgamator::Combiner.new(
  target_dataset_geo_id: '{res_code}',
  source_data_year: '2023',
  source_dataset_geo_ids: %w[{municipalities_str}],
  target_area_name: '{res_data['name']}',
  target_country_name: 'nl2023',
  migration_slug: 'update_2023'
)
{variable_name}_combined_data = {variable_name}_combiner.result
{variable_name}_migration_filename = {variable_name}_combiner.export_data"""
        
        ruby_code_lines.append(combiner_block)
    
    return '\n\n'.join(ruby_code_lines)

# Generate the Ruby code
ruby_code = generate_ruby_code_for_res_dict(res_dict)
print(ruby_code)
# Out:
# es01_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES01',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0014 GM0037 GM0047 GM0765 GM1895 GM1950 GM1952 GM1966 GM1969 GM1979],
#   target_area_name: 'Groningen',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es01_combined_data = es01_combiner.result
# es01_migration_filename = es01_combiner.export_data
#
# es02_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES02',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0059 GM0060 GM0072 GM0074 GM0080 GM0085 GM0086 GM0088 GM0090 GM0093 GM0096 GM0098 GM0737 GM1891 GM1900 GM1940 GM1949 GM1970],
#   target_area_name: 'Friesland',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es02_combined_data = es02_combiner.result
# es02_migration_filename = es02_combiner.export_data
#
# es03_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES03',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0106 GM0109 GM0114 GM0118 GM0119 GM1680 GM1681 GM1690 GM1699 GM1701 GM1730 GM1731],
#   target_area_name: 'Drenthe',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es03_combined_data = es03_combiner.result
# es03_migration_filename = es03_combiner.export_data
#
# es04_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES04',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0141 GM0147 GM0153 GM0158 GM0163 GM0164 GM0168 GM0173 GM0183 GM0189 GM1700 GM1735 GM1742 GM1774],
#   target_area_name: 'Twente',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es04_combined_data = es04_combiner.result
# es04_migration_filename = es04_combiner.export_data
#
# es05_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES05',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0148 GM0150 GM0160 GM0166 GM0175 GM0177 GM0180 GM0193 GM1708 GM1773 GM1896],
#   target_area_name: 'West-Overijssel',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es05_combined_data = es05_combiner.result
# es05_migration_filename = es05_combiner.export_data
#
# es06_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES06',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0034 GM0050 GM0171 GM0184 GM0303 GM0995],
#   target_area_name: 'Flevoland',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es06_combined_data = es06_combiner.result
# es06_migration_filename = es06_combiner.export_data
#
# es07_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES07',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0197 GM0222 GM0294 GM1509 GM1586 GM1859 GM1876 GM1955],
#   target_area_name: 'Achterhoek',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es07_combined_data = es07_combiner.result
# es07_migration_filename = es07_combiner.export_data
#
# es08_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES08',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0202 GM0209 GM0221 GM0225 GM0226 GM0252 GM0268 GM0274 GM0275 GM0277 GM0293 GM0296 GM0299 GM1705 GM1734 GM1945],
#   target_area_name: 'Arnhem Nijmegen',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es08_combined_data = es08_combiner.result
# es08_migration_filename = es08_combiner.export_data
#
# es09_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES09',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0203 GM0228 GM0267 GM0279 GM0289 GM0339 GM0340 GM0345],
#   target_area_name: 'Foodvalley',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es09_combined_data = es09_combiner.result
# es09_migration_filename = es09_combiner.export_data
#
# es10_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES10',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0230 GM0233 GM0243 GM0244 GM0269 GM0273 GM0302],
#   target_area_name: 'Noord-Veluwe',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es10_combined_data = es10_combiner.result
# es10_migration_filename = es10_combiner.export_data
#
# es11_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES11',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0214 GM0216 GM0263 GM0281 GM0297 GM0668 GM1740 GM1960],
#   target_area_name: 'Fruitdelta Rivierenland',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es11_combined_data = es11_combiner.result
# es11_migration_filename = es11_combiner.export_data
#
# es12_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES12',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0200 GM0213 GM0232 GM0246 GM0262 GM0285 GM0301],
#   target_area_name: 'Stedendriehoek',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es12_combined_data = es12_combiner.result
# es12_migration_filename = es12_combiner.export_data
#
# es13_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES13',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0307 GM0308 GM0313 GM0317 GM0327 GM0342 GM0351],
#   target_area_name: 'Amersfoort',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es13_combined_data = es13_combiner.result
# es13_migration_filename = es13_combiner.export_data
#
# es14_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES14',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0310 GM0312 GM0321 GM0331 GM0335 GM0344 GM0352 GM0353 GM0355 GM0356 GM0589 GM0632 GM0736 GM1581 GM1904 GM1961],
#   target_area_name: 'U16',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es14_combined_data = es14_combiner.result
# es14_migration_filename = es14_combiner.export_data
#
# es15_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES15',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0361 GM0373 GM0383 GM0388 GM0399 GM0400 GM0405 GM0420 GM0432 GM0441 GM0448 GM0450 GM0498 GM0532 GM1598 GM1911 GM1980],
#   target_area_name: 'Noord-Holland Noord',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es15_combined_data = es15_combiner.result
# es15_migration_filename = es15_combiner.export_data
#
# es16_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES16',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0358 GM0362 GM0363 GM0375 GM0376 GM0377 GM0384 GM0385 GM0392 GM0394 GM0396 GM0397 GM0402 GM0406 GM0415 GM0417 GM0431 GM0437 GM0439 GM0451 GM0453 GM0473 GM0479 GM0852 GM0880 GM1696 GM1942],
#   target_area_name: 'Noord-Holland Zuid',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es16_combined_data = es16_combiner.result
# es16_migration_filename = es16_combiner.export_data
#
# es17_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES17',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0512 GM1978],
#   target_area_name: 'Alblasserwaard',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es17_combined_data = es17_combiner.result
# es17_migration_filename = es17_combiner.export_data
#
# es18_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES18',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0482 GM0505 GM0523 GM0531 GM0590 GM0610 GM0642],
#   target_area_name: 'Drechtsteden',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es18_combined_data = es18_combiner.result
# es18_migration_filename = es18_combiner.export_data
#
# es19_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES19',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM1924],
#   target_area_name: 'Goeree-Overflakkee',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es19_combined_data = es19_combiner.result
# es19_migration_filename = es19_combiner.export_data
#
# es20_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES20',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM1963],
#   target_area_name: 'Hoeksche Waard',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es20_combined_data = es20_combiner.result
# es20_migration_filename = es20_combiner.export_data
#
# es21_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES21',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0484 GM0534 GM0537 GM0546 GM0547 GM0553 GM0569 GM0575 GM0579 GM0626 GM0638 GM1525 GM1884],
#   target_area_name: 'Holland Rijnland',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es21_combined_data = es21_combiner.result
# es21_migration_filename = es21_combiner.export_data
#
# es22_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES22',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0513 GM0627 GM1892 GM1901 GM1931],
#   target_area_name: 'Midden-Holland',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es22_combined_data = es22_combiner.result
# es22_migration_filename = es22_combiner.export_data
#
# es23_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES23',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0489 GM0502 GM0503 GM0518 GM0542 GM0556 GM0597 GM0599 GM0603 GM0606 GM0613 GM0622 GM0629 GM0637 GM1621 GM1783 GM1842 GM1916 GM1926 GM1930 GM1992],
#   target_area_name: 'Rotterdam-Den Haag',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es23_combined_data = es23_combiner.result
# es23_migration_filename = es23_combiner.export_data
#
# es24_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES24',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0654 GM0664 GM0677 GM0678 GM0687 GM0703 GM0715 GM0716 GM0717 GM0718 GM1676 GM1695 GM1714],
#   target_area_name: 'Zeeland',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es24_combined_data = es24_combiner.result
# es24_migration_filename = es24_combiner.export_data
#
# es25_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES25',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0766 GM0784 GM0785 GM0797 GM0798 GM0809 GM0824 GM0855 GM0867],
#   target_area_name: 'Hart van Brabant',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es25_combined_data = es25_combiner.result
# es25_migration_filename = es25_combiner.export_data
#
# es26_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES26',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0743 GM0753 GM0762 GM0770 GM0772 GM0794 GM0820 GM0823 GM0847 GM0848 GM0858 GM0861 GM0866 GM1652 GM1658 GM1659 GM1667 GM1706 GM1724 GM1728 GM1771],
#   target_area_name: 'Metropoolregio Eindhoven',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es26_combined_data = es26_combiner.result
# es26_migration_filename = es26_combiner.export_data
#
# es27_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES27',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0755 GM0757 GM0796 GM0828 GM0845 GM0865 GM1721 GM1948 GM1982 GM1991],
#   target_area_name: 'Noordoost Brabant',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es27_combined_data = es27_combiner.result
# es27_migration_filename = es27_combiner.export_data
#
# es28_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES28',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0744 GM0748 GM0758 GM0777 GM0779 GM0826 GM0840 GM0851 GM0873 GM0879 GM1655 GM1674 GM1709 GM1719 GM1723 GM1959],
#   target_area_name: 'West-Brabant',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es28_combined_data = es28_combiner.result
# es28_migration_filename = es28_combiner.export_data
#
# es29_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES29',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0889 GM0893 GM0907 GM0944 GM0946 GM0957 GM0983 GM0984 GM0988 GM1507 GM1640 GM1641 GM1669 GM1711 GM1894],
#   target_area_name: 'Noord- en Midden-Limburg',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es29_combined_data = es29_combiner.result
# es29_migration_filename = es29_combiner.export_data
#
# es30_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'ES30',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0882 GM0888 GM0899 GM0917 GM0928 GM0935 GM0938 GM0965 GM0971 GM0981 GM0986 GM0994 GM1729 GM1883 GM1903 GM1954],
#   target_area_name: 'Zuid-Limburg',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# es30_combined_data = es30_combiner.result
# es30_migration_filename = es30_combiner.export_data

# %% [markdown]
# ### Provinces

# %%
# Script to generate Ruby code from province_dict
def generate_ruby_code_for_province_dict(province_dict):
    ruby_code_lines = []
    
    for province_code, province_data in province_dict.items():
        # Convert PV20 to pv20 for variable naming
        variable_name = province_code.lower()
        
        # Sort municipalities for consistent output
        sorted_municipalities = sorted(province_data['municipalities'])
        
        # Format municipalities as Ruby %w array
        municipalities_str = ' '.join(sorted_municipalities)
        
        # Generate the combiner code block
        combiner_block = f"""{variable_name}_combiner = Amalgamator::Combiner.new(
  target_dataset_geo_id: '{province_code}',
  source_data_year: '2023',
  source_dataset_geo_ids: %w[{municipalities_str}],
  target_area_name: '{province_data['name']}',
  target_country_name: 'nl2023',
  migration_slug: 'update_2023'
)
{variable_name}_combined_data = {variable_name}_combiner.result
{variable_name}_migration_filename = {variable_name}_combiner.export_data"""
        
        ruby_code_lines.append(combiner_block)
    
    return '\n\n'.join(ruby_code_lines)

# Generate the Ruby code
ruby_code = generate_ruby_code_for_province_dict(province_dict)
print(ruby_code)
# Out:
# pv20_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'PV20',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0014 GM0037 GM0047 GM0765 GM1895 GM1950 GM1952 GM1966 GM1969 GM1979],
#   target_area_name: 'Groningen',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# pv20_combined_data = pv20_combiner.result
# pv20_migration_filename = pv20_combiner.export_data
#
# pv21_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'PV21',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0059 GM0060 GM0072 GM0074 GM0080 GM0085 GM0086 GM0088 GM0090 GM0093 GM0096 GM0098 GM0737 GM1891 GM1900 GM1940 GM1949 GM1970],
#   target_area_name: 'Fryslan',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# pv21_combined_data = pv21_combiner.result
# pv21_migration_filename = pv21_combiner.export_data
#
# pv22_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'PV22',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0106 GM0109 GM0114 GM0118 GM0119 GM1680 GM1681 GM1690 GM1699 GM1701 GM1730 GM1731],
#   target_area_name: 'Drenthe',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# pv22_combined_data = pv22_combiner.result
# pv22_migration_filename = pv22_combiner.export_data
#
# pv23_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'PV23',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0141 GM0147 GM0148 GM0150 GM0153 GM0158 GM0160 GM0163 GM0164 GM0166 GM0168 GM0173 GM0175 GM0177 GM0180 GM0183 GM0189 GM0193 GM1700 GM1708 GM1735 GM1742 GM1773 GM1774 GM1896],
#   target_area_name: 'Overijssel',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# pv23_combined_data = pv23_combiner.result
# pv23_migration_filename = pv23_combiner.export_data
#
# pv24_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'PV24',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0034 GM0050 GM0171 GM0184 GM0303 GM0995],
#   target_area_name: 'Flevoland',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# pv24_combined_data = pv24_combiner.result
# pv24_migration_filename = pv24_combiner.export_data
#
# pv25_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'PV25',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0197 GM0200 GM0202 GM0203 GM0209 GM0213 GM0214 GM0216 GM0221 GM0222 GM0225 GM0226 GM0228 GM0230 GM0232 GM0233 GM0243 GM0244 GM0246 GM0252 GM0262 GM0263 GM0267 GM0268 GM0269 GM0273 GM0274 GM0275 GM0277 GM0279 GM0281 GM0285 GM0289 GM0293 GM0294 GM0296 GM0297 GM0299 GM0301 GM0302 GM0668 GM1509 GM1586 GM1705 GM1734 GM1740 GM1859 GM1876 GM1945 GM1955 GM1960],
#   target_area_name: 'Gelderland',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# pv25_combined_data = pv25_combiner.result
# pv25_migration_filename = pv25_combiner.export_data
#
# pv26_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'PV26',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0307 GM0308 GM0310 GM0312 GM0313 GM0317 GM0321 GM0327 GM0331 GM0335 GM0339 GM0340 GM0342 GM0344 GM0345 GM0351 GM0352 GM0353 GM0355 GM0356 GM0589 GM0632 GM0736 GM1581 GM1904 GM1961],
#   target_area_name: 'Utrecht',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# pv26_combined_data = pv26_combiner.result
# pv26_migration_filename = pv26_combiner.export_data
#
# pv27_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'PV27',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0358 GM0361 GM0362 GM0363 GM0373 GM0375 GM0376 GM0377 GM0383 GM0384 GM0385 GM0388 GM0392 GM0394 GM0396 GM0397 GM0399 GM0400 GM0402 GM0405 GM0406 GM0415 GM0417 GM0420 GM0431 GM0432 GM0437 GM0439 GM0441 GM0448 GM0450 GM0451 GM0453 GM0473 GM0479 GM0498 GM0532 GM0852 GM0880 GM1598 GM1696 GM1911 GM1942 GM1980],
#   target_area_name: 'Noord-Holland',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# pv27_combined_data = pv27_combiner.result
# pv27_migration_filename = pv27_combiner.export_data
#
# pv28_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'PV28',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0482 GM0484 GM0489 GM0502 GM0503 GM0505 GM0512 GM0513 GM0518 GM0523 GM0531 GM0534 GM0537 GM0542 GM0546 GM0547 GM0553 GM0556 GM0569 GM0575 GM0579 GM0590 GM0597 GM0599 GM0603 GM0606 GM0610 GM0613 GM0622 GM0626 GM0627 GM0629 GM0637 GM0638 GM0642 GM1525 GM1621 GM1783 GM1842 GM1884 GM1892 GM1901 GM1916 GM1924 GM1926 GM1930 GM1931 GM1963 GM1978 GM1992],
#   target_area_name: 'Zuid-Holland',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# pv28_combined_data = pv28_combiner.result
# pv28_migration_filename = pv28_combiner.export_data
#
# pv29_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'PV29',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0654 GM0664 GM0677 GM0678 GM0687 GM0703 GM0715 GM0716 GM0717 GM0718 GM1676 GM1695 GM1714],
#   target_area_name: 'Zeeland',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# pv29_combined_data = pv29_combiner.result
# pv29_migration_filename = pv29_combiner.export_data
#
# pv30_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'PV30',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0743 GM0744 GM0748 GM0753 GM0755 GM0757 GM0758 GM0762 GM0766 GM0770 GM0772 GM0777 GM0779 GM0784 GM0785 GM0794 GM0796 GM0797 GM0798 GM0809 GM0820 GM0823 GM0824 GM0826 GM0828 GM0840 GM0845 GM0847 GM0848 GM0851 GM0855 GM0858 GM0861 GM0865 GM0866 GM0867 GM0873 GM0879 GM1652 GM1655 GM1658 GM1659 GM1667 GM1674 GM1706 GM1709 GM1719 GM1721 GM1723 GM1724 GM1728 GM1771 GM1948 GM1959 GM1982 GM1991],
#   target_area_name: 'Noord-Brabant',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# pv30_combined_data = pv30_combiner.result
# pv30_migration_filename = pv30_combiner.export_data
#
# pv31_combiner = Amalgamator::Combiner.new(
#   target_dataset_geo_id: 'PV31',
#   source_data_year: '2023',
#   source_dataset_geo_ids: %w[GM0882 GM0888 GM0889 GM0893 GM0899 GM0907 GM0917 GM0928 GM0935 GM0938 GM0944 GM0946 GM0957 GM0965 GM0971 GM0981 GM0983 GM0984 GM0986 GM0988 GM0994 GM1507 GM1640 GM1641 GM1669 GM1711 GM1729 GM1883 GM1894 GM1903 GM1954],
#   target_area_name: 'Limburg',
#   target_country_name: 'nl2023',
#   migration_slug: 'update_2023'
# )
# pv31_combined_data = pv31_combiner.result
# pv31_migration_filename = pv31_combiner.export_data
